# %% [markdown]
# # Download data from "The Movie Database" (TMDB)

# %% [markdown]
# We connect with "The Movie Database" API to get data about the cast and popularity of every movie on our original dataset

# %%
import pandas as pd
import numpy as np
import requests
import datetime

# %%
# Import DataFrame
df = pd.read_excel("netflix_movies_dataset.xlsx")

df.sample(10)
# Out:
#                                      Title                      Genre  \
# 549      To All the Boys I've Loved Before            Romantic comedy
# 650                 Untold: Breaking Point                Documentary
# 563  Loudon Wainwright III: Surviving Twin               One-man show
# 679                Cuba and the Cameraman                 Documentary
# 486                   Long Live Brij Mohan                     Comedy
# 223                              15 August               Comedy-drama
# 285             Deidra & Laney Rob a Train                      Drama
# 220                    All Day and a Night                      Drama
# 93                        Rim of the World  Science fiction adventure
# 332                           Get the Goat                     Comedy
#
#               Premiere  Runtime  IMDB Score    Language
# 549    August 17, 2018       99         7.1     English
# 650  September 7, 2021       79         7.6     English
# 563  November 13, 2018       91         7.1     English
# 679  November 24, 2017      114         8.3     English
# 486     August 3, 2018      105         6.8       Hindi
# 223     March 29, 2019      124         5.8     Marathi
# 285     March 17, 2017       94         6.1     English
# 220        May 1, 2020      121         5.8     English
# 93        May 24, 2019       98         5.2     English
# 332     March 18, 2021       97         6.3  Portuguese

# %%
df.drop_duplicates(inplace = True)
df.reset_index(drop = True, inplace = True)

# %%
# Prepare "Premiere column": transform to datetime and get year
df["Premiere"] = pd.to_datetime(df["Premiere"])
df["premiere_year"] = df["Premiere"].dt.year
df.head()
# Out:
#              Title                  Genre   Premiere  Runtime  IMDB Score  \
# 0  Enter the Anime            Documentary 2019-08-05       58         2.5
# 1      Dark Forces               Thriller 2020-08-21       81         2.6
# 2          The App  Science fiction/Drama 2019-12-26       79         2.6
# 3    Sex: Unzipped                 Comedy 2021-10-26       59         3.1
# 4          Swallow                  Drama 2021-10-01      128         3.2
#
#            Language  premiere_year
# 0  English/Japanese           2019
# 1           Spanish           2020
# 2           Italian           2019
# 3           English           2021
# 4           English           2021

# %% [markdown]
# ### 1. Get every movie id
#
# We first get every movie ID and we append the result to the DataFrame

# %%
def get_movie_data(movie):
    '''
    
    Function that gets the name of the movie, connects with the TMDB API and gets all movies data with same name
    
    Parameters
    ==========
    
    movie: str
        Movie's name
    
    Returns
    =======
    
    dict
        movie's data
    '''
    
    # Prepare the string for the ID query replacing " " for "%20"
    movie.replace(" ", "%20")
    
    # Communicate with the API
    response = requests.get(f"http://api.tmdb.org/3/search/movie?api_key=f062d4d3bef1ed6f224531125e4c20c7&query={movie}")
    
    # If the status_code is 200 the function communicated correctly with the API
    if response.status_code == 200:
        
        #Gets movie's data and returns it
        try:
            movie_data = response.json()['results']
        
            return movie_data
        
        # If the program can't get data it prints a phrase
        except:
            movie_data = "No data was found"
            
            return movie_data
    
    else:
        return "The program failed to communicate with the API"

# %%
get_movie_data("7 prisoners")
# Out:
# [{'adult': False,
#   'backdrop_path': '/pKgfWzxOpvGV3MQ0kLjLdjKAzUe.jpg',
#   'genre_ids': [18, 80],
#   'id': 785538,
#   'original_language': 'pt',
#   'original_title': '7 Prisioneiros',
#   'overview': 'To provide a better life for his family in the country, 18-year-old Mateus accepts a job in a junkyard in São Paulo for his new boss Luca. But when he and a few other boys become trapped in the dangerous world of contemporary slavery, Mateus will be forced to decide between working for the very man who enslaved him or risk his and his family’s future.',
#   'popularity': 34.285,
#   'poster_path': '/5svMKCGnR6Yvj8wxldvDvgUi0Jk.jpg',
#   'release_date': '2021-11-11',
#   'title': '7 Prisoners',
#   'video': False,
#   'vote_average': 6,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/gv0p6gQM6tDkJFx2UpURWyCAjPn.jpg',
#   'genre_ids': [18, 53, 80],
#   'id': 146233,
#   'original_language': 'en',
#   'original_title': 'Prisoners',
#   'overview': "Keller Dover faces a parent's worst nightmare when his 6-year-old daughter, Anna, and her friend go missing. The only lead is an old motorhome that had been parked on their street. The head of the investigation, Detective Loki, arrests the driver, but a lack of evidence forces Loki to release his only suspect. Dover, knowing that his daughter's life is at stake, decides that he has no choice but to take matters into his own hands.",
#   'popularity': 54.842,
#   'poster_path': '/tuZhZ6biFMr5n9YSVuHOJnNL1uU.jpg',
#   'release_date': '2013-09-18',
#   'title': 'Prisoners',
#   'video': False,
#   'vote_average': 8,
#   'vote_count': 8605},
#  {'adult': False,
#   'backdrop_path': '/aSgFDRnfppKxRGZE8BWOfgzAR3k.jpg',
#   'genre_ids': [28, 27, 53],
#   'id': 523638,
#   'original_language': 'en',
#   'original_title': 'Prisoners of the Ghostland',
#   'overview': 'In the treacherous frontier city of Samurai Town, a ruthless bank robber is sprung from jail by wealthy warlord The Governor, whose adopted granddaughter Bernice has gone missing. The Governor offers the prisoner his freedom in exchange for retrieving the runaway. Strapped into a leather suit that will self-destruct within five days, the bandit sets off on a journey to find the young woman—and his own path to redemption.',
#   'popularity': 44.149,
#   'poster_path': '/j5HRzcvN1QXZLvwfc3NLxX8XQJY.jpg',
#   'release_date': '2021-08-31',
#   'title': 'Prisoners of the Ghostland',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 156},
#  {'adult': False,
#   'backdrop_path': '/e6CnfsN7wnhZEMqh5EnCfTDXQ7g.jpg',
#   'genre_ids': [28, 12, 14, 16],
#   'id': 507569,
#   'original_language': 'ja',
#   'original_title': '劇場版 七つの大罪 天空の囚われ人',
#   'overview': 'Traveling in search of the rare ingredient, “sky fish”  Meliodas and Hawk arrive at a palace that floats above the clouds. The people there are busy preparing a ceremony, meant to protect their home from a ferocious beast that awakens once every 3,000 years. But before the ritual is complete, the Six Knights of Black—a Demon Clan army—removes the seal on the beast, threatening the lives of everyone in the Sky Palace.',
#   'popularity': 26.473,
#   'poster_path': '/63NOOAkaZAK8h93Sg7Ucq6XLJGP.jpg',
#   'release_date': '2018-08-18',
#   'title': 'The Seven Deadly Sins: Prisoners of the Sky',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 865},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 473968,
#   'original_language': 'fr',
#   'original_title': 'Prisioneros',
#   'overview': 'Civil war in Belgium. Charles and Bruno are childhood friends. Walloon and Flamenco. Now one is a prisoner of war in the custody of the other.',
#   'popularity': 4,
#   'poster_path': '/f0b8T3YU3poIVuCa7fziaAGr0TY.jpg',
#   'release_date': '1999-07-22',
#   'title': 'Prisoners',
#   'video': False,
#   'vote_average': 4,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/5E11a3n4ccCnqXWAAbup33FMptk.jpg',
#   'genre_ids': [9648, 28, 12, 27],
#   'id': 241958,
#   'original_language': 'en',
#   'original_title': 'Prisoners of the Sun',
#   'overview': 'A multinational expedition discovers a lost city beneath a pyramid, where they must stop the reawakened gods of ancient Egypt from initiating the apocalypse',
#   'popularity': 6.629,
#   'poster_path': '/rdiiY0KpjSIaOvt9UwoDvdI7K67.jpg',
#   'release_date': '2013-12-20',
#   'title': 'Prisoners of the Sun',
#   'video': False,
#   'vote_average': 3.6,
#   'vote_count': 42},
#  {'adult': False,
#   'backdrop_path': '/xUPcTaq3dKOK3tInplsX7qQ0Uzb.jpg',
#   'genre_ids': [18, 9648, 53],
#   'id': 36915,
#   'original_language': 'en',
#   'original_title': "Heaven's Prisoners",
#   'overview': 'A hardened New Orleans cop, Dave Robicheaux, finally tosses in the badge and settles into life on the bayou with his wife. But a bizarre plane crash draws him back into the fray when his family is viciously threatened.',
#   'popularity': 5.155,
#   'poster_path': '/yUWVNHA3dVc1CmxNIcXZWqbqWc8.jpg',
#   'release_date': '1996-05-17',
#   'title': "Heaven's Prisoners",
#   'video': False,
#   'vote_average': 5.2,
#   'vote_count': 53},
#  {'adult': False,
#   'backdrop_path': '/6D10gvq47mq5fansWWOB3t2JJyB.jpg',
#   'genre_ids': [35],
#   'id': 129467,
#   'original_language': 'sv',
#   'original_title': 'Släpp fångarne loss - det är vår!',
#   'overview': 'Small and short Frida lives with her long, tall friend in a house in the countryside. Frida rejects the idea that people who have committed crimes should be locked up. One day their own house is burgled by Harald. He is sentenced to prison. Acting in accordance with her philosophy, Frida decides to use all means possible to make it possible for Harald to escape.',
#   'popularity': 1.632,
#   'poster_path': '/mfdMGrMFHd4E372Oj4ZF3tHgy9l.jpg',
#   'release_date': '1975-12-06',
#   'title': "Let the Prisoners Go for It's Spring",
#   'video': False,
#   'vote_average': 5.8,
#   'vote_count': 25},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99, 10752],
#   'id': 262005,
#   'original_language': 'it',
#   'original_title': 'Prigionieri della guerra',
#   'overview': 'This haunting film comprises of footage shot during WWI from opposite sides of the conflict: Czarist Russia and the Austro-Hungarian empire. The filmmakers tinted the material with sensual colors from sepia to red, blue, and purple and slowed the footage to analyze the material. The total absence of commentary renders the material eloquent and disturbing. - MoMA',
#   'popularity': 0.99,
#   'poster_path': '/oAllbo5Xt1HatJJ5vNru0EsrbfK.jpg',
#   'release_date': '1995-01-01',
#   'title': 'Prisoners of War',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 499184,
#   'original_language': 'en',
#   'original_title': 'Prisoners and Pups',
#   'overview': 'A group of women prisoners have signed up to foster retired racing greyhounds and get them ready for adoption. The prisoners have just eight weeks to transform the dogs into family pets, or the dogs could be euthanised.',
#   'popularity': 0.6,
#   'poster_path': '/5Y1G30iR5SFUP4n6Vt6lIulDcQe.jpg',
#   'release_date': '2017-10-12',
#   'title': 'Prisoners and Pups',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/oBQSpNPR8HeUTnrWjfNe03U7dhM.jpg',
#   'genre_ids': [18, 10751, 10752],
#   'id': 274844,
#   'original_language': 'hu',
#   'original_title': 'A föld rabjai',
#   'overview': 'The daughter of the farmer András Balogh, Juli, is confused by the sight of a circus, she leaves her native village secretly and enters into an engagement with the dance master at a night club in the capital. Her seducer tortures her with dancing drills even during the night, what is more, he beats her. She escapes from her tormentor one night and enters into engagement in Russia. Juli becomes Juliette, and soon we can see her again on the Tashkent property of a prince, where she lives in luxury. In the meantime, war breaks out. Prisoners are brought into the castle. Juli discovers her own father among them, but he does not forgive her for bringing shame on him. One day, as the exchanged prisoners set off for their homeland in the morning fog, Juliette dresses up in the old clothes of Juli, braids her hair and leaves everything, riches and love behind, to return to the land, which her soul became a prisoner of in the very moment she was born .',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '1917-08-17',
#   'title': 'Prisoners of Land',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [80, 18],
#   'id': 72283,
#   'original_language': 'en',
#   'original_title': 'น.ช. นักโทษชาย',
#   'overview': "Ray's life is turned upside down when he is jailed for the accidental vehicular homicide. Life behind bars is bitter and violent. Over crowding, male rape, and drug abuse are the order of the day. The warden offers him a way out from this daily torment by working for him. He does his job well but he soon begins to realize that many of those incarcerated are innocent or victims of bad circumstances - but what can he do to help and how much danger is he placing himself in?",
#   'popularity': 1.4,
#   'poster_path': '/2MseJBoXwZ6mc2SnAJGnACvDnKy.jpg',
#   'release_date': '2002-02-28',
#   'title': 'Bangkok Hell: Nor Chor - The Prisoners',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18, 80],
#   'id': 455871,
#   'original_language': 'cn',
#   'original_title': '同囚',
#   'overview': 'After a bar brawl with an off-duty cop, aspiring thug Fan (Neo Yau, Fire Lee’s gonzo Robbery) is sentenced to three months in juvenile detention like Hong Kong’s Sha Tsui Detention Center, which practices military-style rehabilitation. Insults and abuse are core tenets of the treatment, carried out by the bored, jaded staff, where an occasional true believer lingers among the guards...',
#   'popularity': 0.885,
#   'poster_path': '/qIpb2TU3UEyHwziyVtGS0Ib1LP6.jpg',
#   'release_date': '2017-05-04',
#   'title': 'With Prisoners',
#   'video': False,
#   'vote_average': 6,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/jxjaoLHLC3WogMQJxaHjv956hHJ.jpg',
#   'genre_ids': [16, 12, 10770],
#   'id': 441298,
#   'original_language': 'fr',
#   'original_title': 'Le Temple du Soleil',
#   'overview': 'Tintin and Captain Haddock travel to Peru in search of an abducted friend.',
#   'popularity': 2.631,
#   'poster_path': '/i446S8HoOOOxtteUqdQTLqG81JX.jpg',
#   'release_date': '1992-08-03',
#   'title': 'Prisoners of the Sun',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 27},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 458929,
#   'original_language': 'nl',
#   'original_title': 'De gevangenen van Buñuel',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2000-05-24',
#   'title': "Buñuel's Prisoners",
#   'video': False,
#   'vote_average': 7,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/eChC1WI3Wnq0fNTm5bw5MiIqlcU.jpg',
#   'genre_ids': [28, 18, 10752],
#   'id': 28670,
#   'original_language': 'en',
#   'original_title': 'The Secret of Blood Island',
#   'overview': "Based on the true story of a British secret agent, shot down over Malaya near to a Allied POW forced labour camp. There she is hidden, disguised as a youthful prisoner, until her escape can be effected. The costs of keeping her identity secret fall on all the POW's as the Japanese embark on a policy of ruthless terror to extract her and the focus shifts to the conflicts of the group' s collective concerns against the necessities of personal survival.",
#   'popularity': 1.395,
#   'poster_path': '/76lrUyGAmqG88x3TuG5RcSI5Mo7.jpg',
#   'release_date': '1964-12-01',
#   'title': 'The Secret of Blood Island',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 287212,
#   'original_language': 'de',
#   'original_title': 'Gefangene der Liebe',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '1954-07-28',
#   'title': 'Prisoners of Love',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg',
#   'genre_ids': [18, 12],
#   'id': 619556,
#   'original_language': 'fr',
#   'original_title': 'Guerriers et Captives',
#   'overview': 'Patagonia, Argentina, 1880s. During the Conquest of the Desert, Marguerite, the French wife of Colonel Garay, in charge of protecting a new railway, discovers that a French woman is being held captive by the local natives.',
#   'popularity': 0.6,
#   'poster_path': '/ytYs98qqVmiY45cxkqNgJbj8uDL.jpg',
#   'release_date': '1990-09-05',
#   'title': 'Warriors and Prisoners',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [28, 12],
#   'id': 578464,
#   'original_language': 'es',
#   'original_title': 'Tres Reos',
#   'overview': "Three prisoners escape from a train or something. And I think they had to go find a treasure. They shoot some people at some point. Also, one of them had a retarded kid that either got shot or shot someone.  Most of the movie takes place on a farm with some old people. Maybe they are holding the old people hostage? That's all I remember.",
#   'popularity': 0.6,
#   'poster_path': '/u6r6k4do7H3aTJNp75dmNUesw65.jpg',
#   'release_date': '2000-05-05',
#   'title': 'Three Prisoners',
#   'video': False,
#   'vote_average': 5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 504204,
#   'original_language': 'en',
#   'original_title': 'Der Gefangenenchor',
#   'overview': 'The film is based on a scene in Beethoven’s opera Fidelio. The inmates of the Seville prison are kept in dark cells without daylight. Now, for the first time after years, they are allowed to see the sun.  Light as a metaphor for freedom.',
#   'popularity': 0.6,
#   'poster_path': '/rWt8iGDspuz8UOnVY3ckKIGYcWK.jpg',
#   'release_date': '2004-02-09',
#   'title': 'Choir of the Prisoners',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0}]

# %%
def get_movie_id(title, release_year):
    '''
    Function that takes in input a movie title and its release year, communicates with TMDB API and returns the ID of
    the movie that matches the release year of the title in input
    
    Parameters
    ==========

    title: str 
        movie's title
    
    release_year: int 
        movie's release year
    
    Returns
    =======
    
    int 
        movie's id
    '''
    
    # Applies get_movie_data function to get data about every movie with a same title
    data = get_movie_data(title)
    
    # Make a for cicle to return de ID of the movie that matches the year in input or the year before (teather's premiere)
    try:
        if len(data) == 1:
            return data[0]["id"]
        
        elif len(data) > 1:
            for i in data:
                date = pd.to_datetime(i["release_date"])
                if release_year == date.year or release_year == (date.year) + 1:
                    return i["id"]
                else:
                    pass
        
        else:
            pass
        
    # If the program can't find the release_date returns "?"
    except:
        return "?"

# %%
# Prove
get_movie_id("7 prisoners", 2021)
# Out:
# 785538

# %% [markdown]
# #### 1.1 Build the ID column

# %%
# List comprehension that builds the "id" column: we iterate with ".iterrows()"
df["tmdb_id"] = [get_movie_id(i[1]["Title"], i[1]["premiere_year"]) for i in df.iterrows()]

df.sample(10)
# Out:
#                       Title                    Genre   Premiere  Runtime  \
# 159                 Òlòt?ré              Crime drama 2020-10-02      106
# 25           After the Raid              Documentary 2019-12-19       25
# 96             #REALITYHIGH                   Comedy 2017-09-08       99
# 516  The Claudia Kishi Club              Documentary 2020-07-10       17
# 124           A Perfect Fit  Romantic comedy / drama 2021-07-15      112
# 643       The Bleeding Edge              Documentary 2018-07-27      100
# 588              Procession              Documentary 2021-11-19      118
# 361             Street Flow                    Drama 2019-10-12       96
# 191    The Holiday Calendar          Romantic comedy 2018-11-02       95
# 331          Stuck Together                   Comedy 2021-10-20      126
#
#      IMDB Score    Language  premiere_year tmdb_id
# 159         5.5     English           2020    None
# 25          4.3     Spanish           2019  650029
# 96          5.2     English           2017       ?
# 516         6.9     English           2020  686677
# 124         5.3  Indonesian           2021  800669
# 643         7.6     English           2018  511815
# 588         7.2     English           2021  869623
# 361         6.4      French           2019  614488
# 191         5.7     English           2018  555850
# 331         6.3      French           2021  785516

# %% [markdown]
# #### 1.2 Data validation

# %%
# Rows to solve
rows_to_solve = df[df["tmdb_id"].duplicated(keep = False)]
rows_to_solve
# Out:
#                                                  Title  \
# 11                                             Paradox
# 45    Porta dos Fundos: The First Temptation of Christ
# 88                                           The Beast
# 150                                         Sweet Girl
# 159                                            Òlòt?ré
# 163                            The Cloverfield Paradox
# 299                                      The Lovebirds
# 314                                            Voyuer
# 321                 Octonauts & the Caves of Sac Actun
# 358                Porta dos Fundos: The Last Hangover
# 382                                The Heartbreak Club
# 417                                The Heartbreak Club
# 459                                       Sweet & Sour
# 485                               Long Live Brij Mohan
# 492           Blood Brothers: Malcolm X & Muhammad Ali
# 527  I'm No Longer Here: A Discussion with Guillerm...
# 559                             Ali & Ratu Ratu Queens
# 585        The Road to El Camino: A Breaking Bad Movie
# 590                                          Seventeen
# 604                 Octonauts & the Great Barrier Reef
# 630                                        City of Joy
# 648  Rolling Thunder Revue: A bob Dylan Story by Ma...
# 668       Struggle: The Life and Lost Art of Szukaiski
#
#                           Genre   Premiere  Runtime  IMDB Score    Language  \
# 11      Musical/Western/Fantasy 2018-03-23       73         3.9     English
# 45                       Comedy 2019-12-03       46         4.6  Portuguese
# 88                        Drama 2020-11-27       99         5.2     Italian
# 150                      Action 2021-08-20      110         5.5     English
# 159                 Crime drama 2020-10-02      106         5.5     English
# 163             Science fiction 2018-02-04      102         5.5     English
# 299             Romantic comedy 2020-05-22       87         6.1     English
# 314                 Documentary 2017-12-01       95         6.2     English
# 321                   Animation 2020-08-14       72         6.2     English
# 358                      Comedy 2018-12-21       44         6.3  Portuguese
# 382                Comedy-drama 2021-01-14      101         6.4  Indonesian
# 417                Comedy-drama 2021-01-14      101         6.5  Indonesian
# 459              Romantic drama 2021-06-04      102         6.7      Korean
# 485                      Comedy 2018-08-03      105         6.8       Hindi
# 492                 Documentary 2021-09-09       96         6.8     English
# 527       Aftershow / Interview 2020-11-03       14         7.0     English
# 559                Comedy-drama 2021-06-17      100         7.1  Indonesian
# 585                   Making-of 2019-10-29       13         7.2     English
# 590  Coming-of-age comedy-drama 2019-10-18       99         7.2     Spanish
# 604                   Animation 2020-10-13       47         7.3     English
# 630                 Documentary 2018-09-07       74         7.5     English
# 648                 Documentary 2019-06-12      144         7.6     English
# 668                 Documentary 2018-12-21      105         8.0     English
#
#      premiere_year tmdb_id
# 11            2018  384521
# 45            2019    None
# 88            2020    None
# 150           2021  619297
# 159           2020    None
# 163           2018  384521
# 299           2020    None
# 314           2017    None
# 321           2020  726940
# 358           2018    None
# 382           2021  672745
# 417           2021  672745
# 459           2021  619297
# 485           2018    None
# 492           2021  861604
# 527           2020    None
# 559           2021  861604
# 585           2019    None
# 590           2019    None
# 604           2020  726940
# 630           2018    None
# 648           2019    None
# 668           2018    None

# %%
rows_to_solve.shape
# Out:
# (23, 8)

# %% [markdown]
# ##### Duplicates and "?: we solve it manually

# %%
rows_to_solve["tmdb_id"].value_counts()
# Out:
# 384521    2
# 672745    2
# 861604    2
# 726940    2
# 619297    2
# Name: tmdb_id, dtype: int64

# %%
df[df["tmdb_id"] == "?"]
# Out:
#            Title   Genre   Premiere  Runtime  IMDB Score Language  \
# 96  #REALITYHIGH  Comedy 2017-09-08       99         5.2  English
#
#     premiere_year tmdb_id
# 96           2017       ?

# %%
# Solve rows that failed to receive data
get_movie_data("#realityhigh")
# Out:
# 'The program failed to communicate with the API'

# %%
get_movie_data("realityhigh")
# Out:
# [{'adult': False,
#   'backdrop_path': '/smgZYp49OB6xo4hZewxzryrh5xN.jpg',
#   'genre_ids': [35],
#   'id': 455656,
#   'original_language': 'en',
#   'original_title': '#realityhigh',
#   'overview': 'When nerdy high schooler Dani finally attracts the interest of her longtime crush, she lands in the cross hairs of his ex, a social media celebrity.',
#   'popularity': 11.151,
#   'poster_path': '/9TbjIF1p5a3EJXUFzX63Coa2JRM.jpg',
#   'release_date': '2017-07-17',
#   'title': '#realityhigh',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 935}]

# %%
df.iloc[96, 7] = get_movie_id("realityhigh", 2017)
df.iloc[96, :]
# Out:
# Title                   #REALITYHIGH
# Genre                         Comedy
# Premiere         2017-09-08 00:00:00
# Runtime                           99
# IMDB Score                       5.2
# Language                     English
# premiere_year                   2017
# tmdb_id                       455656
# Name: 96, dtype: object

# %%
df[df["tmdb_id"] == 619297]
# Out:
#             Title           Genre   Premiere  Runtime  IMDB Score Language  \
# 150    Sweet Girl          Action 2021-08-20      110         5.5  English
# 459  Sweet & Sour  Romantic drama 2021-06-04      102         6.7   Korean
#
#      premiere_year tmdb_id
# 150           2021  619297
# 459           2021  619297

# %%
get_movie_data("Sweet girl")
# Out:
# [{'adult': False,
#   'backdrop_path': '/nprqOIEfiMMQx16lgKeLf3rmPrR.jpg',
#   'genre_ids': [28],
#   'id': 619297,
#   'original_language': 'en',
#   'original_title': 'Sweet Girl',
#   'overview': "A devastated husband vows to bring justice to the people responsible for his wife's death while protecting the only family he has left, his daughter.",
#   'popularity': 296.569,
#   'poster_path': '/cP7odDzzFBD9ycxj2laTeFWGLjD.jpg',
#   'release_date': '2021-08-18',
#   'title': 'Sweet Girl',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 697},
#  {'adult': False,
#   'backdrop_path': '/cwdeWOqC0dIKphNLhjENWB7GFQd.jpg',
#   'genre_ids': [18, 27, 53],
#   'id': 407757,
#   'original_language': 'en',
#   'original_title': 'Sweet, Sweet Lonely Girl',
#   'overview': "Soon after moving in with her aging aunt Dora, Adele meets Beth, seductive and mysterious, who tests the limits of Adele's moral ground and sends her spiraling down a psychologically unstable and phantasmagoric path.",
#   'popularity': 4.341,
#   'poster_path': '/tKjdsK8JNwo8UXRMYwHq15rW5Uo.jpg',
#   'release_date': '2016-09-22',
#   'title': 'Sweet, Sweet Lonely Girl',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 34},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 422544,
#   'original_language': 'cn',
#   'original_title': '玉女凡心',
#   'overview': 'Drama from Hong Kong directed by Lee Tit.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '1952-12-24',
#   'title': "A Sweet Girl's Fancies",
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [53],
#   'id': 482363,
#   'original_language': 'cn',
#   'original_title': 'Yu nu jing hun',
#   'overview': 'Early Shaw Brothers thriller.',
#   'popularity': 0.6,
#   'poster_path': '/ejbHJDgvAMmwvL2qY8SeMKygW6n.jpg',
#   'release_date': '1958-12-31',
#   'title': 'Sweet Girl in Terror',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [27],
#   'id': 318616,
#   'original_language': 'id',
#   'original_title': 'Si manis jembatan ancol',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '1973-01-01',
#   'title': 'The Sweet Girl at Ancol Bridge',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/18uYXlTXXNJdiBRSPQONWG42bh2.jpg',
#   'genre_ids': [35],
#   'id': 413292,
#   'original_language': 'fr',
#   'original_title': 'Sweet Girls',
#   'overview': 'Elodie and Marie, two teenage girls in a city where the housing crisis worsens by the day, are faced with a lack of prospects offered by the future, and see their chances of independence gradually disappearing. Elodie and Marie suggest a solution more extreme than not; empty apartments unjustly occupied by the "old" that, in their eyes, are the origin of the current social imbalance. In this journey through the initiatory path of adolescence, they discover that behind their cold calculations, human beings are just as lost they are.',
#   'popularity': 0.687,
#   'poster_path': '/qF6VgaAdj9CkpE8sMHtextwGeZX.jpg',
#   'release_date': '2015-08-08',
#   'title': 'Sweet Girls',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 421739,
#   'original_language': 'en',
#   'original_title': 'Sweet Girls',
#   'overview': 'A man sits with two women at a late night table discussing the differences between men and women, triggering polarizing reactions as all three become increasingly intoxicated.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2012-11-15',
#   'title': 'Sweet Girls',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/6S4XEhUekP7sjTPugAXmsa29jY1.jpg',
#   'genre_ids': [35, 18],
#   'id': 171208,
#   'original_language': 'fr',
#   'original_title': "Le viol d'une jeune fille douce",
#   'overview': 'When a sexually promiscuous young woman finds herself pregnant and unmarried her three brothers vow to find the man responsible and punish him for what they consider the rape of their sister.',
#   'popularity': 1.505,
#   'poster_path': '/avkdouay8jHdUOwEeFlcuP99dzb.jpg',
#   'release_date': '1968-05-26',
#   'title': 'The Rape of a Sweet Young Girl',
#   'video': False,
#   'vote_average': 5,
#   'vote_count': 6}]

# %%
get_movie_data("Sweet & sour")
# Out:
# [{'adult': False,
#   'backdrop_path': '/nprqOIEfiMMQx16lgKeLf3rmPrR.jpg',
#   'genre_ids': [28],
#   'id': 619297,
#   'original_language': 'en',
#   'original_title': 'Sweet Girl',
#   'overview': "A devastated husband vows to bring justice to the people responsible for his wife's death while protecting the only family he has left, his daughter.",
#   'popularity': 296.569,
#   'poster_path': '/cP7odDzzFBD9ycxj2laTeFWGLjD.jpg',
#   'release_date': '2021-08-18',
#   'title': 'Sweet Girl',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 697},
#  {'adult': False,
#   'backdrop_path': '/5A3c0R5L2CUY4Dj9VJkm4zdFG7H.jpg',
#   'genre_ids': [10751, 35],
#   'id': 654974,
#   'original_language': 'en',
#   'original_title': 'Home Sweet Home Alone',
#   'overview': 'After being left at home by himself for the holidays, 10-year-old Max Mercer must work to defend his home from a married couple who tries to steal back a valuable heirloom.',
#   'popularity': 72.759,
#   'poster_path': '/fP3VvqUjEBjawxZHL4sYCq2ZdJD.jpg',
#   'release_date': '2021-11-12',
#   'title': 'Home Sweet Home Alone',
#   'video': False,
#   'vote_average': 4.3,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/lDtmwXg6nknzViEQ5SDkk4D1WEZ.jpg',
#   'genre_ids': [18, 10749],
#   'id': 1921,
#   'original_language': 'en',
#   'original_title': 'Sweet November',
#   'overview': 'Nelson is a man devoted to his advertising career in San Francisco. One day, while taking a driving test at the DMV, he meets Sara. She is very different from the other women in his life. Nelson causes her to miss out on taking the test and later that day she tracks him down. One thing leads to another and Nelson ends up living with her through a November that will change his life forever.',
#   'popularity': 14.615,
#   'poster_path': '/3biEHZSBSYqSkawU2sQyNbLcjgE.jpg',
#   'release_date': '2001-02-16',
#   'title': 'Sweet November',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 1001},
#  {'adult': False,
#   'backdrop_path': '/xE0ouu4yVA4fBojdHg2UkfvRxY4.jpg',
#   'genre_ids': [35, 10749],
#   'id': 11529,
#   'original_language': 'en',
#   'original_title': 'Sweet Home Alabama',
#   'overview': "New York fashion designer, Melanie Carmichael suddenly finds herself engaged to the city's most eligible bachelor. But her past holds many secrets—including Jake, the redneck husband she married in high school, who refuses to divorce her. Bound and determined to end their contentious relationship once and for all, Melanie sneaks back home to Alabama to confront her past.",
#   'popularity': 13.197,
#   'poster_path': '/698cbxq0SRwCdOPG5Bwi7JDk12d.jpg',
#   'release_date': '2002-09-26',
#   'title': 'Sweet Home Alabama',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 1175},
#  {'adult': False,
#   'backdrop_path': '/erJ1Fz0TqGtItrhMgb3jmvG4OJW.jpg',
#   'genre_ids': [9648, 35, 18],
#   'id': 1559,
#   'original_language': 'en',
#   'original_title': 'Sweet Movie',
#   'overview': 'The winner of the Miss World Virginity contest marries, escapes from her masochistic husband and ends up involved in a world of debauchery.',
#   'popularity': 7.681,
#   'poster_path': '/vMdeO3ebJGyfkK0PKtwNQiSaS8G.jpg',
#   'release_date': '1974-06-12',
#   'title': 'Sweet Movie',
#   'video': False,
#   'vote_average': 5.4,
#   'vote_count': 89},
#  {'adult': False,
#   'backdrop_path': '/kYDIQ6GSnHStMWUdCYwpmBcXtcm.jpg',
#   'genre_ids': [18, 35],
#   'id': 276839,
#   'original_language': 'en',
#   'original_title': 'Home Sweet Hell',
#   'overview': 'Mona and Don’s seemingly perfect suburban bliss is disrupted by a sexy extortionist and Mona will stop at nothing, including killing the competition, to keep her little slice of heaven.',
#   'popularity': 11.313,
#   'poster_path': '/nitkxCmZ6RiJjHJPxmP4LJSKP4j.jpg',
#   'release_date': '2015-03-13',
#   'title': 'Home Sweet Hell',
#   'video': False,
#   'vote_average': 5.4,
#   'vote_count': 367},
#  {'adult': False,
#   'backdrop_path': '/AmsqqWm48D3x7wCXtsJjehjxEg4.jpg',
#   'genre_ids': [35, 18, 10402],
#   'id': 9684,
#   'original_language': 'en',
#   'original_title': 'Sweet and Lowdown',
#   'overview': 'A comedic biopic focused on the life of fictional jazz guitarist Emmett Ray. Ray was an irresponsible, free-spending, arrogant, obnoxious, alcohol-abusing, miserable human being, who was also arguably the best guitarist in the world.',
#   'popularity': 8.087,
#   'poster_path': '/23S5qa8j3ajYnERcYCqMLfSeOvw.jpg',
#   'release_date': '1999-12-03',
#   'title': 'Sweet and Lowdown',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 353},
#  {'adult': False,
#   'backdrop_path': '/eWZQ2IkBHfltHKUylRyMF5tWzy2.jpg',
#   'genre_ids': [18, 53],
#   'id': 413992,
#   'original_language': 'en',
#   'original_title': 'Sweet Virginia',
#   'overview': 'A former rodeo star, now a motel manager, meets a young man who is responsible for the violence that suddenly has seized his small town.',
#   'popularity': 8.229,
#   'poster_path': '/qTch1l0ZMU4MiOBDEJ14jVmANVC.jpg',
#   'release_date': '2017-11-17',
#   'title': 'Sweet Virginia',
#   'video': False,
#   'vote_average': 5.9,
#   'vote_count': 219},
#  {'adult': False,
#   'backdrop_path': '/o0FHzs3tTqRhiBxQ6qYNlhyXydh.jpg',
#   'genre_ids': [27],
#   'id': 328252,
#   'original_language': 'es',
#   'original_title': 'Sweet Home',
#   'overview': 'A couple decides to spend a romantic evening in a floor of a semi-abandoned building that slip because she works as a consultant for the council house and got the keys. During the evening they discover that a hooded murderer is the only tenant left in the building...and they have become the new target.',
#   'popularity': 8.157,
#   'poster_path': '/2tdfWey5HoXmgM0hdXsJWGbxfR1.jpg',
#   'release_date': '2015-05-08',
#   'title': 'Sweet Home',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 100},
#  {'adult': False,
#   'backdrop_path': '/oOhTBPEzabcSg7HvGLkydIYO1ey.jpg',
#   'genre_ids': [35, 18],
#   'id': 36843,
#   'original_language': 'en',
#   'original_title': 'Life Is Sweet',
#   'overview': "Just north of London live Wendy, Andy, and their twenty-something twins, Natalie and Nicola. Wendy clerks in a shop, leads aerobics at a primary school, jokes like a vaudevillian, agrees to waitress at a friend's new restaurant and dotes on Andy, a cook who forever puts off home remodeling projects, and with a drunken friend, buys a broken down lunch wagon. Natalie, with short neat hair and a snappy, droll manner, is a plumber; she has a holiday planned in America, but little else. Last is Nicola, odd man out: a snarl, big glasses, cigarette, mussed hair, jittery fingers, bulimic, jobless, and unhappy. How they interact and play out family conflict and love is the film's subject.",
#   'popularity': 8.375,
#   'poster_path': '/zdkKNQzzwyciP9vAohAPFZdujlA.jpg',
#   'release_date': '1990-11-15',
#   'title': 'Life Is Sweet',
#   'video': False,
#   'vote_average': 7,
#   'vote_count': 112},
#  {'adult': False,
#   'backdrop_path': '/xpdXXd5i1IN7d4eOhqAreApobxT.jpg',
#   'genre_ids': [80, 18],
#   'id': 1376,
#   'original_language': 'en',
#   'original_title': 'Sweet Sixteen',
#   'overview': 'Determined to have a normal family life once his mother gets out of prison, a Scottish teenager from a tough background sets out to raise the money for a home.',
#   'popularity': 5.786,
#   'poster_path': '/p5h50WEZQ4pRFffnSULqL4cEuLp.jpg',
#   'release_date': '2002-09-07',
#   'title': 'Sweet Sixteen',
#   'video': False,
#   'vote_average': 7,
#   'vote_count': 140},
#  {'adult': False,
#   'backdrop_path': '/5R5O1IkKz4Otrhax39AwYRPkh1h.jpg',
#   'genre_ids': [18, 36, 37],
#   'id': 468210,
#   'original_language': 'en',
#   'original_title': 'Sweet Country',
#   'overview': 'It’s 1929 on the vast, desert-like, Eastern Arrernte Nation lands that are now known as the Central Australian outback. Sam Kelly, a middle-aged Aboriginal man, works the land of a kind preacher, Fred Smith. After an ill-tempered bully arrives in town and Kelly kills him in self-defence, he and his wife go on the run as a posse gathers to hunt him down.',
#   'popularity': 6.2,
#   'poster_path': '/szJdZCSiEIYybmPymoP2UTEvOUC.jpg',
#   'release_date': '2018-01-25',
#   'title': 'Sweet Country',
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 128},
#  {'adult': False,
#   'backdrop_path': '/nC8u2U0YpmFOzJjbQaCt5NwbkGQ.jpg',
#   'genre_ids': [18],
#   'id': 976,
#   'original_language': 'en',
#   'original_title': 'Sweet Smell of Success',
#   'overview': "New York City newspaper writer J.J. Hunsecker holds considerable sway over public opinion with his Broadway column, but one thing that he can't control is his younger sister, Susan, who is in a relationship with aspiring jazz guitarist Steve Dallas. Hunsecker strongly disapproves of the romance and recruits publicist Sidney Falco to find a way to split the couple, no matter how ruthless the method.",
#   'popularity': 11.003,
#   'poster_path': '/4SzW8u7avVczndyR3UbU87ZpE0V.jpg',
#   'release_date': '1957-07-04',
#   'title': 'Sweet Smell of Success',
#   'video': False,
#   'vote_average': 7.7,
#   'vote_count': 299},
#  {'adult': False,
#   'backdrop_path': '/cwdeWOqC0dIKphNLhjENWB7GFQd.jpg',
#   'genre_ids': [18, 27, 53],
#   'id': 407757,
#   'original_language': 'en',
#   'original_title': 'Sweet, Sweet Lonely Girl',
#   'overview': "Soon after moving in with her aging aunt Dora, Adele meets Beth, seductive and mysterious, who tests the limits of Adele's moral ground and sends her spiraling down a psychologically unstable and phantasmagoric path.",
#   'popularity': 4.341,
#   'poster_path': '/tKjdsK8JNwo8UXRMYwHq15rW5Uo.jpg',
#   'release_date': '2016-09-22',
#   'title': 'Sweet, Sweet Lonely Girl',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 34},
#  {'adult': False,
#   'backdrop_path': '/aotEcxMNnWMSNH2XlCxgTwWovRc.jpg',
#   'genre_ids': [18],
#   'id': 10217,
#   'original_language': 'en',
#   'original_title': 'The Sweet Hereafter',
#   'overview': "A small mountain community in Canada is devastated when a school bus accident leaves more than a dozen of its children dead. A big-city lawyer arrives to help the survivors' and victims' families prepare a class-action suit, but his efforts only seem to push the townspeople further apart. At the same time, one teenage survivor of the accident has to reckon with the loss of innocence brought about by a different kind of damage.",
#   'popularity': 7.361,
#   'poster_path': '/gJy7LMq4b5qO5fsSUSoBgm24BHf.jpg',
#   'release_date': '1997-09-25',
#   'title': 'The Sweet Hereafter',
#   'video': False,
#   'vote_average': 7,
#   'vote_count': 271},
#  {'adult': False,
#   'backdrop_path': '/s9dtUJOxWFVjlyvbRvtJVJWv0Mm.jpg',
#   'genre_ids': [35, 18, 10402, 10749],
#   'id': 42618,
#   'original_language': 'en',
#   'original_title': 'Sweet Charity',
#   'overview': 'Taxi dancer, Charity continues to have faith in the human race despite apparently endless disappointments at its hands, and hope that she will finally meet the nice young man to romance her away from her sleazy life.',
#   'popularity': 4.552,
#   'poster_path': '/2UUd14BiK7sNRakOqxGR1lr9xbQ.jpg',
#   'release_date': '1969-02-25',
#   'title': 'Sweet Charity',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 49},
#  {'adult': False,
#   'backdrop_path': '/q2FFDzyz7TYXMGQsPC4xnn0Ox66.jpg',
#   'genre_ids': [18, 27, 9648],
#   'id': 10299,
#   'original_language': 'en',
#   'original_title': 'Hush... Hush, Sweet Charlotte',
#   'overview': 'An aging, reclusive Southern belle plagued by a horrifying family secret descends into madness after the arrival of a lost relative.',
#   'popularity': 6.901,
#   'poster_path': '/hwVGNaVXFblluLwUjGcJ7RgW1rV.jpg',
#   'release_date': '1964-12-15',
#   'title': 'Hush... Hush, Sweet Charlotte',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 174},
#  {'adult': False,
#   'backdrop_path': '/4lk8qws6n3nC3RsJqxzqVK3pjzm.jpg',
#   'genre_ids': [18, 10749],
#   'id': 31048,
#   'original_language': 'en',
#   'original_title': 'Sweet Land',
#   'overview': 'Set in 1920, Inge travels from Germany to rural Minnesota in order to meet the man destined to be her husband.',
#   'popularity': 3.79,
#   'poster_path': '/qYxbJ0pWyuRBqVXrrhaDQnFAsNN.jpg',
#   'release_date': '2005-10-21',
#   'title': 'Sweet Land',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 34},
#  {'adult': False,
#   'backdrop_path': '/w3HmBVzzawXuLmZzbs2jEh5TdVE.jpg',
#   'genre_ids': [28, 18, 80],
#   'id': 5822,
#   'original_language': 'en',
#   'original_title': "Sweet Sweetback's Baadasssss Song",
#   'overview': 'After saving a Black Panther from some racist cops, a black male prostitute goes on the run from "the man" with the help of the ghetto community and some disillusioned Hells Angels.',
#   'popularity': 4.991,
#   'poster_path': '/b8WohfEVW6nCnHBlQGXmXmSJJhW.jpg',
#   'release_date': '1971-04-23',
#   'title': "Sweet Sweetback's Baadasssss Song",
#   'video': False,
#   'vote_average': 5.4,
#   'vote_count': 65},
#  {'adult': False,
#   'backdrop_path': '/dR7NcWkMF2LkiMCR0oOjvec84SG.jpg',
#   'genre_ids': [80, 18, 9648, 53],
#   'id': 1834,
#   'original_language': 'en',
#   'original_title': 'Murder, My Sweet',
#   'overview': "Gumshoe Philip Marlowe is hired by the oafish Moose Malloy to track down his former girlfriend. He's also hired to accompany an effeminate playboy buy back some jewels. When the exchange results in the playboy's murder, Marlowe can't leave the case alone, and soon discovers it's related to Malloy's. As he gets drawn deeper into a complex web of intrigue by a mysterious blonde, the detective finds his own life in increasing jeopardy.",
#   'popularity': 6.522,
#   'poster_path': '/tbyzfN1AUKTvzh058L9ZcOpS9Vn.jpg',
#   'release_date': '1944-12-14',
#   'title': 'Murder, My Sweet',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 149}]

# %%
df.iloc[459, 7] = 662237
df.iloc[459, :]
# Out:
# Title                   Sweet & Sour
# Genre                 Romantic drama
# Premiere         2021-06-04 00:00:00
# Runtime                          102
# IMDB Score                       6.7
# Language                      Korean
# premiere_year                   2021
# tmdb_id                       662237
# Name: 459, dtype: object

# %%
df[df["tmdb_id"] == 726940]
# Out:
#                                   Title      Genre   Premiere  Runtime  \
# 321  Octonauts & the Caves of Sac Actun  Animation 2020-08-14       72
# 604  Octonauts & the Great Barrier Reef  Animation 2020-10-13       47
#
#      IMDB Score Language  premiere_year tmdb_id
# 321         6.2  English           2020  726940
# 604         7.3  English           2020  726940

# %%
get_movie_data("Octonauts & the Caves of Sac Actun")
# Out:
# [{'adult': False,
#   'backdrop_path': '/zG4dbBx3oO37yBkmLCiG81FxAzW.jpg',
#   'genre_ids': [10751, 16],
#   'id': 726940,
#   'original_language': 'en',
#   'original_title': 'Octonauts and the Caves of Sac Actun',
#   'overview': 'The Octonauts embark on an underwater adventure, navigating a set of challenging caves to help a small octopus friend return to the Caribbean Sea.',
#   'popularity': 11.584,
#   'poster_path': '/wlizMbZByBYPOC4i2AN64e4W1iM.jpg',
#   'release_date': '2020-08-14',
#   'title': 'Octonauts and the Caves of Sac Actun',
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 23},
#  {'adult': False,
#   'backdrop_path': '/gXNXD1eou71RWNUQx37bUbjbPmA.jpg',
#   'genre_ids': [10751, 16],
#   'id': 765684,
#   'original_language': 'en',
#   'original_title': 'Octonauts: The Ring of Fire',
#   'overview': 'In this film\'s adventure, a volcano erupts suddenly, suddenly awakening the Pacific Ocean floor of hundreds of volcanoes composed of the "ring of fire", this sudden event quickly turned into a global catastrophe.  The volcanic clusters that are about to erupt en masse threaten the horned whales washed ashore by the tsunami, the cap penguins living in the volcanic islands, the equipment of the small column maintenance station, the food planted by plant fish in the marine farms... Not to mention the plants and animals that live in the crater all year after year!',
#   'popularity': 4.305,
#   'poster_path': '/ieurcC0j9nput2aGiKcbDor0kk.jpg',
#   'release_date': '2021-01-08',
#   'title': 'Octonauts: The Ring of Fire',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/qZS1HLXhr0sQrBY7HSYeaHREqKD.jpg',
#   'genre_ids': [10751, 10402, 16],
#   'id': 752885,
#   'original_language': 'en',
#   'original_title': 'Octonauts and the Great Barrier Reef',
#   'overview': "In this musical special, the Octonauts must find a way to hold back hungry swarms of coral-eating starfish to save a new friend's fragile reef home.",
#   'popularity': 2.079,
#   'poster_path': '/gBIGXzrbzIANnYdPA1yqsRJ3lyG.jpg',
#   'release_date': '2020-11-12',
#   'title': 'Octonauts and the Great Barrier Reef',
#   'video': False,
#   'vote_average': 10,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 139709,
#   'original_language': 'en',
#   'original_title': 'Octonauts Meet the Octonauts',
#   'overview': 'The Octonauts follows a team of adventure heroes who dive right into action whenever there is trouble under the sea. In a fleet of amazing aquatic vehicles, the Octonauts explore incredible new underwater worlds, rescue wonderful sea creatures, and often save the day before returning safely home to the Octopod. Under the leadership of Captain Barnacles Bear, closely flanked by Lieutenant Kwazii Cat and Medic Peso Penguin, the Octonauts are always ready to embark on an exciting new mission!',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2011-02-09',
#   'title': 'Octonauts Meet the Octonauts',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 163760,
#   'original_language': 'en',
#   'original_title': 'Octonauts - Here Come the Octonauts',
#   'overview': 'The Octonauts follows a team of animated adventure heroes who dive into action whenever there is trouble under the sea. In a fleet of aquatic vehicles, they rescue amazing sea creatures, explore incredible new underwater worlds, and often save the day before returning safely to their home base, the Octopod.  Buoyed by the companionship of three leading characters – Captain Barnacles Bear, Lieutenant Kwazii Cat, and Medic Peso Penguin – the Octonauts are always ready to embark on an exciting new mission! The show will arouse their curiosity and feed their imagination, answering questions in a journey of discovery through the world’s oceans.  This DVD features eight episodes, each with a running time of 11 minutes.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'title': 'Octonauts - Here Come the Octonauts',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 467850,
#   'original_language': 'en',
#   'original_title': 'Octonauts - Season4',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': '/h2pgkTS09uGM338KZgxlkKcM1ZF.jpg',
#   'release_date': '2017-06-01',
#   'title': 'Octonauts - Season4',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [16],
#   'id': 405462,
#   'original_language': 'ko',
#   'original_title': 'The Octonauts',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': '/7xSHsF2lTWqOkE0LwrojmKvrpag.jpg',
#   'release_date': '2015-02-05',
#   'title': 'The Octonauts',
#   'video': True,
#   'vote_average': 8,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 139710,
#   'original_language': 'en',
#   'original_title': "Octonauts - Jumpin' Jellyfish",
#   'overview': 'Equipped with a fleet of aquatic vehicles, the Octonauts rescue amazing sea creatures, explore incredible underwater worlds, and often save the day before returning safely to their home base, the Octopod.  In these episodes Peso gets trapped inside a giant Comb Jelly;  Shellington gets trapped in the middle of a massive jellyfish bloom, and the team try to reunite a seahorse with its missing mate.  Includes 7 action packed adventures!  * The Seahorse Tale  * The Oarfish  * The Giant Comb Jelly  * The Combtooth Blenny  * The Cookiecutter Sharks  * The Jellyfish Bloom  * The Baby Dolphin',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2012-05-09',
#   'title': "Octonauts - Jumpin' Jellyfish",
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/30EUjecU9y9rOlnDCRORhvC86Kl.jpg',
#   'genre_ids': [10751],
#   'id': 531638,
#   'original_language': 'en',
#   'original_title': 'Octonauts - Crocodiles & Crabs',
#   'overview': "Dive into adventure with your favorite underwater explorers, the Octonauts! Join brave Captain Barnacles, daredevil ex-pirate, Kwazii and medic Peso Penguin, along with the other Octonauts as they explore the world s oceans, rescue the creatures who live there and protect their habitats above and below the waves! On this exciting DVD, join the Octonauts as they must figure out how to get a gigantic saltwater crocodile back to his warm water home without anyone getting chomped by him! Peso and Tweak try to remove a stuck Hermit Crab from its shell. Kwazii covets the treasure in a sunken pirate ship - but it's protected by slime-squirting Slime Eels! Enjoy these adventures and more with the Octonauts!",
#   'popularity': 0.6,
#   'poster_path': '/7QaEFVmpcMxYnoAWYoIcUsGXBpF.jpg',
#   'release_date': '2015-05-19',
#   'title': 'Octonauts - Crocodiles & Crabs',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530591,
#   'original_language': 'en',
#   'original_title': 'Octonauts Amazon Adventure',
#   'overview': 'Captain Barnacles Bear, Lieutenant Kwazii Cat, Medic Peso Penguin and the crew head off an adventure to the deepest, darkest depths of the Amazon River in search of a hidden city full of treasure.',
#   'popularity': 0.6,
#   'poster_path': '/8X5fpuZrMjSB09mOob2Bvru2LBB.jpg',
#   'release_date': '2014-02-01',
#   'title': 'Octonauts Amazon Adventure',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530598,
#   'original_language': 'en',
#   'original_title': 'Octonauts Flappity Flippers!',
#   'overview': 'Medic Peso Penguin isn’t fond of scary situations, but if someone is hurt or in trouble he can be the bravest Octonaut of all. Only Peso can save the day when a cone snail invades the Octopod and picks off the crew one by one with its dangerous harpoons. In other episodes the Octonauts enlist an undersea detective to find Peso’s missing patient, and recruit a shape-shifting mimic octopus to recover some important medicine.',
#   'popularity': 0.6,
#   'poster_path': '/xLdHh0WLbW31YBqqKoNH5j5QR8O.jpg',
#   'release_date': '2015-07-01',
#   'title': 'Octonauts Flappity Flippers!',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/acp8iZgEwYnDLNzNc2PdTvM0gvd.jpg',
#   'genre_ids': [16, 10751],
#   'id': 528565,
#   'original_language': 'en',
#   'original_title': 'Octonauts - 15 Underwater Adventures',
#   'overview': 'Beluga Whales, Lost Sea Star, Dolphin Reef Rescue, Seahorse Tale, Crafty Cuttlefish, Baby Dolphin, Manta Rays, Damselfish, Lionfish, Cone Snail, Hammerhead Sharks, Albino Humpback Whale, Enormous Elephant, Sardine School, Mixed Up Whales',
#   'popularity': 0.6,
#   'poster_path': '/z1REZlf68oHQAgtpBFmvIl3FFly.jpg',
#   'release_date': '2016-10-25',
#   'title': 'Octonauts - 15 Underwater Adventures',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 265920,
#   'original_language': 'en',
#   'original_title': 'Octonauts (To the Gup-X!)',
#   'overview': 'Join the crew in a exciting adventure, rescue the creatures & protect the enviorment! Go Octonauts!',
#   'popularity': 0.6,
#   'poster_path': None,
#   'title': 'Octonauts (To the Gup-X!)',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530608,
#   'original_language': 'en',
#   'original_title': 'Octonauts Ready For Action',
#   'overview': 'Follow Captain Barnacles and his fellow Octonauts on their missions under the sea.  In these episodes the Octonauts explore the deepest part of the ocean – The Midnight Zone, Kwazii’s GUP-B goes missing, and the Octopod gets caught in the Arctic.  Includes 7 episodes plus learn more about marine life in the 7 creature reports!',
#   'popularity': 0.6,
#   'poster_path': '/25Mvfs5kIjKsP17z0g3cUpxo5uP.jpg',
#   'release_date': '2012-01-03',
#   'title': 'Octonauts Ready For Action',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530592,
#   'original_language': 'en',
#   'original_title': 'Octonauts Calling All Gups',
#   'overview': 'With Captain Barnacles, Kwazii, Peso and the rest of the Octonauts crew every day is an exciting opportunity to embark on a new mission! In these episodes Kwazii explores a pirate shipwreck in search of a mythical sword, Barnacles struggles to free his paw from the mouth of a giant clam and the Octonauts must figure out how to rescue a gigantic saltwater crocodile from freezing waters. Episodes: Porcupine Puffer, Scared Sperm Whale, Long Arm Squid, Swashbuckling Swordfish, Manatees, Saltwater Crocodile, Humphead Parrotfish.',
#   'popularity': 0.6,
#   'poster_path': '/mpuFVEexbUtPEGA7IrJ4wCf8xiu.jpg',
#   'release_date': '2014-06-11',
#   'title': 'Octonauts Calling All Gups',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530603,
#   'original_language': 'en',
#   'original_title': 'Octonauts Shover Me Whiskers',
#   'overview': 'Equipped with a fleet of aquatic vehicles, the Octonauts rescue amazing sea creatures, explore incredible underwater worlds, and often save the day before returning safely to their home base, the octopod. In these episodes Kwazii tries to uncover his grandfather’s golden spyglass, Peso looks after an enormous elephant seal, and the crew team up with some playful dolphins to help revive a sick coral reef.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '',
#   'title': 'Octonauts Shover Me Whiskers',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530605,
#   'original_language': 'en',
#   'original_title': 'Octonauts Shiver Me Whiskers',
#   'overview': 'Equipped with a fleet of aquatic vehicles, the Octonauts rescue amazing sea creatures, explore incredible underwater worlds, and often save the day before returning safely to their home base, the octopod. In these episodes Kwazii tries to uncover his grandfather’s golden spyglass, Peso looks after an enormous elephant seal, and the crew team up with some playful dolphins to help revive a sick coral reef.',
#   'popularity': 0.6,
#   'poster_path': '/fM1uemCz9G7sRn3YwocgZ3E9NID.jpg',
#   'release_date': '2013-06-03',
#   'title': 'Octonauts Shiver Me Whiskers',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 544671,
#   'original_language': 'en',
#   'original_title': 'Octonauts: Calling All Sharks',
#   'overview': 'Dive into adventures with your favorite underwater explorers, the Octonauts! Join brave Captain Barnacles, daredevil ex-pirate Kwazii, and medic Peso Penguin, along with other Octonauts as they explore the world s oceans, rescue the creatures who live there, and protect their habitats above and below the waves! On this exciting DVD, join the Octonauts aboard the Octopod as they come face to face with a trio of pesky Cookiecutter Sharks, look after an injured Lemon Shark and stop a Whitetip Shark who is chasing the Gup-A!',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2014-06-24',
#   'title': 'Octonauts: Calling All Sharks',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530609,
#   'original_language': 'en',
#   'original_title': 'Octonauts Sound the Octoalert!',
#   'overview': 'Following the motto Explore Rescue Protect, the Octonauts dive into action whenever there is trouble under the sea.  In these episodes the Octonauts stake out a thief, Peso’s little brother Pinto comes to visit, and the team use music to rescue a pod of beluga whales.  Includes 7 missions  The Hermit Crabs  The Mixed Up Whales  The Kelp Forest Rescue  The Decorator Crab  The Beluga Whales  The Hungry Pilot Fish  The Vampire Squid  Plus: Find out more about the creatures under the sea with the 7 creature reports',
#   'popularity': 0.6,
#   'poster_path': '/scLiomKwqnHhQXJjF9325ZjpgWF.jpg',
#   'release_date': '2012-06-12',
#   'title': 'Octonauts Sound the Octoalert!',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 530593,
#   'original_language': 'en',
#   'original_title': 'Octonauts Deep Sea Adventures',
#   'overview': 'Tweak has designed a brand-new Deep Sea Station to study the deepest, darkest reaches of the ocean. What prehistoric creatures will the Octonauts discover once they get there? In other episodes the Octonauts must save a huge herd of sea pigs, a timid sperm whale helps free Peso from a giant clam, and Dashi comes to the rescue of Kwazii in the new Octo Max Suit! Dive into action with the Octonauts in these',
#   'popularity': 0.6,
#   'poster_path': '/80fp22N5y0KKKFODqgkhjkSYhHq.jpg',
#   'release_date': '2014-03-09',
#   'title': 'Octonauts Deep Sea Adventures',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0}]

# %%
df.iloc[604, 7] = 752885
df.iloc[604, :]
# Out:
# Title            Octonauts & the Great Barrier Reef
# Genre                                     Animation
# Premiere                        2020-10-13 00:00:00
# Runtime                                          47
# IMDB Score                                      7.3
# Language                                    English
# premiere_year                                  2020
# tmdb_id                                      752885
# Name: 604, dtype: object

# %%
df[df["tmdb_id"] == 384521]
# Out:
#                        Title                    Genre   Premiere  Runtime  \
# 11                   Paradox  Musical/Western/Fantasy 2018-03-23       73
# 163  The Cloverfield Paradox          Science fiction 2018-02-04      102
#
#      IMDB Score Language  premiere_year tmdb_id
# 11          3.9  English           2018  384521
# 163         5.5  English           2018  384521

# %%
get_movie_data("Paradox")
# Out:
# [{'adult': False,
#   'backdrop_path': '/iSLXnEeZpkZQnxeCzp9ZjdhvAKK.jpg',
#   'genre_ids': [878, 16, 28, 12],
#   'id': 183011,
#   'original_language': 'en',
#   'original_title': 'Justice League: The Flashpoint Paradox',
#   'overview': 'The Flash finds himself in a war-torn alternate timeline and teams up with alternate versions of his fellow heroes to restore the timeline.',
#   'popularity': 37.478,
#   'poster_path': '/zmpE3mfhv0NOnI872q66kuuGeZW.jpg',
#   'release_date': '2013-07-30',
#   'title': 'Justice League: The Flashpoint Paradox',
#   'video': False,
#   'vote_average': 7.9,
#   'vote_count': 1341},
#  {'adult': False,
#   'backdrop_path': '/lWrmOhS5WH1650mHJhwcm91jQZR.jpg',
#   'genre_ids': [27, 878, 28, 53],
#   'id': 384521,
#   'original_language': 'en',
#   'original_title': 'The Cloverfield Paradox',
#   'overview': 'Orbiting above a planet on the brink of war, scientists test a device to solve an energy crisis and end up face-to-face with a dark alternate reality.',
#   'popularity': 21.134,
#   'poster_path': '/vJi2ExTcWdJR3150VPKqqtdGxsT.jpg',
#   'release_date': '2018-02-04',
#   'title': 'The Cloverfield Paradox',
#   'video': False,
#   'vote_average': 5.6,
#   'vote_count': 2533},
#  {'adult': False,
#   'backdrop_path': '/krVz3auuoUIYwzl4D2bTqu4x2Rt.jpg',
#   'genre_ids': [28, 878],
#   'id': 376292,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': 'A group of scientists are experimenting with time travel, and they manage to send one of their group ahead in time one hour. But when he comes back, he tells them that they’ll all be dead within the next hour unless they shut the machine down.',
#   'popularity': 5.461,
#   'poster_path': '/nkjDIxzRwFMDvANnpdEIcT4whQe.jpg',
#   'release_date': '2016-04-22',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 4.5,
#   'vote_count': 81},
#  {'adult': False,
#   'backdrop_path': '/rl1pthA40hap00HhBkj5SFdjlsS.jpg',
#   'genre_ids': [878, 53],
#   'id': 51239,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': 'Homicide detective Sean Nault, a cop on a parallel Earth whose technology is powered exclusively by magic. Sean investigates a baffling series of murders committed by a means he\'s never seen before: science. With the aid of Lenoir, a member of the ridiculed subculture of "pragmatists" who believe science is more than the stuff of myths &amp; children\'s stories, and the 130-year-old sorcerer Winston Churchill, Sean uncovers an ominous plot that will lead him to another dimension and the realization that, unless he prevents it, both earths could well be destroyed.',
#   'popularity': 4.546,
#   'poster_path': '/aYR9jDH3fFTdPVreFKfaavTCscn.jpg',
#   'release_date': '2010-01-01',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 4.5,
#   'vote_count': 11},
#  {'adult': False,
#   'backdrop_path': '/xWZrhF5RvBJvDhtCjf3FRtDmnc.jpg',
#   'genre_ids': [10402, 37],
#   'id': 502140,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': 'A loud Poem. A whimsical western tale of music and love.',
#   'popularity': 3.332,
#   'poster_path': '/bEvWTCEZUIqSJ12n4mOVAxid0x3.jpg',
#   'release_date': '2018-03-15',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 3.4,
#   'vote_count': 12},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878, 18, 10749],
#   'id': 370834,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': 'After his wife is killed in a hit-and-run accident by a mysterious Hooded Man, Theoretical Physicist Dylan Brandt builds a Quantum Suicide Machine to jump through parallel universes to find another version of his wife. Based on the ancient Greek myth of Orpheus and Eurydice, where a man storms of the Gates of Hades to return his wife to the land of the living, Dylan transverses infinite worlds of the Multi-verse to find his wife. But with every jump, Dylan is thwarted by the efforts of the mysterious Hooded Man, until the rules of physics completely break down, threatening to destroy the universe and everything in it.',
#   'popularity': 2.708,
#   'poster_path': '/kUxBb3fHKbSvJyf0HleXBdqbKnW.jpg',
#   'release_date': '2015-12-05',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/jSlawSBQhJktzfWchFWxJzbOHhS.jpg',
#   'genre_ids': [878],
#   'id': 222305,
#   'original_language': 'en',
#   'original_title': 'Paradox Alice',
#   'overview': 'In the near future, a team is sent on a dangerous mission to Europa to retrieve and bring water back to a dying Earth. Their operation unexpectedly goes awry, jeopardizing not only the lives of those on board but also on earth, resulting in the possible extinction of the human race.',
#   'popularity': 3.146,
#   'poster_path': '/oUBBOatm4Lyo97inCkoHliX24CL.jpg',
#   'release_date': '2012-04-20',
#   'title': 'Paradox Alice',
#   'video': False,
#   'vote_average': 4.3,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878, 35, 18],
#   'id': 773081,
#   'original_language': 'en',
#   'original_title': 'Paradox Lost',
#   'overview': "Fearing he'll never be a success, Barnaby Bates, a struggling LA comedy writer, pulls away from a blossoming romantic relationship with Rose, an empathetic young photographer, in order to focus on his career. Things get complicated when he's visited by a mysterious stranger from the future who warns that the world as Barnaby knows it will soon be coming to an end.",
#   'popularity': 2.097,
#   'poster_path': '/8Ndm1REgzRBdujZNT6sBDtb3QhW.jpg',
#   'release_date': '2020-12-05',
#   'title': 'Paradox Lost',
#   'video': False,
#   'vote_average': 10,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18, 878, 53],
#   'id': 410630,
#   'original_language': 'en',
#   'original_title': "Jacob's Paradox",
#   'overview': 'In one tragic night, Quantum Physics Professor Jacob Matthews loses his wife...his everything. What he does to get her back will bring him to the edge of madness.',
#   'popularity': 0.702,
#   'poster_path': '/husq8EA7pKkvwSE7CBwRDvWNNCs.jpg',
#   'release_date': '2015-05-14',
#   'title': "Jacob's Paradox",
#   'video': False,
#   'vote_average': 7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/y0G6STU6NK6zvGR3qd1emfavsK.jpg',
#   'genre_ids': [99],
#   'id': 564024,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': "Winter of 2005 was legendary and Standard Films was there to capture every moment. Filmed on epic snow conditions and unique terrain features, Paradox is a perfect blend of freestyle and big mountain snowboarding. Witness Jeremy Jones' craziest line ever. Check out the most insane helicopter kicker footage ever caught on film. Mads Jonsson breaks the world record for the biggest air in Norway. Explore Russia's untracked big mountain first descents. Paradox isn't a dime a dozen jib flick shot on video. Paradox is snowboarding!",
#   'popularity': 0.6,
#   'poster_path': '/5uE4xtCtpwAuaw2JoBYwkkJzBp7.jpg',
#   'release_date': '2005-09-15',
#   'title': 'Paradox',
#   'video': True,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18, 27, 9648],
#   'id': 756956,
#   'original_language': 'en',
#   'original_title': 'The Klatos Paradox',
#   'overview': 'An incompetent time traveler must team up with his unpredictable alternate self, to fix a paradox which is now slowly destroying the universe.',
#   'popularity': 1.4,
#   'poster_path': '/lSiA7CLHbHMA5eidhk2QktBVgdH.jpg',
#   'release_date': '2020-10-23',
#   'title': 'The Klatos Paradox',
#   'video': False,
#   'vote_average': 5,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 647496,
#   'original_language': 'en',
#   'original_title': 'In Paradox',
#   'overview': 'While being relentlessly attacked, a Man seeks to uncover a mystery and stop the unknown memories that are controlling him, only to learn the difference between reality and illusions.',
#   'popularity': 0.96,
#   'poster_path': '/yOW6Zzd8aSdCjb41D49LDpQCVHk.jpg',
#   'release_date': '2019-11-07',
#   'title': 'In Paradox',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [9648, 53],
#   'id': 291041,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': 'A young girl finds out that she has to move. In desperation she goes to her boyfriend and convinces him to flee up in the mountains with her. But there she discovers something that changes her perception on life completely.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2012-03-01',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [53],
#   'id': 305570,
#   'original_language': 'en',
#   'original_title': 'Paradox',
#   'overview': 'Two men are stranded at the bottom of a well. One, with a serious injury to his head, thinks his has fallen in is own back garden in present-day Britain. But the other tells him they are really prisoners in a medieval dungeon. Who is right, and where are they really?',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2006-03-20',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 760230,
#   'original_language': 'fr',
#   'original_title': 'Paradox',
#   'overview': '',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2013-01-01',
#   'title': 'Paradox',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 713227,
#   'original_language': 'en',
#   'original_title': 'The Paradox',
#   'overview': 'When Kyle Paige encounters an issue that leaves him with no choice but to return home, he must confront his estranged father of 11 years.',
#   'popularity': 0.6,
#   'poster_path': '/3CmjmsXGl9Hyi6HjexxU6MU3xVC.jpg',
#   'release_date': '2019-06-17',
#   'title': 'The Paradox',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878],
#   'id': 269878,
#   'original_language': 'en',
#   'original_title': 'Paradox Mary',
#   'overview': 'Mary has a problem. And it’s right in front of her. It’s in front of everyone else too, only they haven’t recognized it yet.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2008-07-06',
#   'title': 'Paradox Mary',
#   'video': False,
#   'vote_average': 3,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 93959,
#   'original_language': 'en',
#   'original_title': 'Dark Paradox',
#   'overview': "The film follows a writer's unwitting discovery of the history and secret efforts of a cult in Victoria, Canada that has been engaged in a 60 year effort to open a portal between our world and another, letting in a host of vicious inter-dimensional beings. The city of Victoria was rumored in the 1980's to be the second worldwide 'capital of Satanism' after Geneva, Switzerland. Dark Paradox explores the idea that this myth was not only partially true but also partially inaccurate in suggesting the cult activity was 'Satanic' when in fact it was based on the worship of ancient extraterrestrial 'elder gods' in the vein of HP Lovecraft's fiction.",
#   'popularity': 0.6,
#   'poster_path': None,
#   'title': 'Dark Paradox',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18, 27],
#   'id': 372728,
#   'original_language': 'en',
#   'original_title': 'Paradox Lake',
#   'overview': 'The tale of the relationship between a camp counselor and a 12 year old autistic girl at an upstate NY summer camp for autistic children.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '2002-01-10',
#   'title': 'Paradox Lake',
#   'video': False,
#   'vote_average': 3.5,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 629368,
#   'original_language': 'en',
#   'original_title': 'Feline Paradox',
#   'overview': "A Time traveler named Paul tries to prevent his tragic misfortunes at Cynthia's new years party. His tampering with space time fixes the problem.... But the consequences are beyond catastrophic.... Paul must navigate through a belligerent world of anthropomorphic cat people to find a way to fix it....",
#   'popularity': 0.6,
#   'poster_path': None,
#   'release_date': '',
#   'title': 'Feline Paradox',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0}]

# %%
df.iloc[11, 7] = 502140
df.iloc[11, :]
# Out:
# Title                            Paradox
# Genre            Musical/Western/Fantasy
# Premiere             2018-03-23 00:00:00
# Runtime                               73
# IMDB Score                           3.9
# Language                         English
# premiere_year                       2018
# tmdb_id                           502140
# Name: 11, dtype: object

# %%
df[df["tmdb_id"] == 861604]
# Out:
#                                         Title         Genre   Premiere  \
# 492  Blood Brothers: Malcolm X & Muhammad Ali   Documentary 2021-09-09
# 559                    Ali & Ratu Ratu Queens  Comedy-drama 2021-06-17
#
#      Runtime  IMDB Score    Language  premiere_year tmdb_id
# 492       96         6.8     English           2021  861604
# 559      100         7.1  Indonesian           2021  861604

# %%
get_movie_data("Blood Brothers: Malcolm X & Muhammad Ali")
# Out:
# [{'adult': False,
#   'backdrop_path': '/8ETxVtj2apApnVZeRLUNGZaFeh.jpg',
#   'genre_ids': [99, 36],
#   'id': 861604,
#   'original_language': 'en',
#   'original_title': 'Blood Brothers: Malcolm X and Muhammad Ali',
#   'overview': "From a chance meeting to a tragic fallout, Malcolm X and Muhammad Ali's extraordinary bond cracks under the weight of distrust and shifting ideals.",
#   'popularity': 16.473,
#   'poster_path': '/kdOXdPIgbbCHXb51tWJZ0r8kZfe.jpg',
#   'release_date': '2021-09-09',
#   'title': 'Blood Brothers: Malcolm X and Muhammad Ali',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 15}]

# %%
get_movie_data("Ali & Ratu Ratu Queens")
# Out:
# [{'adult': False,
#   'backdrop_path': '/gVtm7G5NtQxjFNA5ydqxslxjCuk.jpg',
#   'genre_ids': [18],
#   'id': 8489,
#   'original_language': 'en',
#   'original_title': 'Ali',
#   'overview': "In 1964, a brash, new pro boxer, fresh from his Olympic gold medal victory, explodes onto the scene: Cassius Clay. Bold and outspoken, he cuts an entirely new image for African Americans in sport with his proud public self-confidence and his unapologetic belief that he is the greatest boxer of all time. Yet at the top of his game, both Ali's personal and professional lives face the ultimate test.",
#   'popularity': 15.221,
#   'poster_path': '/egzfj0JpgrVfpMXF4tfHpzEYM70.jpg',
#   'release_date': '2001-12-10',
#   'title': 'Ali',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 1271},
#  {'adult': False,
#   'backdrop_path': '/ll5ktqAG3EOlCS8bpyoC0kYSSe9.jpg',
#   'genre_ids': [35],
#   'id': 9298,
#   'original_language': 'en',
#   'original_title': 'Ali G Indahouse',
#   'overview': "Ali G unwittingly becomes a pawn in the evil Chancellor's plot to overthrow the Prime Minister of Great Britain. However, instead of bringing the Prime Minister down, Ali is embraced by the nation as the voice of youth and 'realness', making the Prime Minister and his government more popular than ever.",
#   'popularity': 9.967,
#   'poster_path': '/pjKvQrVpekshVM6DUDOt3ImhAVH.jpg',
#   'release_date': '2002-03-21',
#   'title': 'Ali G Indahouse',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 1015},
#  {'adult': False,
#   'backdrop_path': '/8ETxVtj2apApnVZeRLUNGZaFeh.jpg',
#   'genre_ids': [99, 36],
#   'id': 861604,
#   'original_language': 'en',
#   'original_title': 'Blood Brothers: Malcolm X and Muhammad Ali',
#   'overview': "From a chance meeting to a tragic fallout, Malcolm X and Muhammad Ali's extraordinary bond cracks under the weight of distrust and shifting ideals.",
#   'popularity': 16.473,
#   'poster_path': '/kdOXdPIgbbCHXb51tWJZ0r8kZfe.jpg',
#   'release_date': '2021-09-09',
#   'title': 'Blood Brothers: Malcolm X and Muhammad Ali',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 15},
#  {'adult': False,
#   'backdrop_path': '/aSAQv17uE2ujmh8lb4CU3mYZhZd.jpg',
#   'genre_ids': [99],
#   'id': 293262,
#   'original_language': 'en',
#   'original_title': 'I Am Ali',
#   'overview': 'Unprecedented access to Muhammad Ali\'s personal archive of "audio journals" as well as interviews and testimonials from his inner circle of family and friends are used to tell the legend\'s life story.',
#   'popularity': 5.876,
#   'poster_path': '/1sI9ogP5SXu8gTiuIIITPTjl12E.jpg',
#   'release_date': '2014-10-10',
#   'title': 'I Am Ali',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 61},
#  {'adult': False,
#   'backdrop_path': '/bGY3ec44F0cuA8UUzhNrA7xxGJq.jpg',
#   'genre_ids': [99],
#   'id': 30966,
#   'original_language': 'en',
#   'original_title': 'Facing Ali',
#   'overview': "Ten of Muhammad Ali's former rivals pay tribute to the three-time world heavyweight champion.",
#   'popularity': 4.587,
#   'poster_path': '/7az2mwUqVj5AeXP4HScgln3EALM.jpg',
#   'release_date': '2009-05-29',
#   'title': 'Facing Ali',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 34},
#  {'adult': False,
#   'backdrop_path': '/1azCtqaPngV36ikwBNrZYqGb0OW.jpg',
#   'genre_ids': [35],
#   'id': 17856,
#   'original_language': 'en',
#   'original_title': 'Ali G, Aiii',
#   'overview': 'Clips from Da Ali G Show with unaired sketches from the show.',
#   'popularity': 5.992,
#   'poster_path': '/dts9V7MhbhOKzcZIm3V5SA71KPm.jpg',
#   'release_date': '2000-11-20',
#   'title': 'Ali G, Aiii',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 54},
#  {'adult': False,
#   'backdrop_path': '/r5GXidBpKAqpzMzFTfBIxIqXlAO.jpg',
#   'genre_ids': [18, 10749],
#   'id': 371741,
#   'original_language': 'en',
#   'original_title': 'Ali and Nino',
#   'overview': 'Muslim prince Ali and Georgian aristocrat Nino have grown up in the Russian province of Azerbaijan. Their tragic love story sees the outbreak of the First World War and the world’s struggle for Baku’s oil. Ultimately they must choose to fight for their country’s independence or for each other.',
#   'popularity': 3.874,
#   'poster_path': '/k678ohrP2DcfgElWZl2mxdO3vEd.jpg',
#   'release_date': '2016-01-27',
#   'title': 'Ali and Nino',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 52},
#  {'adult': False,
#   'backdrop_path': '/2Etv8zkZTUekWFkmksdBeCddpBO.jpg',
#   'genre_ids': [35],
#   'id': 396292,
#   'original_language': 'en',
#   'original_title': 'Ali Wong: Baby Cobra',
#   'overview': 'Ali Wong might be seven-months pregnant, but there’s not a fetus in the world that can stop this acerbic and savage train of comedy from delivering a masterful hour of stand-up.',
#   'popularity': 6.884,
#   'poster_path': '/tiJx25SPyaYqflshkxIyxBuEy9w.jpg',
#   'release_date': '2016-05-06',
#   'title': 'Ali Wong: Baby Cobra',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 134},
#  {'adult': False,
#   'backdrop_path': '/5qGNF9AyAeOwxgqkrBuLlg7gvpa.jpg',
#   'genre_ids': [18, 10749],
#   'id': 661365,
#   'original_language': 'en',
#   'original_title': 'Ali & Ava',
#   'overview': 'Sparks fly after Ali and Ava meet through their shared affection for Sofia, the child of Ali’s tenants whom Ava teaches. Ali finds comfort in Ava’s warmth and kindness while Ava finds Ali’s complexity and humour irresistible. As the pair begin to form a deep connection they have to find a way to keep their newfound passion from being overshadowed by the stresses and struggles of their separate lives and histories.\u200b',
#   'popularity': 2.899,
#   'poster_path': '/amrPTdN4E5zc86LUKI8DtdYPlzo.jpg',
#   'release_date': '2022-02-04',
#   'title': 'Ali & Ava',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [35],
#   'id': 518045,
#   'original_language': 'en',
#   'original_title': 'Ali Wong: Hard Knock Wife',
#   'overview': "Pregnant again, Ali Wong returns to Netflix in her second original stand-up comedy special and gets real on why having kids is not all it's cracked up to be.",
#   'popularity': 5.448,
#   'poster_path': '/q1WE1V01HMz1TGrqFPbLLiXeNdU.jpg',
#   'release_date': '2018-05-13',
#   'title': 'Ali Wong: Hard Knock Wife',
#   'video': False,
#   'vote_average': 7,
#   'vote_count': 86},
#  {'adult': False,
#   'backdrop_path': '/e1KQbrmG2edArMQumuSJ8NMvxfC.jpg',
#   'genre_ids': [12, 28, 35],
#   'id': 366759,
#   'original_language': 'tr',
#   'original_title': 'Ali Baba ve 7 Cüceler',
#   'overview': "Ali Senay and Ilber, the two partners of Senay Cüccaciye, sell garden dwarfs. When their company starts to dwindle, they decide to participate in a gardening fair in Sofia with the plan to meet new people from the sector in an attempt to drum up new business. Things don't go as planned as they find themselves crossing paths with the wrong people hell bent on causing world chaos.",
#   'popularity': 4.029,
#   'poster_path': '/x5o8vK2BJlXU8qtgNoNNIObJ1rw.jpg',
#   'release_date': '2015-11-12',
#   'title': 'Ali Baba and the 7 Dwarfs',
#   'video': False,
#   'vote_average': 5.3,
#   'vote_count': 64},
#  {'adult': False,
#   'backdrop_path': '/u7wNeJHrNToZZk23I4yNqeCG0KP.jpg',
#   'genre_ids': [28, 35, 18, 10752, 36],
#   'id': 54269,
#   'original_language': 'tr',
#   'original_title': 'Son Osmanlı Yandım Ali',
#   'overview': "After the First World War, the Allies occupy Istanbul. The protagonist, Yandim Ali is a rogue, discharged from the navy, who doesn't believe that the country can be saved, until he meets Mustafa Kemal (Ataturk), who plans to start a resistance in Anatolia against the occupying Allies, as well as the collaborators of an Ottoman government, that exists only on paper.",
#   'popularity': 3.656,
#   'poster_path': '/3AMUOPeR3uTfBdcvAyWjXhm2e1w.jpg',
#   'release_date': '2007-01-19',
#   'title': 'The Last Ottoman: Knockout Ali',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 24},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 167435,
#   'original_language': 'es',
#   'original_title': 'Ali',
#   'overview': 'In a role reversal that is challenging for any young adult, Ali has become a caretaker to her mother’s delicate mental health. Scarred by the past, she chain smokes, refuses to learn to drive, and is terrified of falling in love. Ali spends her days working in a supermarket and the rest of her time off on misadventures with her friend. But when she meets Julio, her tough veneer starts to crack and she may have to amend her strict rules of non-engagement.',
#   'popularity': 1.912,
#   'poster_path': '/c7LoLsYZbJ3TaCR89LBzLBFQxeC.jpg',
#   'release_date': '2012-03-25',
#   'title': 'Ali',
#   'video': False,
#   'vote_average': 6.5,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': '/p5fI4uNkdCyu6CfXblGdqpcNZLF.jpg',
#   'genre_ids': [16, 10751, 35],
#   'id': 101503,
#   'original_language': 'en',
#   'original_title': 'Ali Baba Bunny',
#   'overview': 'Bugs and Daffy get lost on the way to Pismo Beach, and find a cave full of treasure in the Arabian Desert, guarded by Hassan.',
#   'popularity': 3.54,
#   'poster_path': '/iGxSqPwnFos4CIV86K7csgTV4ll.jpg',
#   'release_date': '1957-02-09',
#   'title': 'Ali Baba Bunny',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 63},
#  {'adult': False,
#   'backdrop_path': '/40CMrFZHnh4BP9obKSq8jQp4sOv.jpg',
#   'genre_ids': [12, 35],
#   'id': 66540,
#   'original_language': 'fr',
#   'original_title': 'Ali Baba et les Quarante Voleurs',
#   'overview': 'A lord’s servant, Ali Baba, is sent to retrieve a slave for his master, but ends up on an adventure filled with gold, mischief, love, and forty famous thieves instead.',
#   'popularity': 5.392,
#   'poster_path': '/314RaBN4qVTQcmbu2kfKVLmdPfY.jpg',
#   'release_date': '1954-12-24',
#   'title': 'Ali Baba and the Forty Thieves',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 93},
#  {'adult': False,
#   'backdrop_path': '/kA4QzSqz4GN13neq06iFKRcHc3t.jpg',
#   'genre_ids': [35],
#   'id': 17272,
#   'original_language': 'en',
#   'original_title': 'Ali G: Bling Bling',
#   'overview': "Bling Bling is an assortment of Ali G's interviews; a couple of them with possibly the last people in Britain who didn't realise that someone was pulling their leg and several with American grandees of various sorts, including economist JK Galbraith and former CIA director Admiral Stansfield Turner. The real selling point, however, is Ali G's undeniably spectacular Comic Relief interview",
#   'popularity': 4.091,
#   'poster_path': '/1KgclrOLhQZLRS6jup3SgoRNF9g.jpg',
#   'release_date': '2001-10-31',
#   'title': 'Ali G: Bling Bling',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 23},
#  {'adult': False,
#   'backdrop_path': '/hqg9WgxSyjeUw5u2StjQGGuovoH.jpg',
#   'genre_ids': [35, 18],
#   'id': 650129,
#   'original_language': 'id',
#   'original_title': 'Ali & Ratu Ratu Queens',
#   'overview': "After his father's passing, a teenager sets out for New York in search of his estranged mother and soon finds love and connection in unexpected places.",
#   'popularity': 2.909,
#   'poster_path': '/57qni9eU4dBXponOJ9SJ7rc6Isy.jpg',
#   'release_date': '2021-06-17',
#   'title': 'Ali & Ratu Ratu Queens',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/qqqGEgA5m21JnKO5UAt5W7zMDk2.jpg',
#   'genre_ids': [99],
#   'id': 502153,
#   'original_language': 'en',
#   'original_title': 'Ali & Cavett: The Tale of the Tapes',
#   'overview': 'The life and times of Muhammed Ali shown through the lens of his numerous appearances on The Dick Cavett Show. The film features new interviews with Dick Cavett, Rev. Al Sharpton, and Larry Merchant, as well as archival material from the Cavett Show.',
#   'popularity': 5.002,
#   'poster_path': '/lbD8G7g92meTk7MgwHhR4dpel0I.jpg',
#   'release_date': '2018-08-02',
#   'title': 'Ali & Cavett: The Tale of the Tapes',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 49167,
#   'original_language': 'fr',
#   'original_title': 'Ali Zaoua, prince de la rue',
#   'overview': "Ali, Kwita, Omar and Boubker are street kids. The daily dose of glue sniffing represents their only escape from reality. Since they left Dib and his gang, they have been living on the portside of Casablanca. They live in constant fear of Dib's revenge. Ali wants to become a sailor - when he was living with his mother, a prostitute, he used to listen to a fairy tale about the sailor who discovered the miracle island with two suns. Instead of finding his island in the dream, Ali and his friends are confronted with Dib's gang. Matters are getting serious.",
#   'popularity': 3.425,
#   'poster_path': '/zTg8t5ctkG0MtQSFh957xYv1egj.jpg',
#   'release_date': '2000-01-01',
#   'title': 'Ali Zaoua: Prince of the Streets',
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 25},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 162869,
#   'original_language': 'xx',
#   'original_title': 'Princess Ali',
#   'overview': "Princess Ali, of Barnum and Bailey's circus, performs an Egyptian dance in the Edison Company's studio. As she dances, some musicians perform in the background to provide accompaniment.",
#   'popularity': 1.835,
#   'poster_path': '/wGn00YA6Yii4f4Eadizg58ACbiI.jpg',
#   'release_date': '1895-05-09',
#   'title': 'Princess Ali',
#   'video': False,
#   'vote_average': 3.7,
#   'vote_count': 13}]

# %%
df.iloc[559, 7] = 650129
df.iloc[559, :]
# Out:
# Title            Ali & Ratu Ratu Queens
# Genre                      Comedy-drama
# Premiere            2021-06-17 00:00:00
# Runtime                             100
# IMDB Score                          7.1
# Language                     Indonesian
# premiere_year                      2021
# tmdb_id                          650129
# Name: 559, dtype: object

# %%
df[df["tmdb_id"] == 672745]
# Out:
#                    Title         Genre   Premiere  Runtime  IMDB Score  \
# 382  The Heartbreak Club  Comedy-drama 2021-01-14      101         6.4
# 417  The Heartbreak Club  Comedy-drama 2021-01-14      101         6.5
#
#        Language  premiere_year tmdb_id
# 382  Indonesian           2021  672745
# 417  Indonesian           2021  672745

# %%
df.drop(382, inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
# We redefine rows_to_solve
rows_to_solve = df[df["tmdb_id"].duplicated(keep = False)]
rows_to_solve
# Out:
#                                                  Title  \
# 45    Porta dos Fundos: The First Temptation of Christ
# 88                                           The Beast
# 159                                            Òlòt?ré
# 299                                      The Lovebirds
# 314                                            Voyuer
# 358                Porta dos Fundos: The Last Hangover
# 484                               Long Live Brij Mohan
# 526  I'm No Longer Here: A Discussion with Guillerm...
# 584        The Road to El Camino: A Breaking Bad Movie
# 589                                          Seventeen
# 629                                        City of Joy
# 647  Rolling Thunder Revue: A bob Dylan Story by Ma...
# 667       Struggle: The Life and Lost Art of Szukaiski
#
#                           Genre   Premiere  Runtime  IMDB Score    Language  \
# 45                       Comedy 2019-12-03       46         4.6  Portuguese
# 88                        Drama 2020-11-27       99         5.2     Italian
# 159                 Crime drama 2020-10-02      106         5.5     English
# 299             Romantic comedy 2020-05-22       87         6.1     English
# 314                 Documentary 2017-12-01       95         6.2     English
# 358                      Comedy 2018-12-21       44         6.3  Portuguese
# 484                      Comedy 2018-08-03      105         6.8       Hindi
# 526       Aftershow / Interview 2020-11-03       14         7.0     English
# 584                   Making-of 2019-10-29       13         7.2     English
# 589  Coming-of-age comedy-drama 2019-10-18       99         7.2     Spanish
# 629                 Documentary 2018-09-07       74         7.5     English
# 647                 Documentary 2019-06-12      144         7.6     English
# 667                 Documentary 2018-12-21      105         8.0     English
#
#      premiere_year tmdb_id
# 45            2019    None
# 88            2020    None
# 159           2020    None
# 299           2020    None
# 314           2017    None
# 358           2018    None
# 484           2018    None
# 526           2020    None
# 584           2019    None
# 589           2019    None
# 629           2018    None
# 647           2019    None
# 667           2018    None

# %%
get_movie_data("The Lovebirds")
# Out:
# [{'adult': False,
#   'backdrop_path': '/dwcazDHJQmC1euuc7oVvDHMRuCv.jpg',
#   'genre_ids': [35, 28, 10749],
#   'id': 576156,
#   'original_language': 'en',
#   'original_title': 'The Lovebirds',
#   'overview': 'A couple experiences a defining moment in their relationship when they are unintentionally embroiled in a murder mystery. As their journey to clear their names takes them from one extreme – and hilarious - circumstance to the next, they must figure out how they, and their relationship, can survive the night.',
#   'popularity': 7.496,
#   'poster_path': '/5jdLnvALCpK1NkeQU1z4YvOe2dZ.jpg',
#   'release_date': '2021-05-22',
#   'title': 'The Lovebirds',
#   'video': False,
#   'vote_average': 6,
#   'vote_count': 31},
#  {'adult': False,
#   'backdrop_path': '/xjdAkXQSRQNGk7j1VbzW7AWOjzt.jpg',
#   'genre_ids': [18],
#   'id': 586554,
#   'original_language': 'en',
#   'original_title': 'The Lovebirds',
#   'overview': 'THE LOVEBIRDS intertwines six stories about love, friendship and survival. The film stars an international cast of American and Portuguese actors who create a colorful mix of off-beat characters that lead us through a complex labyrinth of emotions. Set in the old Romanesque city of Lisbon during the course of one night where love is the art of survival. Written by Anonymous',
#   'popularity': 0.627,
#   'poster_path': '/tL3JghgQ5IDMtr32KpChTzB8SWr.jpg',
#   'release_date': '2008-03-13',
#   'title': 'The Lovebirds',
#   'video': False,
#   'vote_average': 0,
#   'vote_count': 0}]

# %%
# "Lovebirds" has an error in "Premier" column
df.iloc[299, 7] = 576156
df.iloc[299, 2] = pd.to_datetime("2021-05-22")
df.iloc[299, :]
# Out:
# Title                  The Lovebirds
# Genre                Romantic comedy
# Premiere         2021-05-22 00:00:00
# Runtime                           87
# IMDB Score                       6.1
# Language                     English
# premiere_year                   2020
# tmdb_id                       576156
# Name: 299, dtype: object

# %%
get_movie_data("City of joy")
# Out:
# [{'adult': False,
#   'backdrop_path': '/w6Zgh1kFxLzeQFLOR8hC2JTwEon.jpg',
#   'genre_ids': [18],
#   'id': 47821,
#   'original_language': 'en',
#   'original_title': 'City of Joy',
#   'overview': 'Max Lowe is a Houston surgeon who has grown weary of the bureaucracy of American medicine. When he loses a patient on the operating table, Max impulsively decides to leave America and travel to India in the hope of finding himself. Not long after he arrives in Calcutta, Max is attacked by a group of thugs and left without money or a passport.',
#   'popularity': 7.98,
#   'poster_path': '/8aEfWFECThq5A1VnXsyzX8x2y72.jpg',
#   'release_date': '1992-04-15',
#   'title': 'City of Joy',
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 114},
#  {'adult': False,
#   'backdrop_path': '/ylUBY5u08TUt4mSYNW30Sw9wK8D.jpg',
#   'genre_ids': [99],
#   'id': 450005,
#   'original_language': 'en',
#   'original_title': 'City of Joy',
#   'overview': 'The Democratic Republic of Congo has endured 20 years of devastating violence. Rape has been used as a weapon of war to destroy community and access precious minerals. Congo is often referred to as “the worst place in the world to be a woman.” "City of Joy" tells a different story of the region. The film focuses on Jane, a student at a center where women who have suffered unimaginable abuse join together to become leaders. We also meet the founders of the center: a devout Congolese Doctor, a Congolese activist, and a radical N.Y. playwright. The film weaves between joy and pain as these individuals band together to demand hope in a place so often deemed hopeless.',
#   'popularity': 2.75,
#   'poster_path': '/tm6KdGFHViTOU4qSEVwYaA9gtm2.jpg',
#   'release_date': '2016-11-11',
#   'title': 'City of Joy',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 16}]

# %%
# "City of joy" where released two years delayed
df.iloc[629, 7] = 450005
df.iloc[629, :]
# Out:
# Title                    City of Joy
# Genre                    Documentary
# Premiere         2018-09-07 00:00:00
# Runtime                           74
# IMDB Score                       7.5
# Language                     English
# premiere_year                   2018
# tmdb_id                       450005
# Name: 629, dtype: object

# %%
# Get the ID's manually from movies with "title" problems
movies_without_id = [["The First temptation of Chris", 2019],
                    ["La Belva", 2020],
                    ["Òlòtūré", 2020],
                    ["Voyeur", 2017],
                    ["The Last Hangover", 2017],
                    ["Brij Mohan Amar Rahe!", 2018],
                    ["I’m No Longer Here: A Conversation with Guillermo Del Toro & Alfonso Cuarón", 2020],
                    ["The Road to El Camino: Behind the Scenes of El Camino: A Breaking Bad Movie ", 2019],
                    ["Diecisiete", 2019],
                    ["Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese", 2019],
                    ["Struggle: The Life and Lost Art of Szukalski", 2018]]

id_list = [get_movie_id(i[0], i[1]) for i in movies_without_id]

id_list
# Out:
# [652020,
#  654905,
#  642803,
#  473415,
#  571721,
#  539470,
#  760880,
#  683021,
#  623627,
#  574638,
#  565255]

# %%
# Put the id's on the original DataFrame
movies_without_id_index = [45, 88, 159, 314, 358, 484, 526, 584, 589, 647, 667]
pack = zip(movies_without_id_index, id_list)

for x in pack:
    df.iloc[x[0], 7] = x[1]
    
df.iloc[movies_without_id_index, :]
# Out:
#                                                  Title  \
# 45    Porta dos Fundos: The First Temptation of Christ
# 88                                           The Beast
# 159                                            Òlòt?ré
# 314                                            Voyuer
# 358                Porta dos Fundos: The Last Hangover
# 484                               Long Live Brij Mohan
# 526  I'm No Longer Here: A Discussion with Guillerm...
# 584        The Road to El Camino: A Breaking Bad Movie
# 589                                          Seventeen
# 647  Rolling Thunder Revue: A bob Dylan Story by Ma...
# 667       Struggle: The Life and Lost Art of Szukaiski
#
#                           Genre   Premiere  Runtime  IMDB Score    Language  \
# 45                       Comedy 2019-12-03       46         4.6  Portuguese
# 88                        Drama 2020-11-27       99         5.2     Italian
# 159                 Crime drama 2020-10-02      106         5.5     English
# 314                 Documentary 2017-12-01       95         6.2     English
# 358                      Comedy 2018-12-21       44         6.3  Portuguese
# 484                      Comedy 2018-08-03      105         6.8       Hindi
# 526       Aftershow / Interview 2020-11-03       14         7.0     English
# 584                   Making-of 2019-10-29       13         7.2     English
# 589  Coming-of-age comedy-drama 2019-10-18       99         7.2     Spanish
# 647                 Documentary 2019-06-12      144         7.6     English
# 667                 Documentary 2018-12-21      105         8.0     English
#
#      premiere_year tmdb_id
# 45            2019  652020
# 88            2020  654905
# 159           2020  642803
# 314           2017  473415
# 358           2018  571721
# 484           2018  539470
# 526           2020  760880
# 584           2019  683021
# 589           2019  623627
# 647           2019  574638
# 667           2018  565255

# %%
# Save the new dataframe as a checkpoint
# df.to_excel("temporary_netflix_df.xlsx", index = False)

# %% [markdown]
# ### 2. Get useful movies data

# %%
def get_movie_data(movie_id, *args):
    '''
    Takes a movie ID and a list of useful movie data we need, connects with TMDB API, requests the data and it returns
    the data required.
    
    Parameters
    ==========
    
    movie_id: int 
        movie's id we use to connect to the API
    
    *args: str 
        details we want to get
        
    Returns
    =======
    
    list 
        list with the field required passed in *args
    
    >>> The details can be found here: https://developers.themoviedb.org/3/movies/get-movie-details'''
    
    # Connect with the API
    response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}?api_key=f062d4d3bef1ed6f224531125e4c20c7")
    
    # Make list of details with a for iteration calling the keys in args
    details= []
    for detail in args:
        try:
            details.append(response.json()[detail])
        except:
            details.append("?")
    
    return details

# %%
# Prove
get_movie_data(152601, "adult", "original_language", "original_title")
# Out:
# [False, 'en', 'Her']

# %% [markdown]
# #### 2.1 Movie's data

# %% [markdown]
# ##### Get data we want:
# - Genres: because we want to compare the results with the genres on the original dataset
# - Imdb id: to try to get more data from IMDB site
# - Overview: description of the movie
# - Production countries
# - Vote average
# - Vote count
# - Title: useful for data validation
# - Original title: useful for data validation

# %%
movie_data = [get_movie_data(movie_id, 
                             "genres", 
                             "imdb_id", 
                             "overview", 
                             "production_countries", 
                             "vote_average", 
                             "vote_count",
                             "title",
                             "original_title") for movie_id in df["tmdb_id"]]

movie_data
# Out:
# [[[{'id': 99, 'name': 'Documentary'}],
#   'tt10662450',
#   'What is anime? Through deep-dives with notable masterminds of this electrifying genre, this fast-paced documentary seeks to find the answers.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'JP', 'name': 'Japan'}],
#   5.8,
#   51,
#   'Enter the Anime',
#   'Enter the Anime'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'tt12536776',
#   'In search of his sister, a renegade criminal seeks answers at a sordid hotel where he encounters a sinister guest and romances a mysterious waitress.',
#   [],
#   4.4,
#   25,
#   'Dark Forces',
#   'Fuego negro'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 878, 'name': 'Science Fiction'}],
#   'tt11385066',
#   'Loving girlfriend, family fortune, breakout movie role: he\'s got it all. Until an app awakens a powerful new yearning. While in Rome to shoot his first movie, actor and industrial heir Niccolò becomes obsessed with the dating app "US" that sends him into a self-destructive spiral.',
#   [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#   2.8,
#   105,
#   'The App',
#   'The App'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt15523050',
#   'Rap superstar Saweetie hosts a celebration of sexual health and positivity, with help from expert educators, candid stand-ups and uninhibited puppets.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   2.7,
#   3,
#   'Sex: Unzipped',
#   'Sex: Unzipped'],
#  [[{'id': 18, 'name': 'Drama'},
#    {'id': 36, 'name': 'History'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'}],
#   'tt14391622',
#   'Set in the 1980s, Tolani Ajao is a bank secretary in Lagos, who finds herself persuaded by her friend Rose Adamson to enter the world of drug trafficking.',
#   [],
#   4.7,
#   3,
#   'Swallow',
#   'Swallow'],
#  [[{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   'tt7608028',
#   'A teenager and his mother find themselves besieged by threatening forces when they move into a new house.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   3.7,
#   1154,
#   'The Open House',
#   'The Open House'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt10235600',
#   "When a restless spirit curses a Punjab village that has a history of female infanticide, the town's fate lies in the hands of a 10-year old girl, Shivangi.",
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   5.0,
#   15,
#   'Kaali Khuhi',
#   'काली खुहि'],
#  [[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'tt6593054',
#   'A getaway driver is attracted to a female neighbor whose husband owes money to a local gangster. As a result he is drawn deeper into a dangerous underworld.',
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   5.7,
#   37,
#   'Drive',
#   'Drive'],
#  [[{'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt15484488',
#   'Founded by the power couple, Ali and Sofia Khan, The Light is a training center that claims to be a self-betterment organization, focused on helping youths take charge of their life for a brighter future. But when three best friends join this organization, they soon realize that dark shadows lurk behind The Light and must find a way to escape.',
#   [],
#   4.4,
#   7,
#   'A World Without',
#   'A World Without'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt11792734',
#   'A resilient housewife, her husband and their marriage therapist become mired in a toxic love triangle and a plot to obtain an antique manuscript.',
#   [{'iso_3166_1': 'TR', 'name': 'Turkey'}],
#   3.9,
#   21,
#   'Leyla Everlasting',
#   '9 Kere Leyla'],
#  [[{'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt1552211',
#   'In the not-too-distant future, as a final response to crime and terrorism, the U.S. government plans to broadcast a signal that will make it impossible for anyone to knowingly break the law.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.6,
#   660,
#   'The Last Days of American Crime',
#   'The Last Days of American Crime'],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 37, 'name': 'Western'}],
#   'tt7949046',
#   'A loud Poem. A whimsical western tale of music and love.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   3.4,
#   12,
#   'Paradox',
#   'Paradox'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt14074470',
#   "After a breakup, an influencer takes her friends on a free trip to Bahia's vibrant Carnival, where she learns life's not just about social media likes.",
#   [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   5.3,
#   51,
#   'Carnaval',
#   'Carnaval'],
#  [[{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   'tt14315500',
#   'When something horrible happens to the only survivor of a bloody massacre, an insecure rookie cop must overcome his fears to stop further carnage.',
#   [{'iso_3166_1': 'PL', 'name': 'Poland'}],
#   4.0,
#   76,
#   'Nobody Sleeps in the Woods Tonight 2',
#   'W lesie dziś nie zaśnie nikt 2'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 10751, 'name': 'Family'}],
#   'tt11213600',
#   "A devoted grandson's mission to reunite his ailing grandmother with her ancestral home turns into a complicated, comic cross-border affair.",
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   7.4,
#   14,
#   'Sardar Ka Grandson',
#   'सरदार का पोता'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt14167424',
#   "Journalists and fans await Ma Anand Sheela as the infamous former Rajneesh commune's spokesperson returns to India after decades for an interview tour.",
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   6.8,
#   12,
#   'Searching for Sheela',
#   'Searching for Sheela'],
#  [[{'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt7504726',
#   'Buck is a big-hearted dog whose blissful domestic life is turned upside down when he is suddenly uprooted from his California home and transplanted to the exotic wilds of the Yukon during the Gold Rush of the 1890s. As the newest rookie on a mail delivery dog sled team—and later its leader—Buck experiences the adventure of a lifetime, ultimately finding his true place in the world and becoming his own master.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.6,
#   2678,
#   'The Call of the Wild',
#   'The Call of the Wild'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 10751, 'name': 'Family'}],
#   'tt15387782',
#   "The Undertaker has set a trap for the decorated tag team The New Day at his mansion. What they don't know: The Undertaker's mansion is an extreme Haunted House, packed to the brim with supernatural challenges. It's up to viewers to decide the fate of these poor souls trying to survive the wrath of The Undertaker.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.3,
#   26,
#   'Escape The Undertaker',
#   'Escape The Undertaker'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt14961160',
#   'While blind drunk, two unemployed millennials entrepreneurs drunkenly post a video pitch about their revolutionary app to a crowdfunding site. When the app catches fire and they accidentally raise millions of dollars they actually have to create the app.',
#   [{'iso_3166_1': 'MX', 'name': 'Mexico'}],
#   6.5,
#   21,
#   'Bankrolled',
#   'Fondeados'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'tt11754464',
#   'Four buddies attend a class taught by a love guru who leads them to question their romantic attachments — until her hidden agenda comes to light.',
#   [{'iso_3166_1': 'ID', 'name': 'Indonesia'}],
#   6.4,
#   7,
#   'Whipped',
#   'Bucin'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt5710042',
#   'Brought together at their childhood home over their dying mother, an estranged family is thrust into a deadly fight for their own survival.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.3,
#   121,
#   'Mercy',
#   'Mercy'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 10749, 'name': 'Romance'}],
#   'tt13106900',
#   'After falling for a guest, an unsuspecting hotel staff becomes embroiled in a hostage scheme and discovers true love in an unlikely place.',
#   [{'iso_3166_1': 'MY', 'name': 'Malaysia'}],
#   6.6,
#   4,
#   'All Because of You',
#   'Pasal Kau'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt15198608',
#   'A hiking trip into the wild turns into a desperate bid for survival for five friends on the run from a mysterious shooter.',
#   [{'iso_3166_1': 'DE', 'name': 'Germany'}],
#   4.5,
#   173,
#   'Prey',
#   'Prey'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt14537540',
#   'Kicked out of his band and home, a playful guitarist takes refuge with a bookkeeper, her son and dad. Is it possible to make sweet music together?',
#   [{'iso_3166_1': 'ZA', 'name': 'South Africa'}],
#   5.3,
#   14,
#   'Little Big Mouth',
#   'Little Big Mouth'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt4590256',
#   'To get revenge on her ex-boyfriend, an influencer attempts to transform an unpopular classmate into prom king.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.9,
#   689,
#   "He's All That",
#   "He's All That"],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt11324024',
#   'A large immigration raid in a small Tennessee town leaves emotional fallout as well as far-reaching questions about justice, faith and humanity.',
#   [{'iso_3166_1': 'MX', 'name': 'Mexico'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.0,
#   6,
#   'After the Raid',
#   'After the Raid'],
#  [[{'id': 27, 'name': 'Horror'}],
#   'tt10230404',
#   'An anthology of four short horror tales.',
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   4.8,
#   48,
#   'Ghost Stories',
#   'Ghost Stories'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}],
#   'tt7456312',
#   'At the turning point of the Iran-Contra affair, Elena McMahon, a fearless investigative journalist covering the 1984 US presidential campaign, puts herself in danger when she abandons her assigned task in order to fulfill the last wish of her ailing father, a mysterious man whose past activities she barely knows.',
#   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.9,
#   368,
#   'The Last Thing He Wanted',
#   'The Last Thing He Wanted'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt13667212',
#   "With the peak of his career long behind him, an actor clings to his past glory — until a sudden wake-up call forces him to face who he's become.",
#   [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   6.9,
#   23,
#   'What Happened to Mr Cha?',
#   '차인표'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}],
#   'tt9419834',
#   'Newlywed Jennifer is brutally attacked at a dark rest stop. While healing from her injuries, she can’t recall anything from her past, including the ordeal. Her husband, Russell , is just thankful she’s alive and eager to get her home. As he reintroduces her to their secluded mountain estate, Detective Page  pursues Jennifer’s assailant — his own daughter went missing and was never found. The same fate now awaits Jennifer, unless someone realizes that her loving caretaker is actually her captor.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.5,
#   882,
#   'Secret Obsession',
#   'Secret Obsession'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt10847138',
#   'In this documentary, Chelsea Handler explores how white privilege impacts US culture – and the ways it’s benefited her own life and career.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.5,
#   50,
#   "Hello, Privilege. It's Me, Chelsea",
#   "Hello, Privilege. It's Me, Chelsea"],
#  [[{'id': 14, 'name': 'Fantasy'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'}],
#   'tt1241317',
#   'A young man comes to possess a supernatural notebook, the Death Note, that grants him the power to kill any person simply by writing down their name on the pages. He then decides to use the notebook to kill criminals and change the world, but an enigmatic detective attempts to track him down and end his reign of terror.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.2,
#   3343,
#   'Death Note',
#   'Death Note'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}],
#   'tt8907992',
#   'When a voyeuristic divorcee fixates on the lives of a perfect couple a far, she soon gets embroiled in a murder mystery that unfolds revealing truths about her own life.',
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   5.8,
#   54,
#   'The Girl on the Train',
#   'द गर्ल ऑन द ट्रेन'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt8976710',
#   'Father-to-be Alan is shocked to learn that he was born a sextuplet. With his newfound brother Russell riding shotgun, the duo sets out on a hilarious journey to reunite with their remaining long-lost siblings.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.3,
#   672,
#   'Sextuplets',
#   'Sextuplets'],
#  [[{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'}],
#   'tt10121392',
#   'In a world where supervillains are commonplace, two estranged childhood best friends reunite after one devises a treatment that gives them powers to protect their city.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.7,
#   828,
#   'Thunder Force',
#   'Thunder Force'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt12154638',
#   'Incurable romantic Lotte finds her life upended when her plans for a picture-perfect wedding unravel -- just as her self-absorbed sister gets engaged.',
#   [{'iso_3166_1': 'NL', 'name': 'Netherlands'}],
#   6.7,
#   163,
#   'Just Say Yes',
#   'Just Say Yes'],
#  [[{'id': 28, 'name': 'Action'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 80, 'name': 'Crime'}],
#   'tt13669344',
#   'In Paris, two dysfunctional dealers use family ties to try to boost their small drug business in this crass comedy based on the webseries.',
#   [{'iso_3166_1': 'FR', 'name': 'France'}],
#   4.9,
#   84,
#   'The Misadventures of Hedi and Cokeman',
#   'En passant pécho'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt11010144',
#   "While her free-living bestie urges her to embrace singlehood, a commitment-craving social media expert can't stop following the life of a former love.",
#   [{'iso_3166_1': 'ZA', 'name': 'South Africa'}],
#   7.2,
#   118,
#   'Seriously Single',
#   'Seriously Single'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt11057594',
#   "Ellie tries to mend her marriage with her husband Marcus after a brief encounter with an old friend, David, only to find that David is more dangerous and unstable than she'd realized.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.8,
#   228,
#   'Fatal Affair',
#   'Fatal Affair'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt10136680',
#   'Strong Puerto Rican women forced to flee the island after Hurricane Maria have bonded like family in a FEMA hotel in the Bronx. They seek stability in their new life as forces try to pull them apart.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.7,
#   16,
#   'After Maria',
#   'After Maria'],
#  [[{'id': 53, 'name': 'Thriller'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 27, 'name': 'Horror'}],
#   'tt9257484',
#   'After a mysterious woman saves her daughter from a deadly snakebite, a single mother must repay the debt by killing a stranger before sundown.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.2,
#   335,
#   'Rattlesnake',
#   'Rattlesnake'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt8775056',
#   'When the Italian Premier and his companion find a dead body in his hotel suite, while on a trip to Hungary, they find themselves embroiled in a series of comedic situations as they try to avoid a scandal.',
#   [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#   4.2,
#   152,
#   '5 Star Christmas',
#   'Natale a 5 stelle'],
#  [[{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   'tt5059406',
#   'A young nurse takes care of elderly author who lives in a haunted house.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.4,
#   439,
#   'I Am the Pretty Thing That Lives in the House',
#   'I Am the Pretty Thing That Lives in the House'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt10168672',
#   'From campy lies to sexy surprises, this collection of vignettes captures the follies of several men as they fumble with fidelity and relationships.',
#   [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#   4.1,
#   123,
#   'The Players',
#   'Gli infedeli'],
#  [[{'id': 18, 'name': 'Drama'}],
#   'tt7920024',
#   'Dreams and reality collide as a young woman navigates a tumultuous relationship amid rising social tensions, protests and tragedies in Paris.',
#   [{'iso_3166_1': 'FR', 'name': 'France'}],
#   4.4,
#   137,
#   'Paris Is Us',
#   'Paris est à nous'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 14, 'name': 'Fantasy'}],
#   'tt11310004',
#   "Jesus, who's hitting the big 3-0, brings a surprise guest to meet the family. A Christmas special so wrong it must be from comedians Porta dos Fundos.",
#   [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   5.5,
#   101,
#   'The First Temptation of Christ',
#   'A Primeira Tentação de Cristo'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt12588398',
#   'Activists around the world fight injustice and drive social change in this documentary that follows their participation in the music video "Solidarité."',
#   [{'iso_3166_1': 'FR', 'name': 'France'}],
#   6.3,
#   3,
#   'We Are One',
#   'On est ensemble'],
#  [[{'id': 36, 'name': 'History'},
#    {'id': 10402, 'name': 'Music'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt12885272',
#   "A princess is thrust onto the world stage. The tabloid media is captivated by her beauty and vulnerability. The globe's most celebrated monarchy is disrupted. This is the story of the most princess woman of the modern age as she struggles to endure a spotlight brighter than any the world had ever known.",
#   [],
#   6.8,
#   7,
#   'Diana: The Musical',
#   'Diana: The Musical'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt10914452',
#   "While visiting her fiancé's mother in southern Italy, a woman must fight the mysterious and malevolent curse intent on claiming her daughter.",
#   [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#   5.5,
#   178,
#   'The Binding',
#   'Il legame'],
#  [[{'id': 53, 'name': 'Thriller'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt11734264',
#   'Transferred home after a traumatizing combat mission, a highly trained French soldier uses her lethal skills to hunt down the man who hurt her sister.',
#   [{'iso_3166_1': 'FR', 'name': 'France'}],
#   5.9,
#   454,
#   'Sentinelle',
#   'Sentinelle'],
#  [[{'id': 18, 'name': 'Drama'}],
#   'tt13328840',
#   'On an emotional journey in Morocco, an entrepreneur pieces together the turbulent life of his estranged mother and meets her adopted daughter.',
#   [{'iso_3166_1': 'PH', 'name': 'Philippines'}],
#   5.5,
#   2,
#   'Finding Agnes',
#   'Finding Agnes'],
#  [[{'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 35, 'name': 'Comedy'}],
#   'tt10600398',
#   "When alien invaders capture Earth's superheroes, their kids must learn to work together to save their parents - and the planet.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.3,
#   544,
#   'We Can Be Heroes',
#   'We Can Be Heroes'],
#  [[{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'tt12079068',
#   "A young warrior and her familiar search for the sacred place said to fulfill wishes. It's best not to anger the ancient guardians and spirits.",
#   [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   5.4,
#   26,
#   'Sol Levante',
#   'ソル・レヴァンテ'],
#  [[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}],
#   'tt12783454',
#   'It’s the summer before Elle heads to college, and she has a secret decision to make. Elle has been accepted into Harvard, where boyfriend Noah is matriculating, and also Berkeley, where her BFF Lee is headed and has to decide if she should stay or not.',
#   [{'iso_3166_1': 'ZA', 'name': 'South Africa'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.3,
#   1232,
#   'The Kissing Booth 3',
#   'The Kissing Booth 3'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt15398694',
#   'Activists and volunteers work through the darkest days of 2020, galvanizing social change amidst chaos as governments start to fail local communities. This epic, globally spanning and deeply passionate documentary serves as a clarion call that great change can be born of crisis.',
#   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.3,
#   3,
#   'Convergence: Courage in a Crisis',
#   'Convergence: Courage in a Crisis'],
#  [[{'id': 878, 'name': 'Science Fiction'}],
#   'tt3256226',
#   "As a young scientist searches for a way to save a dying Earth, she finds a connection with a man who's racing to catch the last shuttle off the planet.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.8,
#   1091,
#   'IO',
#   'IO'],
#  [[{'id': 37, 'name': 'Western'}, {'id': 35, 'name': 'Comedy'}],
#   'tt2479478',
#   'When his long-lost outlaw father returns, Tommy "White Knife" Stockburn goes on an adventure-filled journey across the Old West with his five brothers.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.1,
#   1062,
#   'The Ridiculous 6',
#   'The Ridiculous 6'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt13446424',
#   "A man foils an attempted murder, then flees the crew of would-be killers along with their intended target as a woman he's just met tries to find him.",
#   [{'iso_3166_1': 'DE', 'name': 'Germany'}],
#   4.5,
#   57,
#   'Christmas Crossfire',
#   'Wir Können Nicht Anders'],
#  [[{'id': 27, 'name': 'Horror'}],
#   'tt11686490',
#   'While diving in a remote French lake, a couple of YouTubers who specialize in underwater exploration videos discover a house submerged in the deep waters. What was initially a unique finding soon turns into a nightmare when they discover that the house was the scene of atrocious crimes. Trapped, with their oxygen reserves falling dangerously, they realize the worst is yet to come: they are not alone in the house.',
#   [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#    {'iso_3166_1': 'FR', 'name': 'France'}],
#   5.5,
#   116,
#   'The Deep House',
#   'The Deep House'],
#  [[{'id': 10751, 'name': 'Family'}, {'id': 80, 'name': 'Crime'}],
#   'tt5740806',
#   'When a crisis threatens to destroy their high school, four teens hatch a daring plan to raise $10 million. Step one? Breaking into the U.S. Mint.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.4,
#   229,
#   'Coin Heist',
#   'Coin Heist'],
#  [[{'id': 18, 'name': 'Drama'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt10418662',
#   'After a sudden global event wipes out all electronics and takes away humankind’s ability to sleep, chaos quickly begins to consume the world. Only Jill, an ex-soldier with a troubled past, may hold the key to a cure in the form of her own daughter. The question is, can Jill safely deliver her daughter and save the world before she herself loses her mind.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.0,
#   712,
#   'Awake',
#   'Awake'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt10230426',
#   "When her husband is framed and imprisoned for serial murders, a doting wife must perform a copycat murder, to prove her husband's innocence.",
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   6.4,
#   68,
#   'Mrs. Serial Killer',
#   'Mrs. Serial Killer'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'tt8150814',
#   "As the countdown to graduation begins, students at Osborne High are being stalked by a maniac intent on exposing their darkest secrets to the entire town, terrorizing victims while wearing a life-like mask of their own face. With a mysterious past of her own, Makani and her friends must discover the killer's identity before they become victims themselves.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.7,
#   263,
#   "There's Someone Inside Your House",
#   "There's Someone Inside Your House"],
#  [[{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   'tt11240506',
#   'Addicted to technology, a group of teens attends a rehabilitation camp in the forest, but a sinister force there intends to take them offline forever.',
#   [{'iso_3166_1': 'PL', 'name': 'Poland'}],
#   5.0,
#   382,
#   'Nobody Sleeps in the Woods Tonight',
#   'W lesie dziś nie zaśnie nikt'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt5792472',
#   'A day in the life of two best friends, a drug dealer, and a store manager collide at a hip-hop concert in the Inland Empire.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.2,
#   112,
#   'Take the 10',
#   'Take the 10'],
#  [[{'id': 10751, 'name': 'Family'}, {'id': 35, 'name': 'Comedy'}],
#   'tt10540242',
#   'After discovering a magical mask, an 11-year-old aspiring wrestler enters a competition to become the next WWE superstar by using special powers from a magical mask.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.9,
#   145,
#   'The Main Event',
#   'The Main Event'],
#  [[{'id': 18, 'name': 'Drama'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'tt10091530',
#   'After his sudden firing, a popular radio DJ moves in with his aunt, bringing along his four spoiled children, and a plan to return to the airwaves.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.7,
#   160,
#   'Holiday Rush',
#   'Holiday Rush'],
#  [[{'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 35, 'name': 'Comedy'}],
#   'tt8675288',
#   'A teen gamer is forced to level up to full-time babysitter when his favorite video game drops three superpowered infants from space into his backyard.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'}],
#   6.2,
#   90,
#   'Fearless',
#   'Fearless'],
#  [[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'tt10092752',
#   'A sawmill owner and his teenage daughter become tangled in a deadly feud when a drug dealer stashes stolen cocaine on their remote property.',
#   [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#    {'iso_3166_1': 'FR', 'name': 'France'}],
#   6.2,
#   253,
#   'Earth and Blood',
#   'La Terre et le Sang'],
#  [[{'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt5603212',
#   'In this horror movie, a retired priest haunted by his sins is pulled back into the darkness when a friend begs him to help his possessed daughter.',
#   [{'iso_3166_1': 'ES', 'name': 'Spain'},
#    {'iso_3166_1': 'MX', 'name': 'Mexico'}],
#   5.7,
#   27,
#   'The Day of the Lord',
#   'Menéndez: el día del Señor'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt13846542',
#   'A celebrity journalist and renowned womanizer starts to rethink his life choices after he falls for a mysterious model who leads a double life.',
#   [{'iso_3166_1': 'PL', 'name': 'Poland'}],
#   6.2,
#   216,
#   'Squared Love',
#   'Miłość do kwadratu'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt4902716',
#   "A man's life is turned inside out after a visit from his college friend leads him into the unexpected.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.6,
#   143,
#   'Rebirth',
#   'Rebirth'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'tt12217814',
#   'Fearing rejection, a young man struggles to declare his feelings for his best friend, who soon falls for another man — until a fateful incident.',
#   [{'iso_3166_1': 'ID', 'name': 'Indonesia'}],
#   6.3,
#   12,
#   'Love Like the Falling Rain',
#   'Seperti Hujan yang Jatuh ke Bumi'],
#  [[{'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'tt5246700',
#   'A desperate father tries to return home to his pregnant wife after a mysterious apocalyptic event turns everything to chaos.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.3,
#   1514,
#   'How It Ends',
#   'How It Ends'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt5617916',
#   "En route to the world's largest social media convention in Australia, Logan Paul is scared to death; today is his first time flying. All of his worst nightmares come true when the passengers refuse to switch their phones to airplane mode, causing the plane's controls to go haywire and electrocuting the pilots.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   3.9,
#   25,
#   'Airplane Mode',
#   'Airplane Mode'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt14611368',
#   "To rekindle their marriages, best friends-turned-in-laws Shanthi and Jennifer plan a couples' getaway. But it comes with all kinds of surprises.",
#   [{'iso_3166_1': 'ZA', 'name': 'South Africa'}],
#   7.1,
#   33,
#   'Trippin’ with the Kandasamys',
#   'Trippin’ with the Kandasamys'],
#  [[{'id': 27, 'name': 'Horror'}, {'id': 14, 'name': 'Fantasy'}],
#   None,
#   'Maximiliano is a psychiatrist who suffers from strange visions of his past. He grew up in an orphanage and then left for the big city. When his adoptive father dies, he goes back to his hometown where he will be reunited with his brothers and discover a dark family secret.',
#   [{'iso_3166_1': 'AR', 'name': 'Argentina'}],
#   4.5,
#   6,
#   'The Unburied',
#   'El cadáver insepulto'],
#  [[{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}],
#   'tt12588448',
#   'Back at home, Chuck relates the island shenanigans of his larva pals Red and Yellow to a skeptical reporter in this movie sequel to the hit cartoon.',
#   [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   7.4,
#   135,
#   'The Larva Island Movie',
#   'The Larva Island Movie'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'tt11936782',
#   'After falling for Geez, a heartthrob at school, Ann must confront family opposition, heartache, and deception as their romance struggles.',
#   [{'iso_3166_1': 'ID', 'name': 'Indonesia'}],
#   7.3,
#   7,
#   'Geez & Ann',
#   'Geez & Ann'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'}],
#   'tt9898858',
#   "A Detroit cop reluctantly teams with his girlfriend's 11-year-old son to clear his name and take down the city's most ruthless criminal.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.7,
#   285,
#   'Coffee & Kareem',
#   'Coffee & Kareem'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt3458510',
#   'Four best friends negotiate loss and major life changes during the last two weeks of high school.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.5,
#   691,
#   'Dude',
#   'Dude'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt12661060',
#   "An ode to the cat. A compilation of the funniest and cutest cat video's by Abatutu, the most famous cat in The Netherlands",
#   [{'iso_3166_1': 'NL', 'name': 'Netherlands'}],
#   5.0,
#   6,
#   'Kitty Love: An Homage to Cats',
#   'Poeslief'],
#  [[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'tt14315566',
#   "After his brother dies in a car crash, a disgraced MMA fighter takes over the family nightclub — and soon learns his sibling's death wasn’t an accident.",
#   [{'iso_3166_1': 'PL', 'name': 'Poland'}],
#   6.3,
#   114,
#   'Bartkowiak',
#   'Bartkowiak'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#   'tt15204288',
#   "When the clever but socially-awkward Tetê joins a new school, she'll do anything to fit in. But the queen bee among her classmates has other ideas.",
#   [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   6.9,
#   108,
#   'Confessions of an Invisible Girl',
#   'Confissões de Uma Garota Excluída'],
#  [[{'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}],
#   'tt5577742',
#   'A psychiatrist tries to put her life back together after a violent attack by seeking to repair the life of a new patient, but he has his own terrifying history.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.3,
#   321,
#   'Clinical',
#   'Clinical'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt3685236',
#   'She could do the responsible thing. Or she could go to Ibiza with her best friends to chase down a hot DJ. Easy choice.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.8,
#   1049,
#   'Ibiza',
#   'Ibiza'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'tt9252508',
#   'Jodi, the tallest girl in her high school, has always felt uncomfortable in her own skin. But after years of slouching, being made fun of, and avoiding attention at all costs, Jodi finally decides to find the confidence to stand tall.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.4,
#   1502,
#   'Tall Girl',
#   'Tall Girl'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt6821012',
#   'The parents of a soon-to-be married couple make the final preparations for the wedding ceremony.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.4,
#   615,
#   'The Week Of',
#   'The Week Of'],
#  [[{'id': 80, 'name': 'Crime'}],
#   'tt11499506',
#   'To rescue his daughter, an unstable Special Forces veteran unleashes his inner beast as he pursues her kidnappers — and soon becomes a suspect himself.',
#   [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#   6.3,
#   219,
#   'The Beast',
#   'La Belva'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt13787118',
#   'The feature documentary follows women of all walks of life, all ages and ethnic backgrounds, as they shed trauma, body image shame, sexual abuse and other issues locked in their bodies, and embark on a journey to reclaim themselves. The film also gives a rare window into the world of Pole artistry and expression.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.3,
#   32,
#   'Strip Down, Rise Up',
#   'Strip Down, Rise Up'],
#  [[{'id': 878, 'name': 'Science Fiction'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 28, 'name': 'Action'}],
#   'tt8743064',
#   'As two teen prodigies try to master the art of time travel, a tragic police shooting sends them on a series of dangerous trips to the past.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.6,
#   427,
#   'See You Yesterday',
#   'See You Yesterday'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt5893332',
#   'When a hapless but dedicated talent manager signs his first client who actually has talent, his career finally starts to take off.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.5,
#   394,
#   'Sandy Wexler',
#   'Sandy Wexler'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt7256866',
#   'Two college grads return to their hometown, where a hypothetical question -- whose dad would win in a fight? -- leads to mass mayhem.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.4,
#   380,
#   'Father of the Year',
#   'Father of the Year'],
#  [[{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 35, 'name': 'Comedy'}],
#   'tt8179388',
#   'Stranded at a summer camp when aliens attack the planet, four teens with nothing in common embark on a perilous mission to save the world.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.1,
#   744,
#   'Rim of the World',
#   'Rim of the World'],
#  [[{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'tt9174358',
#   'In a world where humans and fearsome monsters live in an uneasy balance, young hunter Aiden fights to save his village from destruction by a dragon.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.8,
#   46,
#   'Monster Hunter: Legends of the Guild',
#   'Monster Hunter: Legends of the Guild'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 9648, 'name': 'Mystery'}],
#   'tt10682266',
#   'Hubie Dubois, despite his devotion to his hometown of Salem, Massachusetts (and its legendary Halloween celebration), is a figure of mockery for kids and adults alike. But this year, something really is going bump in the night, and it’s up to Hubie to save Halloween.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.1,
#   1131,
#   'Hubie Halloween',
#   'Hubie Halloween'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt6119504',
#   'When nerdy high schooler Dani finally attracts the interest of her longtime crush, she lands in the cross hairs of his ex, a social media celebrity.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.4,
#   935,
#   '#realityhigh',
#   '#realityhigh'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#   'tt2962984',
#   "When he's caught up in a deadly conspiracy, an unemployed greeting card writer must create the perfect card for a new holiday to save his skin.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   4.8,
#   98,
#   "Girlfriend's Day",
#   "Girlfriend's Day"],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 10402, 'name': 'Music'},
#    {'id': 10770, 'name': 'TV Movie'},
#    {'id': 99, 'name': 'Documentary'}],
#   'tt9880234',
#   'Hollywood\'s finest pay tribute to "Rowan and Martin\'s Laugh-In" for an uncensored and unforgettable celebration at The Dolby Theater.',
#   [],
#   5.5,
#   13,
#   'Still Laugh-In: The Stars Celebrate',
#   'Still Laugh-In: The Stars Celebrate'],
#  [[{'id': 53, 'name': 'Thriller'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'}],
#   'tt12383460',
#   'A young woman seeking self-improvement enlists the help of a renowned hypnotist but, after a handful of intense sessions, discovers unexpected and deadly consequences.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.2,
#   225,
#   'Hypnotic',
#   'Hypnotic'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt5563324',
#   'When a husband and wife move to a small town, a home invasion leaves the wife traumatized and suspicious that those around her might not be who they seem.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.2,
#   292,
#   'Intrusion',
#   'Intrusion'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt10937318',
#   'Barack and Michelle Obama talk with the directors of the documentary American Factory about the importance of storytelling and the impact of their film.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.6,
#   13,
#   'American Factory: A Conversation with the Obamas',
#   'American Factory: A Conversation with the Obamas'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt5809020',
#   "LA homicide detective Gene Handsome's knack for solving mysteries is matched only by his inability to make sense of his own problems.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.3,
#   94,
#   'Handsome: A Netflix Mystery Movie',
#   'Handsome: A Netflix Mystery Movie'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 10402, 'name': 'Music'},
#    {'id': 10751, 'name': 'Family'}],
#   'tt10627548',
#   'A rich and nasty woman returns to her hometown to evict everyone but discovers the true meaning of Christmas thanks to the local townsfolk – and an actual angel. Features 14 original songs with music and lyrics by Dolly Parton!',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.3,
#   42,
#   "Dolly Parton's Christmas on the Square",
#   "Dolly Parton's Christmas on the Square"],
#  [[{'id': 18, 'name': 'Drama'}],
#   'tt8852536',
#   "While she advocates for her female clients in divorce cases, a lawyer's trauma from sexual violence impacts her own marriage.",
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   6.0,
#   2,
#   'Firebrand',
#   'Firebrand'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt12881516',
#   'The dark secrets of a seemingly peaceful island threaten to swallow up an orphaned student when he grows close to a mysterious new teacher.',
#   [{'iso_3166_1': 'DE', 'name': 'Germany'}],
#   6.2,
#   110,
#   'Black Island',
#   'Schwarze Insel'],
#  [[{'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt13446126',
#   'After witnessing a haunting in their hospital, two doctors become dangerously obsessed with obtaining scientific proof that ghosts exist.',
#   [{'iso_3166_1': 'TH', 'name': 'Thailand'}],
#   6.5,
#   83,
#   'Ghost Lab',
#   'โกสต์แล็บ..ฉีกกฎทดลองผี'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt1545304',
#   'A panicked young woman and her two best friends fly to Mexico to delete a ranting email she sent to her new boyfriend. On arrival, they run into her former beau, who soon gets caught up in their frantic scheme.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.2,
#   402,
#   'Desperados',
#   'Desperados'],
#  [[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}],
#   'tt12299824',
#   'Elisabeth and John-John live in the same city, but they inhabit different worlds.',
#   [{'iso_3166_1': 'SE', 'name': 'Sweden'}],
#   5.6,
#   46,
#   'JJ+E',
#   'Vinterviken'],
#  [[{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}],
#   'tt3612126',
#   'After a young mother murders her family in her own house, a detective attempts to investigate the mysterious case, only to discover that the house is cursed by a vengeful ghost. Now targeted by the demonic spirits, the detective must do anything to protect herself and her family from harm.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.6,
#   852,
#   'The Grudge',
#   'The Grudge'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt9471660',
#   "A woman named Amanda lies stricken, far from home. A young boy named David questions her, trying to make her remember. She's not his mother, he's not her son. As her time is running out, he helps her unravel a powerful, haunting story of obsessive jealousy, an invisible danger, and the power of a mother's love for her child.",
#   [{'iso_3166_1': 'CL', 'name': 'Chile'},
#    {'iso_3166_1': 'PE', 'name': 'Peru'}],
#   6.1,
#   68,
#   'Fever Dream',
#   'Distancia de rescate'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#   'tt8976832',
#   "On their last night together, four longtime flatmates' lives are suddenly upended when a secret is revealed during the course of an evening celebration.",
#   [{'iso_3166_1': 'ES', 'name': 'Spain'}],
#   5.0,
#   333,
#   'Who Would You Take to a Deserted Island?',
#   '¿A quién te llevarías a una isla desierta?'],
#  [[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'tt6290418',
#   "Just as Simone works up the courage to tell her conservative Jewish family she's a lesbian, she finds herself attracted to a male Senegalese chef.",
#   [{'iso_3166_1': 'FR', 'name': 'France'}],
#   5.1,
#   151,
#   'To Each, Her Own',
#   'Les Goûts et les Couleurs'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt10962368',
#   'Catherine Clare reluctantly trades life in 1980 Manhattan for a remote home in the tiny hamlet of Chosen, New York, after her husband George lands a job teaching art history at a small Hudson Valley college. Even as she does her best to transform the old dairy farm into a place where young daughter Franny will be happy, Catherine increasingly finds herself isolated and alone. She soon comes to sense a sinister darkness lurking both in the walls of the ramshackle property—and in her marriage to George.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   5.8,
#   602,
#   'Things Heard & Seen',
#   'Things Heard & Seen'],
#  [[{'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}],
#   'tt6186696',
#   "Set against the backdrop of the infamous Theatre Grand Guignol the story revolves around iconic actress Paula Maxa - the most famous of the Grand Guignol's leading ladies and the titular Most Assassinated Woman, who was graphically slain on stage multiple times a day.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'BE', 'name': 'Belgium'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   5.1,
#   58,
#   'The Most Assassinated Woman in the World',
#   'La Femme la plus assassinée du monde'],
#  [[{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}],
#   'tt10350626',
#   'Inspired by the life of a fearless young officer who made history by becoming the first Indian female Air Force officer to fly in a combat zone during the 1999 Kargil War',
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   7.5,
#   49,
#   'Gunjan Saxena: The Kargil Girl',
#   'गुंजन सक्सेना: द कारगिल गर्ल'],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 18, 'name': 'Drama'}],
#   'tt4855748',
#   'XOXO follows six strangers whose lives collide in one frenetic, dream-chasing, hopelessly romantic night.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.0,
#   543,
#   'XOXO',
#   'XOXO'],
#  [[{'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}],
#   'tt12282598',
#   'Police officer Pipa works on her first big case while simultaneously investigating her boss, who is suspected of murder. The prequel to "Perdida".',
#   [{'iso_3166_1': 'AR', 'name': 'Argentina'}],
#   6.3,
#   149,
#   'Intuition',
#   'La corazonada'],
#  [[{'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'tt13056008',
#   "An immigrant in search of the American dream is forced to take a room in a boarding house and soon finds herself in a nightmare from which she can't escape.",
#   [{'iso_3166_1': 'RO', 'name': 'Romania'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.1,
#   227,
#   'No One Gets Out Alive',
#   'No One Gets Out Alive'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 18, 'name': 'Drama'}],
#   'tt15360916',
#   'After their partner swap experiment takes a turn, four friends arrive at a remote beach hut to face the fallout and purge themselves of deeper truths.',
#   [{'iso_3166_1': 'DE', 'name': 'Germany'}],
#   5.2,
#   37,
#   'The Four of Us',
#   'Du Sie Er & Wir'],
#  [[],
#   'tt11864226',
#   'Westchester, Summer 1991. Closeted teenager Daniel Rosen begins to come out to himself when his estranged gay uncle Ira returns home, dying of complications from HIV/AIDS.',
#   [],
#   0.0,
#   0,
#   'Last Summer with Uncle Ira',
#   'Last Summer with Uncle Ira'],
#  [[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}],
#   'tt8709036',
#   "A year after Amber helped Richard secure the crown. The two are set to tie the knot in a royal Christmas wedding — but their plans are jeopardized when Amber finds herself second-guessing whether or not she's cut out to be queen, and Richard is faced with a political crisis that threatens to tarnish not only the holiday season but the future of the kingdom.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.5,
#   756,
#   'A Christmas Prince: The Royal Wedding',
#   'A Christmas Prince: The Royal Wedding'],
#  [[{'id': 16, 'name': 'Animation'}],
#   'tt10687588',
#   'The Super Monsters welcome Vida to her new home in Pitchfork Pines with a tour of their favorite places, then help her through her first day at school.',
#   [],
#   6.5,
#   2,
#   'Super Monsters Back to School',
# ...
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.2,
#   92,
#   'Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese',
#   'Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt15101938',
#   'Under pressure to continue a winning tradition in American tennis, Mardy Fish faced mental health challenges that changed his life on and off the court.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.0,
#   18,
#   'Untold: Breaking Point',
#   'Untold: Breaking Point'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt11905462',
#   "Follow the Indianapolis Star reporters that broke the story about USA Gymnastics doctor Larry Nassar's abuse and hear from gymnasts.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.8,
#   192,
#   'Athlete A',
#   'Athlete A'],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}],
#   'tt10516984',
#   'In a short musical film directed by Paul Thomas Anderson, Thom Yorke of Radiohead stars in a mind-bending visual piece. Best played loud.',
#   [{'iso_3166_1': 'CZ', 'name': 'Czech Republic'},
#    {'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   7.4,
#   295,
#   'Anima',
#   'Anima'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}],
#   'tt1365050',
#   "A drama based on the experiences of Agu, a child fighting in the civil war of an unnamed, fictional West African country. Follows the journey of Agu as he's forced to join a group of soldiers. While Agu fears his commander and many of the men around him, his fledgling childhood has been brutally shattered by the war raging through his country, and he is at first torn between conflicting revulsion and fascination. Depicts the mechanics of war and does not shy away from explicit, visceral detail, painting a complex, difficult picture of Agu as a child soldier.",
#   [{'iso_3166_1': 'GH', 'name': 'Ghana'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.6,
#   1335,
#   'Beasts of No Nation',
#   'Beasts of No Nation'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt10050766',
#   'Brené Brown is a research professor at the University of Houston Graduate College of Social Work. She has spent more than a decade studying vulnerability, courage, authenticity and shame. With two TED talks under her belt, Brené Brown brings her humor and empathy to Netflix to discuss what it takes to choose courage over comfort in a culture defined by scarcity, fear and uncertainty.',
#   [],
#   7.0,
#   31,
#   'Brené Brown: The Call to Courage',
#   'Brené Brown: The Call to Courage'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt8923484',
#   'Down the road from Woodstock in the early 1970s, a revolution blossomed in a ramshackle summer camp for disabled teenagers, transforming their young lives and igniting a landmark movement.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.1,
#   95,
#   'Crip Camp: A Disability Revolution',
#   'Crip Camp: A Disability Revolution'],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': 'Documentary'}],
#   'tt5001772',
#   "For Justin Timberlake it's the final two dates of his 20/20 Experience World Tour at the MGM Grand Garden Arena in Las Vegas. Surrounded by the 25 band members of The Tennessee Kids and featuring show-stopping performances from one of the highest-grossing tours of the decade, the film is a culmination of the singer’s 134 shows and 2 years on the road.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.6,
#   37,
#   'Justin Timberlake + The Tennessee Kids',
#   'Justin Timberlake + The Tennessee Kids'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt11763742',
#   "Director Alfonso Cuarón reflects on the childhood memories, period details and creative choices that shaped his Academy Award-winning film 'ROMA.'",
#   [{'iso_3166_1': 'MX', 'name': 'Mexico'}],
#   8.2,
#   15,
#   'Road to Roma',
#   'Camino a Roma'],
#  [[{'id': 18, 'name': 'Drama'}],
#   'tt6155172',
#   'In 1970s Mexico City, two domestic workers help a mother of four while her husband is away for an extended period of time.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'MX', 'name': 'Mexico'}],
#   7.7,
#   3238,
#   'Roma',
#   'Roma'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt5849950',
#   'Returning for a second Netflix comedy special, Jim Jefferies unleashes his famously ferocious black humor to a packed house in Nashville, Tennessee.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.5,
#   97,
#   'Jim Jefferies: Freedumb',
#   'Jim Jefferies: Freedumb'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 16, 'name': 'Animation'}],
#   'tt11768948',
#   'Grieving parents journey through an emotional void as they mourn the loss of a child in the aftermath of a tragic school shooting.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.8,
#   560,
#   'If Anything Happens I Love You',
#   'If Anything Happens I Love You'],
#  [[{'id': 80, 'name': 'Crime'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 36, 'name': 'History'}],
#   'tt1302006',
#   'Pennsylvania, 1956. Frank Sheeran, a war veteran of Irish origin who works as a truck driver, accidentally meets mobster Russell Bufalino. Once Frank becomes his trusted man, Bufalino sends him to Chicago with the task of helping Jimmy Hoffa, a powerful union leader related to organized crime, with whom Frank will maintain a close friendship for nearly twenty years.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.7,
#   5021,
#   'The Irishman',
#   'The Irishman'],
#  [[{'id': 36, 'name': 'History'}, {'id': 18, 'name': 'Drama'}],
#   'tt1070874',
#   'What was supposed to be a peaceful protest turned into a violent clash with the police. What followed was one of the most notorious trials in history.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.8,
#   2075,
#   'The Trial of the Chicago 7',
#   'The Trial of the Chicago 7'],
#  [[{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}],
#   'tt14168118',
#   'To provide a better life for his family in the country, 18-year-old Mateus accepts a job in a junkyard in São Paulo for his new boss Luca. But when he and a few other boys become trapped in the dangerous world of contemporary slavery, Mateus will be forced to decide between working for the very man who enslaved him or risk his and his family’s future.',
#   [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   6.0,
#   2,
#   '7 Prisoners',
#   '7 Prisioneiros'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt6333060',
#   'While investigating the furtive world of illegal doping in sports, director Bryan Fogel connects with renegade Russian scientist Dr. Grigory Rodchenkov—a pillar of his country’s “anti-doping” program. Over dozens of Skype calls, urine samples, and badly administered hormone injections, Fogel and Rodchenkov grow closer despite shocking allegations that place Rodchenkov at the center of Russia’s state-sponsored Olympic doping program.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.7,
#   538,
#   'Icarus',
#   'Icarus'],
#  [[{'id': 18, 'name': 'Drama'}],
#   'tt7653254',
#   'A stage director and an actress struggle through a grueling, coast-to-coast divorce that pushes them to their personal extremes.',
#   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   7.8,
#   5247,
#   'Marriage Story',
#   'Marriage Story'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt3260524',
#   'Amid shifting times, two women kept their decades-long love a secret. But coming out later in life comes with its own set of challenges.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.5,
#   91,
#   'A Secret Love',
#   'A Secret Love'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt14539726',
#   "David Attenborough and scientist Johan Rockström examine Earth's biodiversity collapse and how this crisis can still be averted.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.2,
#   25,
#   'Breaking Boundaries: The Science of Our Planet',
#   'Breaking Boundaries: The Science of Our Planet'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt5952266',
#   'Wildlife activists and investigators put their lives on the line to battle the illegal African ivory trade, in this suspenseful on-the-ground documentary.',
#   [{'iso_3166_1': 'AT', 'name': 'Austria'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.6,
#   49,
#   'The Ivory Game',
#   'The Ivory Game'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt9316022',
#   'The remarkable life story of the pre-war Polish artist Stanislav Szukalski, documented by the American friends he made late in life.',
#   [{'iso_3166_1': 'PL', 'name': 'Poland'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.7,
#   52,
#   'Struggle: The Life and Lost Art of Szukalski',
#   'Struggle: The Life and Lost Art of Szukalski'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt10851618',
#   "The history and current standing of the Paralympic Games, which has grown to become the world's third largest sporting event.",
#   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   8.2,
#   74,
#   'Rising Phoenix',
#   'Rising Phoenix'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt12888462',
#   'After years of swimming every day in the freezing ocean at the tip of Africa, Craig Foster meets an unlikely teacher: a young octopus who displays remarkable curiosity. Visiting her den and tracking her movements for months on end he eventually wins the animal’s trust and they develop a never-before-seen bond between human and wild animal.',
#   [{'iso_3166_1': 'ZA', 'name': 'South Africa'}],
#   8.0,
#   507,
#   'My Octopus Teacher',
#   'My Octopus Teacher'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt6333054',
#   'Coral reefs are the nursery for all life in the oceans, a remarkable ecosystem that sustains us. Yet with carbon emissions warming the seas, a phenomenon called “coral bleaching”—a sign of mass coral death—has been accelerating around the world, and the public has no idea of the scale or implication of the catastrophe silently raging underwater.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.9,
#   91,
#   'Chasing Coral',
#   'Chasing Coral'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt5895028',
#   "An in-depth look at the prison system in the United States and how it reveals the nation's history of racial inequality.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.0,
#   599,
#   '13th',
#   '13th'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt14152756',
#   'Passionate about ocean life, a filmmaker sets out to document the harm that humans do to marine species — and uncovers an alarming global conspiracy.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.0,
#   264,
#   'Seaspiracy',
#   'Seaspiracy'],
#  [[{'id': 99, 'name': 'Documentary'}, {'id': 80, 'name': 'Crime'}],
#   'tt13206564',
#   "Follows a mother's tireless crusade to jail her daughter's murderer after Mexico's justice system failed to do so.",
#   [{'iso_3166_1': 'MX', 'name': 'Mexico'}],
#   9.0,
#   175,
#   'The Three Deaths of Marisela Escobedo',
#   'Las tres muertes de Marisela Escobedo'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt8637504',
#   "An investigation of how Hollywood's fabled stories have deeply influenced how Americans feel about transgender people, and how transgender people have been taught to feel about themselves.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.3,
#   94,
#   'Disclosure',
#   'Disclosure'],
#  [[{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'}],
#   'tt4729430',
#   "When Jesper distinguishes himself as the Postal Academy's worst student, he is sent to Smeerensburg, a small village located on an icy island above the Arctic Circle, where grumpy inhabitants barely exchange words, let alone letters. Jesper is about to give up and abandon his duty as a postman when he meets local teacher Alva and Klaus, a mysterious carpenter who lives alone in a cabin full of handmade toys.",
#   [{'iso_3166_1': 'ES', 'name': 'Spain'}],
#   8.3,
#   2617,
#   'Klaus',
#   'Klaus'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt11101698',
#   "Some of the world's most majestic birds display delightfully captivating mating rituals, from flashy dancing to flaunting their colorful feathers.",
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.0,
#   37,
#   'Dancing with the Birds',
#   'Dancing with the Birds'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt7320560',
#   'This revealing portrait of Cuba follows the lives of Fidel Castro and three Cuban families affected by his policies over the last four decades.',
#   [{'iso_3166_1': 'CU', 'name': 'Cuba'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.6,
#   70,
#   'Cuba and the Cameraman',
#   'Cuba and the Cameraman'],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': 'Documentary'}],
#   'tt11000894',
#   'Backed by a full band and a ready wit, actor Ben Platt opens up a very personal songbook onstage -- numbers from his debut LP, "Sing to Me Instead."',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.2,
#   15,
#   'Ben Platt: Live from Radio City Music Hall',
#   'Ben Platt: Live from Radio City Music Hall'],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': 'Documentary'}],
#   'tt9426852',
#   'Taylor Swift takes the stage in Dallas for the Reputation Stadium Tour and celebrates a monumental night of music, memories and visual magic.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   8.1,
#   218,
#   'Taylor Swift: Reputation Stadium Tour',
#   'Taylor Swift: Reputation Stadium Tour'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt4908644',
#   'A documentary on the unrest in Ukraine during 2013 and 2014, as student demonstrations supporting European integration grew into a violent revolution calling for the resignation of President Viktor F. Yanukovich.',
#   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'UA', 'name': 'Ukraine'}],
#   8.0,
#   171,
#   "Winter on Fire: Ukraine's Fight for Freedom",
#   "Winter on Fire: Ukraine's Fight for Freedom"],
#  [[{'id': 10402, 'name': 'Music'}, {'id': 99, 'name': 'Documentary'}],
#   'tt8716334',
#   "Springsteen on Broadway is a solo acoustic performance written and performed by Tony Award, Academy Award, and 20-time Grammy Award winner Bruce Springsteen. Based on his worldwide best-selling autobiography 'Born to Run,' Springsteen on Broadway is a unique evening with Bruce, his guitar, a piano, and his very personal stories. In addition, it features a special appearance by Patti Scialfa. Netflix will allow global audiences to see the show critics have been raving about from anywhere they are.",
#   [],
#   8.1,
#   35,
#   'Springsteen On Broadway',
#   'Springsteen On Broadway'],
#  [[{'id': 99, 'name': 'Documentary'}, {'id': 10402, 'name': 'Music'}],
#   'tt13458600',
#   "Between scenes from his concert in São Paulo's oft-inaccessible Theatro Municipal, rapper and activist Emicida celebrates the rich legacy of Black Brazilian culture.",
#   [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   8.8,
#   35,
#   "Emicida: AmarElo - It's All for Yesterday",
#   'Emicida: AmarElo - É Tudo Pra Ontem'],
#  [[{'id': 99, 'name': 'Documentary'}],
#   'tt11989890',
#   'The story of life on our planet by the man who has seen more of the natural world than any other. In more than 90 years, Attenborough has visited every continent on the globe, exploring the wild places of our planet and documenting the living world in all its variety and wonder. Addressing the biggest challenges facing life on our planet, the film offers a powerful message of hope for future generations.',
#   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   8.6,
#   201,
#   'David Attenborough: A Life on Our Planet',
#   'David Attenborough: A Life on Our Planet']]

# %%
# Transform the result to DataFrame
data_df = pd.DataFrame(movie_data, columns=["genres", 
                             "imdb_id", 
                             "overview", 
                             "production_countries", 
                             "vote_average", 
                             "vote_count",
                             "title",
                             "original_title"])

data_df.head()
# Out:
#                                               genres     imdb_id  \
# 0                [{'id': 99, 'name': 'Documentary'}]  tt10662450
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...  tt12536776
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...  tt11385066
# 3                     [{'id': 35, 'name': 'Comedy'}]  tt15523050
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...  tt14391622
#
#                                             overview  \
# 0  What is anime? Through deep-dives with notable...
# 1  In search of his sister, a renegade criminal s...
# 2  Loving girlfriend, family fortune, breakout mo...
# 3  Rap superstar Saweetie hosts a celebration of ...
# 4  Set in the 1980s, Tolani Ajao is a bank secret...
#
#                                 production_countries  vote_average  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...           5.8
# 1                                                 []           4.4
# 2            [{'iso_3166_1': 'IT', 'name': 'Italy'}]           2.8
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...           2.7
# 4                                                 []           4.7
#
#    vote_count            title   original_title
# 0          51  Enter the Anime  Enter the Anime
# 1          25      Dark Forces      Fuego negro
# 2         105          The App          The App
# 3           3    Sex: Unzipped    Sex: Unzipped
# 4           3          Swallow          Swallow

# %% [markdown]
# ##### Clean the DataFrame

# %%
# Build first genre column
genres_1 = []
for genre in data_df["genres"]:
    try:
        genres_1.append(genre[0])
    except:
        genres_1.append("?")
        
genres_1
# Out:
# [{'id': 99, 'name': 'Documentary'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 36, 'name': 'History'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 37, 'name': 'Western'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 37, 'name': 'Western'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 36, 'name': 'History'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 36, 'name': 'History'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'}]

# %%
genres_1_clean = []

for genres in genres_1:
    try:
        genres_1_clean.append(genres['name'])
    except:
        genres_1_clean.append("?")
        
genres_1_clean
# Out:
# ['Documentary',
#  'Horror',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Horror',
#  'Action',
#  'Mystery',
#  'Comedy',
#  'Action',
#  'Music',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Documentary',
#  'Adventure',
#  'Horror',
#  'Comedy',
#  'Comedy',
#  'Thriller',
#  'Comedy',
#  'Thriller',
#  'Comedy',
#  'Comedy',
#  'Documentary',
#  'Horror',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Fantasy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Thriller',
#  'Documentary',
#  'Thriller',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'History',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Animation',
#  'Romance',
#  'Documentary',
#  'Science Fiction',
#  'Western',
#  'Comedy',
#  'Horror',
#  'Family',
#  'Drama',
#  'Thriller',
#  'Horror',
#  'Horror',
#  'Comedy',
#  'Family',
#  'Drama',
#  'Family',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Science Fiction',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Animation',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Documentary',
#  'Action',
#  'Comedy',
#  'Thriller',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Science Fiction',
#  'Comedy',
#  'Comedy',
#  'Science Fiction',
#  'Animation',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Thriller',
#  'Thriller',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Horror',
#  'Horror',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Mystery',
#  'Action',
#  'Music',
#  'Thriller',
#  'Horror',
#  'Comedy',
#  '?',
#  'Romance',
#  'Animation',
#  'Documentary',
#  'Romance',
#  'Comedy',
#  'Action',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Family',
#  'Crime',
#  'Thriller',
#  'Crime',
#  'Family',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Mystery',
#  'Thriller',
#  'Animation',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Fantasy',
#  'Comedy',
#  'Thriller',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Science Fiction',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Horror',
#  'Documentary',
#  'Romance',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Thriller',
#  'Science Fiction',
#  'Thriller',
#  'Action',
#  'Family',
#  'Comedy',
#  'Horror',
#  'Drama',
#  'Action',
#  'Romance',
#  'Romance',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Romance',
#  'Drama',
#  'Western',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Crime',
#  'Romance',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Family',
#  'Action',
#  'Fantasy',
#  'Fantasy',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Science Fiction',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Romance',
#  'Comedy',
#  'Documentary',
#  'Mystery',
#  'Comedy',
#  '?',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Romance',
#  'Romance',
#  'Romance',
#  'Comedy',
#  'Action',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Family',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Documentary',
#  'Romance',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Crime',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Mystery',
#  'Animation',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'Crime',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Action',
#  'Documentary',
#  'Science Fiction',
#  'Thriller',
#  'Horror',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'War',
#  'Music',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Science Fiction',
#  'Documentary',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Animation',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Animation',
#  'Action',
#  'Animation',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Action',
#  'Animation',
#  'Thriller',
#  'Action',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Romance',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'War',
#  'Horror',
#  'Animation',
#  'Animation',
#  'Science Fiction',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Adventure',
#  'Family',
#  'Documentary',
#  'Romance',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Thriller',
#  'Comedy',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Documentary',
#  'Mystery',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Drama',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Documentary',
#  'Animation',
#  'Documentary',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Animation',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Crime',
#  'Action',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Animation',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Horror',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'History',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Romance',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Crime',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Mystery',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Action',
#  'Romance',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  '?',
#  'Music',
#  'Documentary',
#  'Music',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Animation',
#  'Animation',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Action',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'Crime',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'War',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'War',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Crime',
#  'Documentary',
#  'Animation',
#  'Documentary',
#  'Family',
#  'Documentary',
#  'Documentary',
#  'Crime',
#  'Comedy',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Comedy',
#  'Family',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'History',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Animation',
#  'Documentary',
#  'Documentary',
#  'Music',
#  'Music',
#  'Documentary',
#  'Music',
#  'Documentary',
#  'Documentary']

# %%
data_df["genre_1"] = genres_1_clean

data_df.head()
# Out:
#                                               genres     imdb_id  \
# 0                [{'id': 99, 'name': 'Documentary'}]  tt10662450
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...  tt12536776
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...  tt11385066
# 3                     [{'id': 35, 'name': 'Comedy'}]  tt15523050
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...  tt14391622
#
#                                             overview  \
# 0  What is anime? Through deep-dives with notable...
# 1  In search of his sister, a renegade criminal s...
# 2  Loving girlfriend, family fortune, breakout mo...
# 3  Rap superstar Saweetie hosts a celebration of ...
# 4  Set in the 1980s, Tolani Ajao is a bank secret...
#
#                                 production_countries  vote_average  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...           5.8
# 1                                                 []           4.4
# 2            [{'iso_3166_1': 'IT', 'name': 'Italy'}]           2.8
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...           2.7
# 4                                                 []           4.7
#
#    vote_count            title   original_title      genre_1
# 0          51  Enter the Anime  Enter the Anime  Documentary
# 1          25      Dark Forces      Fuego negro       Horror
# 2         105          The App          The App        Drama
# 3           3    Sex: Unzipped    Sex: Unzipped       Comedy
# 4           3          Swallow          Swallow        Drama

# %%
# Build second genre column
genres_2 = []
for genre in data_df["genres"]:
    try:
        genres_2.append(genre[1])
    except:
        genres_2.append("?")
        
genres_2
# Out:
# ['?',
#  {'id': 28, 'name': 'Action'},
#  {'id': 878, 'name': 'Science Fiction'},
#  '?',
#  {'id': 36, 'name': 'History'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 37, 'name': 'Western'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  {'id': 9648, 'name': 'Mystery'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 28, 'name': 'Action'},
#  '?',
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 28, 'name': 'Action'},
#  '?',
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 878, 'name': 'Science Fiction'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 28, 'name': 'Action'},
#  '?',
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 9648, 'name': 'Mystery'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  '?',
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 9648, 'name': 'Mystery'},
#  '?',
#  '?',
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 28, 'name': 'Action'},
#  '?',
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 27, 'name': 'Horror'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  '?',
#  '?',
#  '?',
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  {'id': 878, 'name': 'Science Fiction'},
#  '?',
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 12, 'name': 'Adventure'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  '?',
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10751, 'name': 'Family'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 36, 'name': 'History'},
#  {'id': 37, 'name': 'Western'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 27, 'name': 'Horror'},
#  '?',
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  {'id': 27, 'name': 'Horror'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  '?',
#  '?',
#  {'id': 28, 'name': 'Action'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 14, 'name': 'Fantasy'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 36, 'name': 'History'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 36, 'name': 'History'},
#  '?',
#  '?',
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 36, 'name': 'History'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  '?',
#  '?',
#  {'id': 36, 'name': 'History'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 12, 'name': 'Adventure'},
#  '?',
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 16, 'name': 'Animation'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 36, 'name': 'History'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  '?',
#  {'id': 36, 'name': 'History'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 9648, 'name': 'Mystery'},
#  '?',
#  {'id': 10770, 'name': 'TV Movie'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 36, 'name': 'History'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 36, 'name': 'History'},
#  {'id': 10752, 'name': 'War'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  {'id': 10752, 'name': 'War'},
#  '?',
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  {'id': 16, 'name': 'Animation'},
#  '?',
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  '?',
#  '?',
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 10752, 'name': 'War'},
#  '?',
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  '?',
#  '?',
#  {'id': 16, 'name': 'Animation'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'id': 80, 'name': 'Crime'},
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  '?',
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 99, 'name': 'Documentary'},
#  '?',
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 10402, 'name': 'Music'},
#  '?']

# %%
genres_2_clean = []

for genres in genres_2:
    try:
        genres_2_clean.append(genres['name'])
    except:
        genres_2_clean.append("?")
        
genres_2_clean
# Out:
# ['?',
#  'Action',
#  'Science Fiction',
#  '?',
#  'History',
#  'Thriller',
#  'Drama',
#  'Thriller',
#  'Thriller',
#  '?',
#  'Crime',
#  'Western',
#  '?',
#  'Thriller',
#  'Drama',
#  '?',
#  'Family',
#  'Mystery',
#  '?',
#  'Drama',
#  '?',
#  'Action',
#  '?',
#  '?',
#  'Romance',
#  '?',
#  '?',
#  'Thriller',
#  '?',
#  'Thriller',
#  '?',
#  'Thriller',
#  'Thriller',
#  '?',
#  'Adventure',
#  'Romance',
#  'Comedy',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  'Thriller',
#  '?',
#  '?',
#  'Fantasy',
#  '?',
#  'Music',
#  'Thriller',
#  'Action',
#  '?',
#  'Fantasy',
#  'Action',
#  'Comedy',
#  '?',
#  '?',
#  'Comedy',
#  'Crime',
#  '?',
#  'Crime',
#  'Science Fiction',
#  '?',
#  'Thriller',
#  'Thriller',
#  '?',
#  'Comedy',
#  'Comedy',
#  'Animation',
#  'Thriller',
#  'Horror',
#  'Romance',
#  '?',
#  'Romance',
#  'Thriller',
#  '?',
#  'Romance',
#  'Fantasy',
#  'Family',
#  'Romance',
#  'Action',
#  '?',
#  '?',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Romance',
#  'Drama',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'Adventure',
#  'Adventure',
#  'Mystery',
#  '?',
#  'Drama',
#  'Music',
#  'Drama',
#  '?',
#  '?',
#  '?',
#  'Music',
#  '?',
#  '?',
#  'Horror',
#  'Romance',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Thriller',
#  'Romance',
#  '?',
#  'Comedy',
#  '?',
#  '?',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  '?',
#  'Comedy',
#  'Romance',
#  'Romance',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Fantasy',
#  'Drama',
#  '?',
#  'Drama',
#  'Family',
#  '?',
#  'Fantasy',
#  'Romance',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Music',
#  'Music',
#  '?',
#  'Romance',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  'Crime',
#  'Crime',
#  '?',
#  '?',
#  'Romance',
#  'Mystery',
#  'Crime',
#  '?',
#  'Drama',
#  '?',
#  'Science Fiction',
#  'Romance',
#  '?',
#  'Drama',
#  'Drama',
#  'Crime',
#  '?',
#  'Comedy',
#  'Thriller',
#  'Crime',
#  'Comedy',
#  'Horror',
#  'Music',
#  'Drama',
#  'Romance',
#  'Romance',
#  'Mystery',
#  '?',
#  '?',
#  'Mystery',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  '?',
#  '?',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Mystery',
#  'Family',
#  'Horror',
#  '?',
#  'Thriller',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Comedy',
#  '?',
#  'Romance',
#  'Family',
#  'Romance',
#  '?',
#  '?',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Crime',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'TV Movie',
#  'Romance',
#  'Romance',
#  '?',
#  '?',
#  'Comedy',
#  'Horror',
#  'Fantasy',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Romance',
#  'Comedy',
#  '?',
#  'Family',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Crime',
#  '?',
#  'Thriller',
#  'Music',
#  'Drama',
#  'Adventure',
#  'Drama',
#  'Action',
#  '?',
#  '?',
#  '?',
#  'Fantasy',
#  '?',
#  '?',
#  'Comedy',
#  '?',
#  '?',
#  'Thriller',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Mystery',
#  'Music',
#  'Drama',
#  '?',
#  'Comedy',
#  '?',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Comedy',
#  '?',
#  '?',
#  'Science Fiction',
#  '?',
#  'Fantasy',
#  'Thriller',
#  'Music',
#  'Drama',
#  '?',
#  'Comedy',
#  '?',
#  'Mystery',
#  'Comedy',
#  '?',
#  'Thriller',
#  'Romance',
#  'Comedy',
#  'Adventure',
#  '?',
#  'Thriller',
#  '?',
#  '?',
#  '?',
#  'Family',
#  'Thriller',
#  'Drama',
#  'Action',
#  'Horror',
#  'Romance',
#  'Drama',
#  'Thriller',
#  '?',
#  '?',
#  '?',
#  'Science Fiction',
#  'Family',
#  '?',
#  'Crime',
#  'Thriller',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  'Comedy',
#  '?',
#  'Mystery',
#  'Romance',
#  'Thriller',
#  'Animation',
#  'Action',
#  'Comedy',
#  'Thriller',
#  'Thriller',
#  '?',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Crime',
#  '?',
#  'Comedy',
#  'History',
#  'Western',
#  'Music',
#  'Action',
#  'Drama',
#  'Drama',
#  '?',
#  '?',
#  'Music',
#  'Documentary',
#  '?',
#  'Crime',
#  '?',
#  'Thriller',
#  'Crime',
#  'Comedy',
#  'Romance',
#  'Crime',
#  'Crime',
#  '?',
#  'Drama',
#  'Action',
#  'Action',
#  'Documentary',
#  'Comedy',
#  '?',
#  '?',
#  'Romance',
#  'Crime',
#  '?',
#  '?',
#  'Documentary',
#  'Thriller',
#  '?',
#  '?',
#  '?',
#  'Comedy',
#  '?',
#  'Romance',
#  'Romance',
#  'Adventure',
#  'Drama',
#  '?',
#  'Documentary',
#  '?',
#  'Music',
#  'Crime',
#  'Family',
#  'Crime',
#  'Romance',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Thriller',
#  'Comedy',
#  'Mystery',
#  'Crime',
#  '?',
#  'Music',
#  'Music',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Family',
#  'Science Fiction',
#  'Thriller',
#  'Romance',
#  'Comedy',
#  'Romance',
#  'Crime',
#  'Fantasy',
#  '?',
#  'Drama',
#  'Fantasy',
#  '?',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  '?',
#  'Horror',
#  '?',
#  '?',
#  'Thriller',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  'Romance',
#  'Romance',
#  'Fantasy',
#  '?',
#  'Horror',
#  '?',
#  'Music',
#  'Documentary',
#  'Fantasy',
#  '?',
#  'Drama',
#  '?',
#  'Thriller',
#  'Crime',
#  '?',
#  '?',
#  '?',
#  'Action',
#  '?',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  '?',
#  'Comedy',
#  '?',
#  'Drama',
#  'Family',
#  'Drama',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Drama',
#  '?',
#  '?',
#  'Romance',
#  '?',
#  'Music',
#  '?',
#  'Drama',
#  'Fantasy',
#  'Comedy',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Fantasy',
#  '?',
#  'Music',
#  'History',
#  '?',
#  'Thriller',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  'History',
#  '?',
#  '?',
#  '?',
#  'Comedy',
#  '?',
#  '?',
#  'Drama',
#  'History',
#  '?',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Music',
#  'Crime',
#  '?',
#  'Music',
#  'Crime',
#  'Comedy',
#  '?',
#  '?',
#  '?',
#  'History',
#  'Drama',
#  '?',
#  'Romance',
#  'Music',
#  '?',
#  'Adventure',
#  '?',
#  'Thriller',
#  'Music',
#  '?',
#  'Animation',
#  'Crime',
#  '?',
#  'Documentary',
#  '?',
#  'Documentary',
#  'Music',
#  '?',
#  '?',
#  'Music',
#  'Music',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'Family',
#  'Family',
#  'Music',
#  'History',
#  '?',
#  'Music',
#  '?',
#  '?',
#  'Romance',
#  '?',
#  'History',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Crime',
#  'Music',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'TV Movie',
#  'Music',
#  '?',
#  'Mystery',
#  '?',
#  'TV Movie',
#  '?',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Comedy',
#  '?',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Music',
#  '?',
#  'History',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  'History',
#  'War',
#  '?',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Crime',
#  '?',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'Music',
#  'Music',
#  '?',
#  '?',
#  'Mystery',
#  'Drama',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Music',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Documentary',
#  '?',
#  'Crime',
#  'Documentary',
#  'Music',
#  '?',
#  'Music',
#  '?',
#  'War',
#  '?',
#  '?',
#  'Crime',
#  '?',
#  'Family',
#  'Animation',
#  '?',
#  'Comedy',
#  'Drama',
#  '?',
#  'Drama',
#  '?',
#  '?',
#  'Documentary',
#  'Music',
#  '?',
#  '?',
#  'Romance',
#  'War',
#  '?',
#  '?',
#  'Documentary',
#  '?',
#  '?',
#  '?',
#  'Animation',
#  'Drama',
#  'Drama',
#  'Crime',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Crime',
#  '?',
#  'Family',
#  '?',
#  '?',
#  'Documentary',
#  'Documentary',
#  '?',
#  'Documentary',
#  'Music',
#  '?']

# %%
data_df["genre_2"] = genres_2_clean

# %%
# Drop genres column
data_df.drop(columns = "genres", inplace = True)
data_df.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10662450  What is anime? Through deep-dives with notable...
# 1  tt12536776  In search of his sister, a renegade criminal s...
# 2  tt11385066  Loving girlfriend, family fortune, breakout mo...
# 3  tt15523050  Rap superstar Saweetie hosts a celebration of ...
# 4  tt14391622  Set in the 1980s, Tolani Ajao is a bank secret...
#
#                                 production_countries  vote_average  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...           5.8
# 1                                                 []           4.4
# 2            [{'iso_3166_1': 'IT', 'name': 'Italy'}]           2.8
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...           2.7
# 4                                                 []           4.7
#
#    vote_count            title   original_title      genre_1          genre_2
# 0          51  Enter the Anime  Enter the Anime  Documentary                ?
# 1          25      Dark Forces      Fuego negro       Horror           Action
# 2         105          The App          The App        Drama  Science Fiction
# 3           3    Sex: Unzipped    Sex: Unzipped       Comedy                ?
# 4           3          Swallow          Swallow        Drama          History

# %%
# Build first production country column
country_1 = []
for country in data_df["production_countries"]:
    try:
        country_1.append(country[0])
    except:
        country_1.append("?")
        
country_1
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  '?',
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MY', 'name': 'Malaysia'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'PH', 'name': 'Philippines'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'TH', 'name': 'Thailand'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'SE', 'name': 'Sweden'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'CL', 'name': 'Chile'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'RO', 'name': 'Romania'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'PH', 'name': 'Philippines'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'NG', 'name': 'Nigeria'},
#  {'iso_3166_1': 'SE', 'name': 'Sweden'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'SE', 'name': 'Sweden'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'CO', 'name': 'Colombia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'TH', 'name': 'Thailand'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'NG', 'name': 'Nigeria'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'AT', 'name': 'Austria'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'PH', 'name': 'Philippines'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AL', 'name': 'Albania'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AU', 'name': 'Australia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AL', 'name': 'Albania'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'NG', 'name': 'Nigeria'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'AU', 'name': 'Australia'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AE', 'name': 'United Arab Emirates'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CN', 'name': 'China'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'CL', 'name': 'Chile'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'SE', 'name': 'Sweden'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'TH', 'name': 'Thailand'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GE', 'name': 'Georgia'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'IE', 'name': 'Ireland'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'IS', 'name': 'Iceland'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CN', 'name': 'China'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'DK', 'name': 'Denmark'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IE', 'name': 'Ireland'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'JP', 'name': 'Japan'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AR', 'name': 'Argentina'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ID', 'name': 'Indonesia'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'KH', 'name': 'Cambodia'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'AU', 'name': 'Australia'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IE', 'name': 'Ireland'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'CN', 'name': 'China'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'PK', 'name': 'Pakistan'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'EG', 'name': 'Egypt'},
#  '?',
#  {'iso_3166_1': 'CL', 'name': 'Chile'},
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'SG', 'name': 'Singapore'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'CD', 'name': 'Congo'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'SY', 'name': 'Syrian Arab Republic'},
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CZ', 'name': 'Czech Republic'},
#  {'iso_3166_1': 'GH', 'name': 'Ghana'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'AT', 'name': 'Austria'},
#  {'iso_3166_1': 'PL', 'name': 'Poland'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CU', 'name': 'Cuba'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'}]

# %%
country_1_clean = []

for country in country_1:
    try:
        country_1_clean.append(country['name'])
    except:
        country_1_clean.append("?")
        
country_1_clean
# Out:
# ['United States of America',
#  '?',
#  'Italy',
#  'United States of America',
#  '?',
#  'United States of America',
#  'India',
#  'India',
#  '?',
#  'Turkey',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  'Poland',
#  'India',
#  'India',
#  'Canada',
#  'United States of America',
#  'Mexico',
#  'Indonesia',
#  'United States of America',
#  'Malaysia',
#  'Germany',
#  'South Africa',
#  'United States of America',
#  'Mexico',
#  'India',
#  'United Kingdom',
#  'South Korea',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'United States of America',
#  'Netherlands',
#  'France',
#  'South Africa',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'United States of America',
#  'Italy',
#  'France',
#  'Brazil',
#  'France',
#  '?',
#  'Italy',
#  'France',
#  'Philippines',
#  'United States of America',
#  'Japan',
#  'South Africa',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'Germany',
#  'Belgium',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'Poland',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Canada',
#  'Belgium',
#  'Spain',
#  'Poland',
#  'United States of America',
#  'Indonesia',
#  'Canada',
#  'United States of America',
#  'South Africa',
#  'Argentina',
#  'South Korea',
#  'Indonesia',
#  'United States of America',
#  'United States of America',
#  'Netherlands',
#  'Poland',
#  'Brazil',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  '?',
#  'Canada',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Germany',
#  'Thailand',
#  'United States of America',
#  'Sweden',
#  'Canada',
#  'Chile',
#  'Spain',
#  'France',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'Argentina',
#  'Romania',
#  'Germany',
#  '?',
#  'United States of America',
#  '?',
#  'United States of America',
#  'Indonesia',
#  'Spain',
#  'France',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'United States of America',
#  'France',
#  'United States of America',
#  'Netherlands',
#  'United States of America',
#  'India',
#  'Spain',
#  'Canada',
#  'United States of America',
#  'United States of America',
#  'Germany',
#  'Brazil',
#  'South Korea',
#  'India',
#  'Japan',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  'Philippines',
#  'India',
#  '?',
#  'United Kingdom',
#  'Germany',
#  'Nigeria',
#  'Sweden',
#  'Japan',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Sweden',
#  'Brazil',
#  'Brazil',
#  'United Kingdom',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  '?',
#  'United States of America',
#  'Italy',
#  'Turkey',
#  'Colombia',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Spain',
#  'United States of America',
#  'United States of America',
#  'Spain',
#  'United States of America',
#  'Poland',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'Thailand',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Nigeria',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'India',
#  'United States of America',
#  'India',
#  'Mexico',
#  'South Africa',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Austria',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Belgium',
#  'Spain',
#  'United States of America',
#  'Canada',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Canada',
#  'Brazil',
#  'Germany',
#  'United States of America',
#  'Canada',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'Philippines',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'United States of America',
#  'France',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  '?',
#  'Italy',
#  'United States of America',
#  'United States of America',
#  'Japan',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  '?',
#  'India',
#  'United States of America',
#  'Albania',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'Argentina',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Australia',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Albania',
#  'France',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Germany',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Indonesia',
#  'Turkey',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'Italy',
#  'Spain',
#  'Nigeria',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Indonesia',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Germany',
#  'United Kingdom',
#  'United States of America',
#  'Turkey',
#  'Belgium',
#  'Japan',
#  'France',
#  'France',
#  'Australia',
#  'Indonesia',
#  'United States of America',
#  'Belgium',
#  'Brazil',
#  'United States of America',
#  'United Kingdom',
#  'India',
#  'United States of America',
#  'United Arab Emirates',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'Canada',
#  'United Kingdom',
#  'Argentina',
#  'Germany',
#  'United Kingdom',
#  'United States of America',
#  'Canada',
#  'United States of America',
#  'United States of America',
#  'Japan',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'South Korea',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  '?',
#  'United States of America',
#  'France',
#  'United States of America',
#  'France',
#  'United States of America',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'United States of America',
#  'Germany',
#  'United States of America',
#  'Indonesia',
#  'United States of America',
#  'China',
#  'Mexico',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Japan',
#  'Germany',
#  'United States of America',
#  'France',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  '?',
#  'United States of America',
#  'Canada',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'United States of America',
#  'France',
#  'United States of America',
#  'India',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Japan',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Spain',
#  'Germany',
#  'Chile',
#  'United Kingdom',
#  'United States of America',
#  'Sweden',
#  '?',
#  'United States of America',
#  'Indonesia',
#  'United States of America',
#  'United Kingdom',
#  'Netherlands',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Poland',
#  'Canada',
#  'United States of America',
#  'Spain',
#  'Spain',
#  'India',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'South Korea',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Canada',
#  'Argentina',
#  'United States of America',
#  'Thailand',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Mexico',
#  'Japan',
#  'India',
#  'Japan',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'South Korea',
#  'Japan',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'Spain',
#  'Turkey',
#  'South Korea',
#  'United States of America',
#  'India',
#  'Mexico',
#  'Italy',
#  'United States of America',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Georgia',
#  'France',
#  'Mexico',
#  'Ireland',
#  'United Kingdom',
#  'France',
#  'India',
#  'United States of America',
#  'United States of America',
#  'France',
#  'United Kingdom',
#  'Iceland',
#  'Spain',
#  'United States of America',
#  'Argentina',
#  'United States of America',
#  'China',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Denmark',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  'France',
#  'India',
#  'India',
#  '?',
#  'United States of America',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Indonesia',
#  'United States of America',
#  'Netherlands',
#  'United States of America',
#  'United States of America',
#  '?',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  '?',
#  'Italy',
#  'United Kingdom',
#  'United States of America',
#  'Ireland',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Japan',
#  '?',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United Kingdom',
#  'Argentina',
#  'United Kingdom',
#  'United States of America',
#  'Argentina',
#  'Belgium',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Indonesia',
#  'Canada',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  '?',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'Cambodia',
#  'India',
#  'United States of America',
#  'United States of America',
#  'Canada',
#  'India',
#  'United States of America',
#  'Canada',
#  'India',
#  'Brazil',
#  'Australia',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  'United States of America',
#  'Ireland',
#  'Spain',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'South Korea',
#  'United States of America',
#  '?',
#  'China',
#  'Mexico',
#  'United States of America',
#  'United States of America',
#  'Pakistan',
#  '?',
#  '?',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'Egypt',
#  '?',
#  'Chile',
#  'Italy',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Singapore',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Canada',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'South Korea',
#  'Congo',
#  'United States of America',
#  'United States of America',
#  'Syrian Arab Republic',
#  'Germany',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'India',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United Kingdom',
#  'India',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Czech Republic',
#  'Ghana',
#  '?',
#  'United States of America',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Brazil',
#  'United States of America',
#  'United Kingdom',
#  'United States of America',
#  'United States of America',
#  'Austria',
#  'Poland',
#  'United Kingdom',
#  'South Africa',
#  'United States of America',
#  'United States of America',
#  'United States of America',
#  'Mexico',
#  'United States of America',
#  'Spain',
#  'United States of America',
#  'Cuba',
#  'United States of America',
#  'United States of America',
#  'United Kingdom',
#  '?',
#  'Brazil',
#  'United Kingdom']

# %%
data_df["country_1"] = country_1_clean

data_df.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10662450  What is anime? Through deep-dives with notable...
# 1  tt12536776  In search of his sister, a renegade criminal s...
# 2  tt11385066  Loving girlfriend, family fortune, breakout mo...
# 3  tt15523050  Rap superstar Saweetie hosts a celebration of ...
# 4  tt14391622  Set in the 1980s, Tolani Ajao is a bank secret...
#
#                                 production_countries  vote_average  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...           5.8
# 1                                                 []           4.4
# 2            [{'iso_3166_1': 'IT', 'name': 'Italy'}]           2.8
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...           2.7
# 4                                                 []           4.7
#
#    vote_count            title   original_title      genre_1          genre_2  \
# 0          51  Enter the Anime  Enter the Anime  Documentary                ?
# 1          25      Dark Forces      Fuego negro       Horror           Action
# 2         105          The App          The App        Drama  Science Fiction
# 3           3    Sex: Unzipped    Sex: Unzipped       Comedy                ?
# 4           3          Swallow          Swallow        Drama          History
#
#                   country_1
# 0  United States of America
# 1                         ?
# 2                     Italy
# 3  United States of America
# 4                         ?

# %%
# Build second production country column
country_2 = []
for country in data_df["production_countries"]:
    try:
        country_2.append(country[1])
    except:
        country_2.append("?")
        
country_2
# Out:
# [{'iso_3166_1': 'JP', 'name': 'Japan'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'PE', 'name': 'Peru'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  {'iso_3166_1': 'IT', 'name': 'Italy'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'JO', 'name': 'Jordan'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'TH', 'name': 'Thailand'},
#  '?',
#  {'iso_3166_1': 'KR', 'name': 'South Korea'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'IQ', 'name': 'Iraq'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  '?',
#  '?',
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'BG', 'name': 'Bulgaria'},
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'IR', 'name': 'Iran'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'NO', 'name': 'Norway'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'IE', 'name': 'Ireland'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'SG', 'name': 'Singapore'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'RS', 'name': 'Serbia'},
#  {'iso_3166_1': 'NL', 'name': 'Netherlands'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'HU', 'name': 'Hungary'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'DE', 'name': 'Germany'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'ZA', 'name': 'South Africa'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'MX', 'name': 'Mexico'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  '?']

# %%
country_2_clean = []

for country in country_2:
    try:
        country_2_clean.append(country['name'])
    except:
        country_2_clean.append("?")
        
country_2_clean
# Out:
# ['Japan',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  'France',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'France',
#  'Mexico',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  'Peru',
#  '?',
#  '?',
#  '?',
#  'Belgium',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Italy',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Italy',
#  'India',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'France',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  'Italy',
#  '?',
#  '?',
#  '?',
#  'Spain',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Jordan',
#  '?',
#  'United States of America',
#  '?',
#  'United Kingdom',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  'Canada',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Spain',
#  '?',
#  '?',
#  '?',
#  'France',
#  'Thailand',
#  '?',
#  'South Korea',
#  '?',
#  '?',
#  '?',
#  'France',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  'United States of America',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Iraq',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'France',
#  '?',
#  'France',
#  '?',
#  '?',
#  'Canada',
#  '?',
#  'United States of America',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  'Bulgaria',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Iran',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  'Norway',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Canada',
#  'Ireland',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Singapore',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Serbia',
#  'Netherlands',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Hungary',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  'Germany',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  'South Africa',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United Kingdom',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'France',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  'Mexico',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  'United States of America',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  '?']

# %%
data_df["country_2"] = country_2_clean

data_df.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10662450  What is anime? Through deep-dives with notable...
# 1  tt12536776  In search of his sister, a renegade criminal s...
# 2  tt11385066  Loving girlfriend, family fortune, breakout mo...
# 3  tt15523050  Rap superstar Saweetie hosts a celebration of ...
# 4  tt14391622  Set in the 1980s, Tolani Ajao is a bank secret...
#
#                                 production_countries  vote_average  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...           5.8
# 1                                                 []           4.4
# 2            [{'iso_3166_1': 'IT', 'name': 'Italy'}]           2.8
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...           2.7
# 4                                                 []           4.7
#
#    vote_count            title   original_title      genre_1          genre_2  \
# 0          51  Enter the Anime  Enter the Anime  Documentary                ?
# 1          25      Dark Forces      Fuego negro       Horror           Action
# 2         105          The App          The App        Drama  Science Fiction
# 3           3    Sex: Unzipped    Sex: Unzipped       Comedy                ?
# 4           3          Swallow          Swallow        Drama          History
#
#                   country_1 country_2
# 0  United States of America     Japan
# 1                         ?         ?
# 2                     Italy         ?
# 3  United States of America         ?
# 4                         ?         ?

# %%
data_df.drop(columns = "production_countries", inplace = True)

data_df.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10662450  What is anime? Through deep-dives with notable...
# 1  tt12536776  In search of his sister, a renegade criminal s...
# 2  tt11385066  Loving girlfriend, family fortune, breakout mo...
# 3  tt15523050  Rap superstar Saweetie hosts a celebration of ...
# 4  tt14391622  Set in the 1980s, Tolani Ajao is a bank secret...
#
#    vote_average  vote_count            title   original_title      genre_1  \
# 0           5.8          51  Enter the Anime  Enter the Anime  Documentary
# 1           4.4          25      Dark Forces      Fuego negro       Horror
# 2           2.8         105          The App          The App        Drama
# 3           2.7           3    Sex: Unzipped    Sex: Unzipped       Comedy
# 4           4.7           3          Swallow          Swallow        Drama
#
#            genre_2                 country_1 country_2
# 0                ?  United States of America     Japan
# 1           Action                         ?         ?
# 2  Science Fiction                     Italy         ?
# 3                ?  United States of America         ?
# 4          History                         ?         ?

# %% [markdown]
# ##### Merge the DataFrames

# %%
df = df.merge(data_df, left_index = True, right_index = True)

df.head()
# Out:
#              Title                  Genre   Premiere  Runtime  IMDB Score  \
# 0  Enter the Anime            Documentary 2019-08-05       58         2.5
# 1      Dark Forces               Thriller 2020-08-21       81         2.6
# 2          The App  Science fiction/Drama 2019-12-26       79         2.6
# 3    Sex: Unzipped                 Comedy 2021-10-26       59         3.1
# 4          Swallow                  Drama 2021-10-01      128         3.2
#
#            Language  premiere_year tmdb_id     imdb_id  \
# 0  English/Japanese           2019  616904  tt10662450
# 1           Spanish           2020  735110  tt12536776
# 2           Italian           2019  653522  tt11385066
# 3           English           2021  890280  tt15523050
# 4           English           2021  874562  tt14391622
#
#                                             overview  vote_average  \
# 0  What is anime? Through deep-dives with notable...           5.8
# 1  In search of his sister, a renegade criminal s...           4.4
# 2  Loving girlfriend, family fortune, breakout mo...           2.8
# 3  Rap superstar Saweetie hosts a celebration of ...           2.7
# 4  Set in the 1980s, Tolani Ajao is a bank secret...           4.7
#
#    vote_count            title   original_title      genre_1          genre_2  \
# 0          51  Enter the Anime  Enter the Anime  Documentary                ?
# 1          25      Dark Forces      Fuego negro       Horror           Action
# 2         105          The App          The App        Drama  Science Fiction
# 3           3    Sex: Unzipped    Sex: Unzipped       Comedy                ?
# 4           3          Swallow          Swallow        Drama          History
#
#                   country_1 country_2
# 0  United States of America     Japan
# 1                         ?         ?
# 2                     Italy         ?
# 3  United States of America         ?
# 4                         ?         ?

# %%
# Save the new dataframe as a checkpoint
# df.to_excel("temporary_netflix_df.xlsx", index = False)

# %% [markdown]
# ##### Data validation

# %%
# Films with different title columns
pd.set_option("display.max_rows", None, "display.max_columns", None)
validate_df = df[df["Title"] != df["title"]]
validate_df.loc[:, ("Title", "Language", "title", "original_title", "country_1")]
# Out:
#                                                  Title         Language  \
# 13           Nobody Sleeps in the Woods Tonight Part 2           Polish
# 16                                            The Call           Korean
# 17                               Escape the Undertaker          English
# 28                           What Happened to Mr. Cha?           Korean
# 30                   Hello Privilege. It's Me, Chelsea          English
# 45    Porta dos Fundos: The First Temptation of Christ       Portuguese
# 58                                                Deep             Thai
# 75                        Trippin' with the Kandasamys          English
# 76                                             Cadaver        Norwegian
# 96                                        #REALITYHIGH          English
# 101  American Factory: A Conversation with the Obamas           English
# 109                                             Grudge          Turkish
# 120                                        Last Summer          Turkish
# 122                                     Back to School           French
# 140                           Freaks: You're One of Us           German
# 159                                            Òlòt?ré          English
# 196                                           One Take             Thai
# 241                                                TAU          English
# 252  Notes from Dunblane: Lesson from a School Shoo...          English
# 258                                        The Decline           French
# 293                   Attack of The Hollywood Clichés!          English
# 296                      Tribhanga  Tedhi Medhi Crazy            Hindi
# 300                                         The Killer       Portuguese
# 301                               Tersanjung the Movie       Indonesian
# 314                                            Voyuer           English
# 317                                    Roxanne Roxanne          English
# 318                           Fear Street Part 1: 1994          English
# 321                 Octonauts & the Caves of Sac Actun          English
# 333                                            Apostle          English
# 358                Porta dos Fundos: The Last Hangover       Portuguese
# 364               Ariana Grande: Excuse Me, I Love You          English
# 374                               Como Caído del Cielo          Spanish
# 378            Sturgill Simpson Presents: Sound & Fury          English
# 383                                  Britney vs Spears          English
# 389                                       The Occupant          Spanish
# 402                                            Canvas           English
# 406                                  What Did Jack Do?          English
# 409                                            Monster          English
# 431                           Fear Street Part 3: 1666          English
# 442                 Hope Frozen: A Quest to Live Twice     Thia/English
# 452                                      CounterPunch           English
# 456  Michael Bolton's Big, Sexy, Valentine's Day Sp...          English
# 457                           Fear Street Part 2: 1978          English
# 464                           Parchis: The Documentary          Spanish
# 475                                         Heroin(e)           English
# 480        Private Network: Who Killed Manuel Buendia?          Spanish
# 484                               Long Live Brij Mohan            Hindi
# 490                                             7 años          Spanish
# 491           Blood Brothers: Malcolm X & Muhammad Ali          English
# 507                       Bigflo & Oil: Hip Hop Frenzy           French
# 510                  ReMastered: Who Shot the Sheriff?          English
# 526  I'm No Longer Here: A Discussion with Guillerm...          English
# 528                         Lorena, Light-Footed Woman          Spanish
# 532                                               Pele          English
# 544              Flip a Coin – One OK Rock Documentary         Japanese
# 553                            El Pepe: A Supreme Life          Spanish
# 567         ReMastered: Tricky Dick & the Man in Black          English
# 571       Fyre: The Greatest Party That Never Happened          English
# 579                            The 40-Year-Old Version          English
# 580                                          Sometimes            Tamil
# 584        The Road to El Camino: A Breaking Bad Movie          English
# 585                                              Zion           English
# 586               Emicida: AmarElo – Live in São Paulo       Portuguese
# 600    Mucho Mucho Amor: The Legend of Walter Mercado   Spanish/English
# 602   The Other One: The Long Strange Trip of Bob Weir          English
# 603                 Octonauts & the Great Barrier Reef          English
# 627        Barbra: The Music, The Mem'ries, The Magic!          English
# 628                        Blackpink: Light Up the Sky           Korean
# 630                     Homecoming: A Film by Beyonce           English
# 637                John Mulaney & the Sack Lunch Bunch          English
# 638                     Invader Zim: Enter the Florpus          English
# 647  Rolling Thunder Revue: A bob Dylan Story by Ma...          English
# 652                   Brene Brown: The Call to Courage          English
# 657  Jim & Andy: The Great Beyond - Featuring a Ver...          English
# 667       Struggle: The Life and Lost Art of Szukaiski          English
# 670                                     Chasing Coral           English
# 674                  Disclosure: Trans Lives on Screen          English
# 677                            Cuba and the Cameraman           English
# 681                            Springsteen on Broadway          English
# 682          Emicida: AmarElo - It's All For Yesterday       Portuguese
#
#                                                  title  \
# 13                Nobody Sleeps in the Woods Tonight 2
# 16                                The Call of the Wild
# 17                               Escape The Undertaker
# 28                            What Happened to Mr Cha?
# 30                  Hello, Privilege. It's Me, Chelsea
# 45                      The First Temptation of Christ
# 58                                      The Deep House
# 75                        Trippin’ with the Kandasamys
# 76                                        The Unburied
# 96                                        #realityhigh
# 101   American Factory: A Conversation with the Obamas
# 109                                         The Grudge
# 120                         Last Summer with Uncle Ira
# 122                      Super Monsters Back to School
# 140                          Freaks – You're One of Us
# 159                                            Òlòtūré
# 196                                    BNK48: One Take
# 241                                                Tau
# 252  Notes from Dunblane: Lessons from a School Sho...
# 258                NOFX: The Decline Live At Red Rocks
# 293                   Attack of the Hollywood Clichés!
# 296                                          Tribhanga
# 300                        Attack of the Killer Donuts
# 301                              Tersanjung: The Movie
# 314                                             Voyeur
# 317                                   Roxanne, Roxanne
# 318                                  Fear Street: 1994
# 321               Octonauts and the Caves of Sac Actun
# 333                            Paul, Apostle of Christ
# 358                                  The Last Hangover
# 364               ariana grande: excuse me, i love you
# 374                          Out Of The Clear Blue Sky
# 378             Sturgill Simpson Presents Sound & Fury
# 383                                 Britney vs. Spears
# 389                               The Current Occupant
# 402                                             Canvas
# 406                                  WHAT DID JACK DO?
# 409                                     Monster Hunter
# 431                                  Fear Street: 1666
# 442                                        Hope Frozen
# 452                                       Counterpunch
# 456  Michael Bolton's Big, Sexy Valentine's Day Spe...
# 457                                  Fear Street: 1978
# 464                           Parchís: the Documentary
# 475                                          Heroin(e)
# 480        Private Network: Who Killed Manuel Buendía?
# 484                              Brij Mohan Amar Rahe!
# 490                                            7 Years
# 491         Blood Brothers: Malcolm X and Muhammad Ali
# 507                       Bigflo & Oli: Hip Hop Frenzy
# 510                   ReMastered: Who Shot the Sheriff
# 526  I’m No Longer Here: A Conversation with Guille...
# 528                         Lorena, Light-footed Woman
# 532                                               Pelé
# 544               Flip a Coin: ONE OK ROCK Documentary
# 553                            El Pepe, A Supreme Life
# 567         ReMastered: Tricky Dick & The Man in Black
# 571                                               Fyre
# 579                         The Forty-Year-Old Version
# 580                            Sometimes the Good Kill
# 584  The Road to El Camino: Behind the Scenes of El...
# 585                                               Zion
# 586                  Emicida AmarElo Live in Sao Paulo
# 600     Mucho Mucho Amor: The Legend of Walter Mercado
# 602  The Other One: The Long, Strange Trip of Bob Weir
# 603               Octonauts and the Great Barrier Reef
# 627  Barbra: The Music ... The Mem'ries ... The Magic!
# 628                        BLACKPINK: Light Up the Sky
# 630                      Homecoming: A Film by Beyoncé
# 637                John Mulaney & The Sack Lunch Bunch
# 638                     Invader ZIM: Enter the Florpus
# 647  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 652                   Brené Brown: The Call to Courage
# 657                            Jim Jefferies: Freedumb
# 667       Struggle: The Life and Lost Art of Szukalski
# 670                                      Chasing Coral
# 674                                         Disclosure
# 677                             Cuba and the Cameraman
# 681                            Springsteen On Broadway
# 682          Emicida: AmarElo - It's All for Yesterday
#
#                                         original_title  \
# 13                      W lesie dziś nie zaśnie nikt 2
# 16                                The Call of the Wild
# 17                               Escape The Undertaker
# 28                                                 차인표
# 30                  Hello, Privilege. It's Me, Chelsea
# 45                       A Primeira Tentação de Cristo
# 58                                      The Deep House
# 75                        Trippin’ with the Kandasamys
# 76                                El cadáver insepulto
# 96                                        #realityhigh
# 101   American Factory: A Conversation with the Obamas
# 109                                         The Grudge
# 120                         Last Summer with Uncle Ira
# 122                      Super Monsters Back to School
# 140                      Freaks – Du bist eine von uns
# 159                                            Òlòtūré
# 196                                    BNK48: One Take
# 241                                                Tau
# 252  Notes from Dunblane: Lessons from a School Sho...
# 258                NOFX: The Decline Live At Red Rocks
# 293                   Attack of the Hollywood Clichés!
# 296                                            त्रिभंग
# 300                        Attack of the Killer Donuts
# 301                              Tersanjung: The Movie
# 314                                             Voyeur
# 317                                   Roxanne, Roxanne
# 318                                  Fear Street: 1994
# 321               Octonauts and the Caves of Sac Actun
# 333                            Paul, Apostle of Christ
# 358               Porta dos Fundos: Se Beber, Não Ceie
# 364               ariana grande: excuse me, i love you
# 374                               Como caído del cielo
# 378             Sturgill Simpson Presents Sound & Fury
# 383                                 Britney vs. Spears
# 389                               The Current Occupant
# 402                                             Canvas
# 406                                  WHAT DID JACK DO?
# 409                                     Monster Hunter
# 431                                  Fear Street: 1666
# 442                                        Hope Frozen
# 452                                       Counterpunch
# 456  Michael Bolton's Big, Sexy Valentine's Day Spe...
# 457                                  Fear Street: 1978
# 464                             Parchís: el documental
# 475                                          Heroin(e)
# 480         Red privada: ¿quién mató a Manuel Buendía?
# 484                                 ब्रिज मोहन अमर रहे
# 490                                             7 años
# 491         Blood Brothers: Malcolm X and Muhammad Ali
# 507                        Bigflo & Oli : Presque Trop
# 510                   ReMastered: Who Shot the Sheriff
# 526  Ya no estoy aquí: Una conversación entre Guill...
# 528                         Lorena, la de pies ligeros
# 532                                               Pelé
# 544               Flip a Coin: ONE OK ROCK Documentary
# 553                          El Pepe, una vida suprema
# 567         ReMastered: Tricky Dick & The Man in Black
# 571                                               Fyre
# 579                         The Forty-Year-Old Version
# 580                            Sometimes the Good Kill
# 584  The Road to El Camino: Behind the Scenes of El...
# 585                                               Zion
# 586                  Emicida AmarElo Live in Sao Paulo
# 600     Mucho Mucho Amor: The Legend of Walter Mercado
# 602  The Other One: The Long, Strange Trip of Bob Weir
# 603               Octonauts and the Great Barrier Reef
# 627  Barbra: The Music ... The Mem'ries ... The Magic!
# 628                                      블랙핑크: 세상을 밝혀라
# 630                      Homecoming: A Film by Beyoncé
# 637                John Mulaney & The Sack Lunch Bunch
# 638                     Invader ZIM: Enter the Florpus
# 647  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 652                   Brené Brown: The Call to Courage
# 657                            Jim Jefferies: Freedumb
# 667       Struggle: The Life and Lost Art of Szukalski
# 670                                      Chasing Coral
# 674                                         Disclosure
# 677                             Cuba and the Cameraman
# 681                            Springsteen On Broadway
# 682                Emicida: AmarElo - É Tudo Pra Ontem
#
#                     country_1
# 13                     Poland
# 16                     Canada
# 17   United States of America
# 28                South Korea
# 30   United States of America
# 45                     Brazil
# 58                    Belgium
# 75               South Africa
# 76                  Argentina
# 96   United States of America
# 101  United States of America
# 109                    Canada
# 120                         ?
# 122                         ?
# 140                   Germany
# 159                   Nigeria
# 196                  Thailand
# 241  United States of America
# 252  United States of America
# 258                         ?
# 293            United Kingdom
# 296                     India
# 300  United States of America
# 301                 Indonesia
# 314  United States of America
# 317  United States of America
# 318  United States of America
# 321            United Kingdom
# 333  United States of America
# 358                    Brazil
# 364  United States of America
# 374                    Mexico
# 378                     Japan
# 383  United States of America
# 389  United States of America
# 402  United States of America
# 406  United States of America
# 409                   Germany
# 431  United States of America
# 442                  Thailand
# 452  United States of America
# 456  United States of America
# 457  United States of America
# 464                     Spain
# 475  United States of America
# 480                    Mexico
# 484                     India
# 490                     Spain
# 491  United States of America
# 507                    France
# 510                         ?
# 526                         ?
# 528                    Mexico
# 532            United Kingdom
# 544                     Japan
# 553                 Argentina
# 567  United States of America
# 571  United States of America
# 579  United States of America
# 580                    Canada
# 584  United States of America
# 585  United States of America
# 586                    Brazil
# 600  United States of America
# 602                         ?
# 603                         ?
# 627  United States of America
# 628               South Korea
# 630  United States of America
# 637  United States of America
# 638  United States of America
# 647  United States of America
# 652                         ?
# 657  United States of America
# 667                    Poland
# 670  United States of America
# 674  United States of America
# 677                      Cuba
# 681                         ?
# 682                    Brazil

# %% [markdown]
# ##### List of movies with problems
# - The Call: 575604
# - Deep: 430474
# - Cadaver: 692969
# - Grudge: 874948
# - Last Summer: 785537
# - Back to School: 624060
# - The Decline: 674607
# - The Killer: 466190
# - The Occupant: 674944
# - Monster: 489932
# - Sometimes: 411852
# - John Mulaney & the Sack Lunch Bunch: 650073
# - Jim & Andy: The Great Beyond - Featuring a Very Special, Contractually Obligated Mention of Tony Cliffton: 469019

# %%
# Replace the correct id's
ids_to_correct = [16, 58, 76, 109, 120, 122, 258, 300, 389, 409, 580, 637, 657]
id_list_2 = [575604, 430474, 692969, 874948, 785537, 624060, 674607, 466190, 674944, 489932, 411852, 650073, 469019]
pack_2 = zip(ids_to_correct, id_list_2)

for x in pack_2:
    df.iloc[x[0], 7] = x[1]
    
df.iloc[ids_to_correct, :]
# Out:
#                                                  Title            Genre  \
# 16                                            The Call            Drama
# 58                                                Deep  Science fiction
# 76                                             Cadaver           Horror
# 109                                             Grudge         Thriller
# 120                                        Last Summer   Romantic drama
# 122                                     Back to School           Comedy
# 258                                        The Decline         Thriller
# 300                                         The Killer          Western
# 389                                       The Occupant         Thriller
# 409                                            Monster            Drama
# 580                                          Sometimes            Drama
# 637                John Mulaney & the Sack Lunch Bunch     Variety show
# 657  Jim & Andy: The Great Beyond - Featuring a Ver...      Documentary
#
#       Premiere  Runtime  IMDB Score    Language  premiere_year tmdb_id  \
# 16  2020-11-27      112         4.1      Korean           2020  575604
# 58  2021-07-16      101         4.8        Thai           2021  430474
# 76  2020-10-22       86         5.1   Norwegian           2020  692969
# 109 2021-10-08      105         5.3     Turkish           2021  874948
# 120 2021-07-09      101         5.3     Turkish           2021  785537
# 122 2019-08-30       83         5.3      French           2019  624060
# 258 2020-03-27       83         5.9      French           2020  674607
# 300 2017-11-10       99         6.1  Portuguese           2017  466190
# 389 2020-03-25      103         6.4     Spanish           2020  674944
# 409 2021-05-07       98         6.5     English           2021  489932
# 580 2018-05-01      101         7.2       Tamil           2018  411852
# 637 2019-12-24       70         7.5     English           2019  650073
# 657 2017-11-17       94         7.7     English           2017  469019
#
#         imdb_id                                           overview  \
# 16    tt7504726  Buck is a big-hearted dog whose blissful domes...
# 58   tt11686490  While diving in a remote French lake, a couple...
# 76         None  Maximiliano is a psychiatrist who suffers from...
# 109   tt3612126  After a young mother murders her family in her...
# 120  tt11864226  Westchester, Summer 1991. Closeted teenager Da...
# 122  tt10687588  The Super Monsters welcome Vida to her new hom...
# 258        None  NOFX perform The Decline live with Baz's Orche...
# 300   tt4480398  A chemical accident turns ordinary donuts into...
# 389  tt11629124  Trapped in a mysterious psychiatric ward, a ma...
# 409   tt6475714  A portal transports Cpt. Artemis and an elite ...
# 580   tt6184244  After a mysterious death at the Abbey, Sister ...
# 637  tt11318624  John Mulaney and his kid pals tackle existenti...
# 657   tt5849950  Returning for a second Netflix comedy special,...
#
#      vote_average  vote_count                                title  \
# 16            7.6        2678                 The Call of the Wild
# 58            5.5         116                       The Deep House
# 76            4.5           6                         The Unburied
# 109           5.6         852                           The Grudge
# 120           0.0           0           Last Summer with Uncle Ira
# 122           6.5           2        Super Monsters Back to School
# 258           0.0           0  NOFX: The Decline Live At Red Rocks
# 300           4.2          79          Attack of the Killer Donuts
# 389           5.7          16                 The Current Occupant
# 409           6.9        2241                       Monster Hunter
# 580           5.3          16              Sometimes the Good Kill
# 637           7.1          73  John Mulaney & The Sack Lunch Bunch
# 657           7.5          97              Jim Jefferies: Freedumb
#
#                           original_title    genre_1  genre_2  \
# 16                  The Call of the Wild  Adventure   Family
# 58                        The Deep House     Horror        ?
# 76                  El cadáver insepulto     Horror  Fantasy
# 109                           The Grudge     Horror  Mystery
# 120           Last Summer with Uncle Ira          ?        ?
# 122        Super Monsters Back to School  Animation        ?
# 258  NOFX: The Decline Live At Red Rocks          ?        ?
# 300          Attack of the Killer Donuts     Comedy   Horror
# 389                 The Current Occupant   Thriller  Mystery
# 409                       Monster Hunter     Action  Fantasy
# 580              Sometimes the Good Kill   Thriller    Drama
# 637  John Mulaney & The Sack Lunch Bunch     Comedy   Family
# 657              Jim Jefferies: Freedumb     Comedy        ?
#
#                     country_1                 country_2
# 16                     Canada  United States of America
# 58                    Belgium                    France
# 76                  Argentina                         ?
# 109                    Canada  United States of America
# 120                         ?                         ?
# 122                         ?                         ?
# 258                         ?                         ?
# 300  United States of America                         ?
# 389  United States of America                         ?
# 409                   Germany                    Canada
# 580                    Canada                         ?
# 637  United States of America                         ?
# 657  United States of America                         ?

# %%
# Get the correct data from films that had the wrong id
id_list_2 = [575604, 430474, 692969, 874948, 785537, 624060, 674607, 466190, 674944, 489932, 411852, 650073, 469019]
movie_data_2 = [get_movie_data(movie_id, 
                              "genres", 
                              "imdb_id", 
                              "overview", 
                              "production_countries", 
                              "vote_average", 
                              "vote_count",
                              "title",
                              "original_title") for movie_id in id_list_2]

movie_data_2
# Out:
# [[[{'id': 53, 'name': 'Thriller'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'tt10530176',
#   'Connected by phone in the same home but 20 years apart, a serial killer puts another woman’s past — and life — on the line to change her own fate.',
#   [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   7.6,
#   407,
#   'The Call',
#   '콜'],
#  [[{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}],
#   'tt4105584',
#   'In 2100, when humanity has abandoned the earth, a colony of extravagant creatures still thrives in the deepest abyss of the ocean.',
#   [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#    {'iso_3166_1': 'CN', 'name': 'China'},
#    {'iso_3166_1': 'ES', 'name': 'Spain'},
#    {'iso_3166_1': 'CH', 'name': 'Switzerland'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   6.0,
#   120,
#   'Deep',
#   'Deep'],
#  [[{'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt11284280',
#   "In the aftermath of a nuclear disaster, a starving family find hope in a charismatic hotel owner. Lured by the prospect of a free dinner, they discover that the evening's entertainment blurs the lines between performance and reality. Will they wind up the spectators or the spectacle?",
#   [{'iso_3166_1': 'FI', 'name': 'Finland'},
#    {'iso_3166_1': 'NO', 'name': 'Norway'}],
#   5.6,
#   413,
#   'Cadaver',
#   'Kadaver'],
#  [[{'id': 80, 'name': 'Crime'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 53, 'name': 'Thriller'}],
#   'tt13717980',
#   'Ahead of a promotion, a police chief becomes entangled in a deadly incident and uncovers an intrigue fueled by grudge that threatens his colleagues.',
#   [{'iso_3166_1': 'TR', 'name': 'Turkey'}],
#   6.6,
#   32,
#   'Grudge',
#   'Kin'],
#  [[{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}],
#   'tt13067004',
#   "For Deniz, a 16-year-old teenager, this summer is different from the others. Deniz, who goes to his family's summer house every year, falls in love with a young girl named Aslı. Trying to get closer to Aslı, Deniz realizes that a handsome young man, Burak, also likes Aslı.",
#   [{'iso_3166_1': 'TR', 'name': 'Turkey'}],
#   5.8,
#   31,
#   'Last Summer',
#   'Geçen Yaz'],
#  [[{'id': 35, 'name': 'Comedy'}],
#   'tt10715194',
#   'Two adults go to their middle school reunion in order to show off their success to old bullies teenage crushes.',
#   [{'iso_3166_1': 'FR', 'name': 'France'}],
#   5.4,
#   204,
#   'Back to School',
#   'La grande classe'],
#  [[{'id': 53, 'name': 'Thriller'}],
#   'tt10307440',
#   'Anticipating a disaster, Antoine, a father, attends a survivalist training given by Alain in his autonomous hideout. In fear of a natural, economic or social crisis, the group trains to face the different possible apocalyptic scenarios. But the disaster they will experience will not be the one they predicted.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'}],
#   6.2,
#   326,
#   'The Decline',
#   "Jusqu'au déclin"],
#  [[{'id': 28, 'name': 'Action'}, {'id': 37, 'name': 'Western'}],
#   'tt5379294',
#   'In lawless badlands, reclusive Cabeleira sets out to discover the fate of his gunman father and grows to be a feared assassin himself.',
#   [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   6.2,
#   106,
#   'The Killer',
#   'O Matador'],
#  [[{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}],
#   'tt9345754',
#   'An unemployed executive is forced to sell his apartment. When he discovers that he still has the keys, he becomes obsessed with the family that now lives there and decides to recover the life he has lost, at any price.',
#   [{'iso_3166_1': 'ES', 'name': 'Spain'}],
#   6.4,
#   584,
#   'The Occupant',
#   'Hogar'],
#  [[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}],
#   'tt2850272',
#   'The story of Steve Harmon, a 17-year-old honor student whose world comes crashing down around him when he is charged with felony murder.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.0,
#   140,
#   'Monster',
#   'Monster'],
#  [[{'id': 18, 'name': 'Drama'}],
#   'tt5877882',
#   'Seven people from different walks of life give their blood sample for ELISA Test - AIDS Screening. To avoid the tension of waiting, they decide to bribe the technician and know the results earlier. They come to know only one among them has AIDS. Each one hoping it is not him,waits with anxiety. The film takes an unexpected turn from here creating an emotional and shocking end.',
#   [{'iso_3166_1': 'IN', 'name': 'India'}],
#   7.9,
#   13,
#   'Sila Samayangalil',
#   'சில சமயங்களில்'],
#  [[{'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 10402, 'name': 'Music'}],
#   'tt11318624',
#   'John Mulaney and his kid pals tackle existential topics for all ages with catchy songs, comedy sketches and special guests in a nostalgic variety special.',
#   [{'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.1,
#   73,
#   'John Mulaney & The Sack Lunch Bunch',
#   'John Mulaney & The Sack Lunch Bunch'],
#  [[{'id': 99, 'name': 'Documentary'}, {'id': 35, 'name': 'Comedy'}],
#   'tt7214762',
#   'Offbeat documentarian Chris Smith provides a behind-the-scenes look at how Jim Carrey adopted the persona of idiosyncratic comedian Andy Kaufman on the set of Man on the Moon.',
#   [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   7.6,
#   511,
#   'Jim & Andy: The Great Beyond - Featuring a Very Special, Contractually Obligated Mention of Tony Clifton',
#   'Jim & Andy: The Great Beyond - Featuring a Very Special, Contractually Obligated Mention of Tony Clifton']]

# %%
# Clean the new downloaded data
data_df_2 = pd.DataFrame(movie_data_2, columns=["genres", 
                                                "imdb_id", 
                                                "overview", 
                                                "production_countries", 
                                                "vote_average", 
                                                "vote_count",
                                                "title",
                                                "original_title"])
data_df_2.head()
# Out:
#                                               genres     imdb_id  \
# 0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...  tt10530176
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   tt4105584
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...  tt11284280
# 3  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  tt13717980
# 4  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  tt13067004
#
#                                             overview  \
# 0  Connected by phone in the same home but 20 yea...
# 1  In 2100, when humanity has abandoned the earth...
# 2  In the aftermath of a nuclear disaster, a star...
# 3  Ahead of a promotion, a police chief becomes e...
# 4  For Deniz, a 16-year-old teenager, this summer...
#
#                                 production_countries  vote_average  \
# 0      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]           7.6
# 1  [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...           6.0
# 2  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...           5.6
# 3           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           6.6
# 4           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           5.8
#
#    vote_count        title original_title
# 0         407     The Call              콜
# 1         120         Deep           Deep
# 2         413      Cadaver        Kadaver
# 3          32       Grudge            Kin
# 4          31  Last Summer      Geçen Yaz

# %%
# Build first genre column
genres_1 = []
for genre in data_df_2["genres"]:
    try:
        genres_1.append(genre[0])
    except:
        genres_1.append("?")
        
genres_1
# Out:
# [{'id': 53, 'name': 'Thriller'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 99, 'name': 'Documentary'}]

# %%
genres_1_clean = []

for genres in genres_1:
    try:
        genres_1_clean.append(genres['name'])
    except:
        genres_1_clean.append("?")
        
genres_1_clean
# Out:
# ['Thriller',
#  'Animation',
#  'Drama',
#  'Crime',
#  'Romance',
#  'Comedy',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Documentary']

# %%
data_df_2["genre_1"] = genres_1_clean

data_df_2.head()
# Out:
#                                               genres     imdb_id  \
# 0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...  tt10530176
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   tt4105584
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...  tt11284280
# 3  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  tt13717980
# 4  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...  tt13067004
#
#                                             overview  \
# 0  Connected by phone in the same home but 20 yea...
# 1  In 2100, when humanity has abandoned the earth...
# 2  In the aftermath of a nuclear disaster, a star...
# 3  Ahead of a promotion, a police chief becomes e...
# 4  For Deniz, a 16-year-old teenager, this summer...
#
#                                 production_countries  vote_average  \
# 0      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]           7.6
# 1  [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...           6.0
# 2  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...           5.6
# 3           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           6.6
# 4           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           5.8
#
#    vote_count        title original_title    genre_1
# 0         407     The Call              콜   Thriller
# 1         120         Deep           Deep  Animation
# 2         413      Cadaver        Kadaver      Drama
# 3          32       Grudge            Kin      Crime
# 4          31  Last Summer      Geçen Yaz    Romance

# %%
# Build second genre column
genres_2 = []
for genre in data_df_2["genres"]:
    try:
        genres_2.append(genre[1])
    except:
        genres_2.append("?")
        
genres_2
# Out:
# [{'id': 9648, 'name': 'Mystery'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  '?',
#  {'id': 37, 'name': 'Western'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 18, 'name': 'Drama'},
#  '?',
#  {'id': 10751, 'name': 'Family'},
#  {'id': 35, 'name': 'Comedy'}]

# %%
genres_2_clean = []

for genres in genres_2:
    try:
        genres_2_clean.append(genres['name'])
    except:
        genres_2_clean.append("?")
        
genres_2_clean
# Out:
# ['Mystery',
#  'Family',
#  'Horror',
#  'Drama',
#  'Drama',
#  '?',
#  '?',
#  'Western',
#  'Drama',
#  'Drama',
#  '?',
#  'Family',
#  'Comedy']

# %%
data_df_2["genre_2"] = genres_2_clean

# %%
# Drop genres column
data_df_2.drop(columns = "genres", inplace = True)
data_df_2.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10530176  Connected by phone in the same home but 20 yea...
# 1   tt4105584  In 2100, when humanity has abandoned the earth...
# 2  tt11284280  In the aftermath of a nuclear disaster, a star...
# 3  tt13717980  Ahead of a promotion, a police chief becomes e...
# 4  tt13067004  For Deniz, a 16-year-old teenager, this summer...
#
#                                 production_countries  vote_average  \
# 0      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]           7.6
# 1  [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...           6.0
# 2  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...           5.6
# 3           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           6.6
# 4           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           5.8
#
#    vote_count        title original_title    genre_1  genre_2
# 0         407     The Call              콜   Thriller  Mystery
# 1         120         Deep           Deep  Animation   Family
# 2         413      Cadaver        Kadaver      Drama   Horror
# 3          32       Grudge            Kin      Crime    Drama
# 4          31  Last Summer      Geçen Yaz    Romance    Drama

# %%
# Build first production country column
country_1 = []
for country in data_df_2["production_countries"]:
    try:
        country_1.append(country[0])
    except:
        country_1.append("?")
        
country_1
# Out:
# [{'iso_3166_1': 'KR', 'name': 'South Korea'},
#  {'iso_3166_1': 'BE', 'name': 'Belgium'},
#  {'iso_3166_1': 'FI', 'name': 'Finland'},
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'TR', 'name': 'Turkey'},
#  {'iso_3166_1': 'FR', 'name': 'France'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'BR', 'name': 'Brazil'},
#  {'iso_3166_1': 'ES', 'name': 'Spain'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'},
#  {'iso_3166_1': 'IN', 'name': 'India'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  {'iso_3166_1': 'CA', 'name': 'Canada'}]

# %%
country_1_clean = []

for country in country_1:
    try:
        country_1_clean.append(country['name'])
    except:
        country_1_clean.append("?")
        
country_1_clean
# Out:
# ['South Korea',
#  'Belgium',
#  'Finland',
#  'Turkey',
#  'Turkey',
#  'France',
#  'Canada',
#  'Brazil',
#  'Spain',
#  'Canada',
#  'India',
#  'United States of America',
#  'Canada']

# %%
data_df_2["country_1"] = country_1_clean

data_df_2.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10530176  Connected by phone in the same home but 20 yea...
# 1   tt4105584  In 2100, when humanity has abandoned the earth...
# 2  tt11284280  In the aftermath of a nuclear disaster, a star...
# 3  tt13717980  Ahead of a promotion, a police chief becomes e...
# 4  tt13067004  For Deniz, a 16-year-old teenager, this summer...
#
#                                 production_countries  vote_average  \
# 0      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]           7.6
# 1  [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...           6.0
# 2  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...           5.6
# 3           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           6.6
# 4           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           5.8
#
#    vote_count        title original_title    genre_1  genre_2    country_1
# 0         407     The Call              콜   Thriller  Mystery  South Korea
# 1         120         Deep           Deep  Animation   Family      Belgium
# 2         413      Cadaver        Kadaver      Drama   Horror      Finland
# 3          32       Grudge            Kin      Crime    Drama       Turkey
# 4          31  Last Summer      Geçen Yaz    Romance    Drama       Turkey

# %%
# Build second production country column
country_2 = []
for country in data_df_2["production_countries"]:
    try:
        country_2.append(country[1])
    except:
        country_2.append("?")
        
country_2
# Out:
# ['?',
#  {'iso_3166_1': 'CN', 'name': 'China'},
#  {'iso_3166_1': 'NO', 'name': 'Norway'},
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'},
#  '?',
#  '?',
#  {'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
country_2_clean = []

for country in country_2:
    try:
        country_2_clean.append(country['name'])
    except:
        country_2_clean.append("?")
        
country_2_clean
# Out:
# ['?',
#  'China',
#  'Norway',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  'United States of America',
#  '?',
#  '?',
#  'United States of America']

# %%
data_df_2["country_2"] = country_2_clean

data_df_2.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10530176  Connected by phone in the same home but 20 yea...
# 1   tt4105584  In 2100, when humanity has abandoned the earth...
# 2  tt11284280  In the aftermath of a nuclear disaster, a star...
# 3  tt13717980  Ahead of a promotion, a police chief becomes e...
# 4  tt13067004  For Deniz, a 16-year-old teenager, this summer...
#
#                                 production_countries  vote_average  \
# 0      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]           7.6
# 1  [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'is...           6.0
# 2  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...           5.6
# 3           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           6.6
# 4           [{'iso_3166_1': 'TR', 'name': 'Turkey'}]           5.8
#
#    vote_count        title original_title    genre_1  genre_2    country_1  \
# 0         407     The Call              콜   Thriller  Mystery  South Korea
# 1         120         Deep           Deep  Animation   Family      Belgium
# 2         413      Cadaver        Kadaver      Drama   Horror      Finland
# 3          32       Grudge            Kin      Crime    Drama       Turkey
# 4          31  Last Summer      Geçen Yaz    Romance    Drama       Turkey
#
#   country_2
# 0         ?
# 1     China
# 2    Norway
# 3         ?
# 4         ?

# %%
data_df_2.drop(columns = "production_countries", inplace = True)

data_df_2.head()
# Out:
#       imdb_id                                           overview  \
# 0  tt10530176  Connected by phone in the same home but 20 yea...
# 1   tt4105584  In 2100, when humanity has abandoned the earth...
# 2  tt11284280  In the aftermath of a nuclear disaster, a star...
# 3  tt13717980  Ahead of a promotion, a police chief becomes e...
# 4  tt13067004  For Deniz, a 16-year-old teenager, this summer...
#
#    vote_average  vote_count        title original_title    genre_1  genre_2  \
# 0           7.6         407     The Call              콜   Thriller  Mystery
# 1           6.0         120         Deep           Deep  Animation   Family
# 2           5.6         413      Cadaver        Kadaver      Drama   Horror
# 3           6.6          32       Grudge            Kin      Crime    Drama
# 4           5.8          31  Last Summer      Geçen Yaz    Romance    Drama
#
#      country_1 country_2
# 0  South Korea         ?
# 1      Belgium     China
# 2      Finland    Norway
# 3       Turkey         ?
# 4       Turkey         ?

# %%
# Replace with this DataFrame the original one
ids_to_correct = [16, 58, 76, 109, 120, 122, 258, 300, 389, 409, 580, 637, 657]

n = 0
for i in ids_to_correct:
    df.iloc[i, 8:] = data_df_2.iloc[n, :]
    n += 1
    
df.iloc[16, :]
# Out:
# Title                                                      The Call
# Genre                                                         Drama
# Premiere                                        2020-11-27 00:00:00
# Runtime                                                         112
# IMDB Score                                                      4.1
# Language                                                     Korean
# premiere_year                                                  2020
# tmdb_id                                                      575604
# imdb_id                                                  tt10530176
# overview          Connected by phone in the same home but 20 yea...
# vote_average                                                    7.6
# vote_count                                                      407
# title                                                      The Call
# original_title                                                    콜
# genre_1                                                    Thriller
# genre_2                                                     Mystery
# country_1                                               South Korea
# country_2                                                         ?
# Name: 16, dtype: object

# %% [markdown]
# ### 3. Get cast data

# %% [markdown]
# #### 3.1 Full cast

# %%
def get_cast(movie_id):
    '''
    Takes movie's id, communicates with TMDB API and gets its entire cast and director
    
    Parameters
    ==========
    
    movie_id: int 
        movie's id we use to connect to the API
   
    Returns
    =======
    
    list
        list with actor's name 
    
    >>> The details can be found here: https://developers.themoviedb.org/3/movies/get-movie-credits'''
    
    # Connect with the API
    response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key=f062d4d3bef1ed6f224531125e4c20c7&language=en-US")
    
    # Save the cast and crew in respective lists
    cast = list(response.json()["cast"])
    crew = list(response.json()["crew"])
    
    # List to fullfill
    actor_list = []
    directors = []
    
    ## Loop that creates a list with the original name of every actor (if actor is relevant)
    for actor in cast:
        if actor["gender"] != 0:
            actor_list.append(actor["original_name"])
        else:
            pass
        
        
    ## Get the director
    for person in crew:
        if person["job"] == "Director":
            directors.append(person["original_name"])
        else:
            pass
        
        
    return actor_list, directors

# %%
# Prove
get_cast(398978)
# Out:
# (['Robert De Niro',
#   'Al Pacino',
#   'Joe Pesci',
#   'Stephen Graham',
#   'Ray Romano',
#   'Harvey Keitel',
#   'Bobby Cannavale',
#   'Anna Paquin',
#   'Stephanie Kurtzuba',
#   'Kathrine Narducci',
#   'Welker White',
#   'Jesse Plemons',
#   'Jack Huston',
#   'Domenick Lombardozzi',
#   'Paul Herman',
#   'Louis Cancelmi',
#   'Gary Basaraba',
#   'Marin Ireland',
#   'Sebastian Maniscalco',
#   'Steven Van Zandt',
#   'Lucy Gallina',
#   'Dascha Polanco',
#   'Bo Dietl',
#   'Aleksa Palladino',
#   'Daniel Jenkins',
#   'Jim Norton',
#   'Billy Smith',
#   "Kevin O'Rourke",
#   'Action Bronson',
#   'Glenn Cunningham',
#   'Paul Ben-Victor',
#   'Patrick Gallo',
#   'Jake Hoffman',
#   'Barry Primus',
#   'Danny A. Abeckaser',
#   'Anthony J. Gallo',
#   'J. C. MacKenzie',
#   'John Polce',
#   'Joseph Riccobene',
#   'Vinny Vella',
#   'Thomas E. Sullivan',
#   'John Cenatiempo',
#   'Robert Funaro',
#   'Jennifer Mudge',
#   'India Ennenga',
#   'Jordyn DiNatale',
#   'Kate Arrington',
#   'Philip Suriano',
#   'James P. Harkins',
#   'Garry Pastore',
#   'Frank Pietrangolare',
#   'Frank Aquilino',
#   'Patrick Murney',
#   'Samantha Soule',
#   'Richard V. Licata',
#   'Vito Picone',
#   'Paul Borghese',
#   'Veronica Alicino',
#   'Mike Massimino',
#   'James Ciccone',
#   'Meghan Rafferty',
#   'James Lorinz',
#   'Vince Maritato',
#   'John Rue',
#   'Steve Routman',
#   'Charles DelGatto',
#   "Matthew F. O'Connor",
#   'Alfred Sauchelli Jr.',
#   'Diana Agostini',
#   'John Scurti',
#   'Steve Witting',
#   'Frank L. Messina',
#   'Cilda Shaur',
#   'Erick Zamora',
#   'Lou Martini Jr.',
#   'Margaret Anne Florence',
#   'Logan Crawford',
#   'Mark Fairchild',
#   'Blaise Corrigan',
#   'Jill Brown',
#   'Matt Walton',
#   'Stephen Mailer',
#   'Gino Cafarelli',
#   'Lucia Giannetta',
#   'Nina Lafarga',
#   'Jeremy Luke',
#   'Joe Passaro',
#   'Patrick Borriello',
#   'Alfred Nittoli',
#   'David Aaron Baker',
#   'Stanley Burns',
#   'Bill Timoney',
#   'Bill McHugh',
#   'Kevin Kane',
#   'Amelia Brain',
#   "Craig 'Radioman' Castaldo",
#   'Jacqueline Kennedy',
#   'John F. Kennedy',
#   'Fidel Castro',
#   'Michael Iacono',
#   'Dean Ciallella',
#   'Vanessa Mitchell'],
#  ['Martin Scorsese'])

# %%
actors_directors = [get_cast(tmdb_id) for tmdb_id in df["tmdb_id"]]

# %%
actors_directors[0][0]
# Out:
# ['Kouzou Morishita',
#  'Kenji Kamiyama',
#  'Youko Takahashi',
#  'Alex Burunova',
#  'Adi Shankar',
#  'LeSean Thomas']

# %%
len(actors_directors)
# Out:
# 684

# %%
df.shape
# Out:
# (684, 18)

# %% [markdown]
# ##### Build the columns "cast" and "director"

# %%
actors_list = []

for actors in actors_directors:
    actors_list.append(actors[0])
    
df["cast"] = actors_list
df["cast"].sample(10)
# Out:
# 549    [Carey Mulligan, Ralph Fiennes, Lily James, Jo...
# 675    [Jason Schwartzman, J.K. Simmons, Rashida Jone...
# 243    [Rishi Kapoor, Amyra Dastur, Nirmal Rishi, Apa...
# 200    [Tiya Sircar, Chad Connell, Marco Grazzini, Je...
# 272    [Dhanush, James Cosmo, Joju George, Kalaiyaras...
# 107    [Nasim Pedrad, Anna Camp, Lamorne Morris, Sara...
# 603    [Simon Greenall, Rob Rackstraw, Jo Wyatt, Keit...
# 121    [Rose McIver, Ben Lamb, Alice Krige, Honor Kne...
# 613                                                   []
# 130    [Vanessa Hudgens, Sam Palladio, Nick Sagar, Su...
# Name: cast, dtype: object

# %%
df.iloc[117,:]
# Out:
# Title                                                     Intuition
# Genre                                                      Thriller
# Premiere                                        2020-05-28 00:00:00
# Runtime                                                         116
# IMDB Score                                                      5.3
# Language                                                    Spanish
# premiere_year                                                  2020
# tmdb_id                                                      620883
# imdb_id                                                  tt12282598
# overview          Police officer Pipa works on her first big cas...
# vote_average                                                    6.3
# vote_count                                                      149
# title                                                     Intuition
# original_title                                        La corazonada
# genre_1                                                    Thriller
# genre_2                                                       Crime
# country_1                                                 Argentina
# country_2                                                         ?
# cast              [Luisana Lopilato, Joaquín Furriel, Rafael Fer...
# Name: 117, dtype: object

# %%
directors_list = []

for actors in actors_directors:
    directors_list.append(actors[1])
    
df["director"] = directors_list
df["director"].sample(10)
# Out:
# 399            [Sachin Yardi]
# 395             [Brett Haley]
# 218               [Ben Young]
# 222    [Shaun Paul Piccinino]
# 200     [Kate Miles Melville]
# 192      [Steven K. Tsuchida]
# 79            [Michael Dowse]
# 307              [Jim Mickle]
# 405               [Adam Leon]
# 19             [Chandra Liow]
# Name: director, dtype: object

# %% [markdown]
# #### 3.3 Gender column

# %%
def get_male(movie_id):
    '''
    Gets a movie id and get the sum of male actors in the movie
    
    Parameters
    ==========
    
    movie_id: int
        Movie's ID
    
    Returns
    =======
    int
        Sum of male actors
    '''
    
    # Connect with the API
    response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key=f062d4d3bef1ed6f224531125e4c20c7&language=en-US")

    # Save the cast in a list
    cast = list(response.json()["cast"])
    
    # Sum of male actors
    male_actors = 0
    
    ## Loop that builds the sum of male actors
    for actor in cast:
        if actor["gender"] == 2:
            male_actors += 1
        else:
            pass
        
    # Return the sum
    return male_actors

# %%
def get_female(movie_id):
    '''
    Gets a movie id and get the sum of female actors in the movie
    
    Parameters
    ==========
    
    movie_id: int
        Movie's ID
    
    Returns
    =======
    int
        Sum of female actors
    '''
    
    # Connect with the API
    response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key=f062d4d3bef1ed6f224531125e4c20c7&language=en-US")

    # Save the cast in a list
    cast = list(response.json()["cast"])
    
    # Sum of male actors
    female_actors = 0
    
    ## Loop that builds the sum of male actors
    for actor in cast:
        if actor["gender"] == 1:
            female_actors += 1
        else:
            pass
        
    # Return the sum
    return female_actors

# %%
# Prove
print(get_male(398978), get_female(398978))
# Out:
# 78 24

# %%
# Data validation: the sum of get_male and get female must be equal to the length of get_cast's actors_list
get_male(398978) + get_female(398978) == len(get_cast(398978)[0])
# Out:
# True

# %%
# Build columns
df["male_actors"] = [get_male(movie_id) for movie_id in df["tmdb_id"] ]
df["female_actors"] = [get_female(movie_id) for movie_id in df["tmdb_id"] ]

# %%
df.head()
# Out:
#              Title                  Genre   Premiere  Runtime  IMDB Score  \
# 0  Enter the Anime            Documentary 2019-08-05       58         2.5
# 1      Dark Forces               Thriller 2020-08-21       81         2.6
# 2          The App  Science fiction/Drama 2019-12-26       79         2.6
# 3    Sex: Unzipped                 Comedy 2021-10-26       59         3.1
# 4          Swallow                  Drama 2021-10-01      128         3.2
#
#            Language  premiere_year tmdb_id     imdb_id  \
# 0  English/Japanese           2019  616904  tt10662450
# 1           Spanish           2020  735110  tt12536776
# 2           Italian           2019  653522  tt11385066
# 3           English           2021  890280  tt15523050
# 4           English           2021  874562  tt14391622
#
#                                             overview  vote_average  \
# 0  What is anime? Through deep-dives with notable...           5.8
# 1  In search of his sister, a renegade criminal s...           4.4
# 2  Loving girlfriend, family fortune, breakout mo...           2.8
# 3  Rap superstar Saweetie hosts a celebration of ...           2.7
# 4  Set in the 1980s, Tolani Ajao is a bank secret...           4.7
#
#    vote_count            title   original_title      genre_1          genre_2  \
# 0          51  Enter the Anime  Enter the Anime  Documentary                ?
# 1          25      Dark Forces      Fuego negro       Horror           Action
# 2         105          The App          The App        Drama  Science Fiction
# 3           3    Sex: Unzipped    Sex: Unzipped       Comedy                ?
# 4           3          Swallow          Swallow        Drama          History
#
#                   country_1 country_2  \
# 0  United States of America     Japan
# 1                         ?         ?
# 2                     Italy         ?
# 3  United States of America         ?
# 4                         ?         ?
#
#                                                 cast             director  \
# 0  [Kouzou Morishita, Kenji Kamiyama, Youko Takah...      [Alex Burunova]
# 1  [Tenoch Huerta, Eréndira Ibarra, Ariane Pellic...  [Bernardo Arellano]
# 2  [Vincenzo Crea, Greta Scarano, Maya Sansa, Abe...       [Elisa Fuksas]
# 3  [Saweetie, Joel Kim Booster, Michelle Buteau, ...                   []
# 4                                                 []     [Kunle Afolayan]
#
#    male_actors  female_actors
# 0            4              2
# 1            2              2
# 2            3              3
# 3            3              7
# 4            0              0

# %%
# Data validation: the sum of "male_actors" and "female" actors must be equal to the lenght of cast

wrong = 0

for row in df:
    if row[-2] + row[-1] == len(row[-4]):
        wrong += 1
    else:
        pass
    
wrong
# Out:
# 0

# %% [markdown]
# ### 4. Save final DF

# %%
df.to_excel("final_netflix_df.xlsx", index = False)
